# %%
import numpy as np
import pandas as pd
import sqlite3

# %%
def get_host_from_headers(x):
    temp = x.replace('"','').split('],[')
    for t in temp:
            pair = t.replace(']]','').replace('[[','').split(',')
            if "Host" in pair:
                host_value = pair[1]
    return host_value

def get_cookies_from_headers(x):
    ls = x.replace('"','').split('],[')
    for l in ls:
        ta = l.replace(']]','').split(',')
        if "Cookie" in ta:
            return ta[-1]
    return ''

# %%
for exp_number in range(1,2):
    exp_path = "./raw-data/exp"+str(exp_number)+"/crawl-data.sqlite"
    
    conn = sqlite3.connect(exp_path)
    javascript_cookies = pd.read_sql_query("select visit_id, record_type, change_cause, host, name, value, time_stamp from javascript_cookies;", conn)
    # http_responses = pd.read_sql_query("select visit_id, url, method, headers, time_stamp from http_responses where response_status == 200;", conn)
    http_requests = pd.read_sql_query("select visit_id, headers, referrer, Url, time_stamp from http_requests;", conn)
    javascript = pd.read_sql_query("select visit_id, script_url, top_level_url, symbol, operation, value, arguments, time_stamp from javascript;", conn)
    site_visits = pd.read_sql_query("select visit_id, site_url from site_visits;", conn)
    
    conn.close()
    
    names = list(map(lambda x: x.split('.')[1], list(site_visits.site_url)))
    websites = list( names[i] for i in [0,5,10])
    
    web_dict = {
      "nytimes": 'nytimes|nyt',
      "webmd": 'webmd',
      "berkeley": 'berkeley'
    }

# %%
javascript
# Out:
#        visit_id                                         script_url  \
# 0             1                           https://www.nytimes.com/
# 1             1                           https://www.nytimes.com/
# 2             1                           https://www.nytimes.com/
# 3             1                           https://www.nytimes.com/
# 4             1                           https://www.nytimes.com/
# 5             1                           https://www.nytimes.com/
# 6             1                           https://www.nytimes.com/
# 7             1                           https://www.nytimes.com/
# 8             1                           https://www.nytimes.com/
# 9             1                           https://www.nytimes.com/
# 10            1                           https://www.nytimes.com/
# 11            1                           https://www.nytimes.com/
# 12            1                           https://www.nytimes.com/
# 13            1                           https://www.nytimes.com/
# 14            1                           https://www.nytimes.com/
# 15            1                           https://www.nytimes.com/
# 16            1                           https://www.nytimes.com/
# 17            1                           https://www.nytimes.com/
# 18            1                           https://www.nytimes.com/
# 19            1                           https://www.nytimes.com/
# 20            1                           https://www.nytimes.com/
# 21            1                           https://www.nytimes.com/
# 22            1                           https://www.nytimes.com/
# 23            1                           https://www.nytimes.com/
# 24            1                           https://www.nytimes.com/
# 25            1                           https://www.nytimes.com/
# 26            1                           https://www.nytimes.com/
# 27            1                           https://www.nytimes.com/
# 28            1                           https://www.nytimes.com/
# 29            1                           https://www.nytimes.com/
# ...         ...                                                ...
# 27318        15      https://www.google-analytics.com/analytics.js
# 27319        15      https://www.google-analytics.com/analytics.js
# 27320        15      https://www.google-analytics.com/analytics.js
# 27321        15      https://www.google-analytics.com/analytics.js
# 27322        15      https://www.google-analytics.com/analytics.js
# 27323        15      https://www.google-analytics.com/analytics.js
# 27324        15      https://www.google-analytics.com/analytics.js
# 27325        15      https://www.google-analytics.com/analytics.js
# 27326        15      https://www.google-analytics.com/analytics.js
# 27327        15      https://www.google-analytics.com/analytics.js
# 27328        15      https://www.google-analytics.com/analytics.js
# 27329        15      https://www.google-analytics.com/analytics.js
# 27330        15      https://www.google-analytics.com/analytics.js
# 27331        15      https://www.google-analytics.com/analytics.js
# 27332        15      https://www.google-analytics.com/analytics.js
# 27333        15      https://www.google-analytics.com/analytics.js
# 27334        15      https://www.google-analytics.com/analytics.js
# 27335        15      https://www.google-analytics.com/analytics.js
# 27336        15  https://script.crazyegg.com/pages/scripts/0085...
# 27337        15  https://script.crazyegg.com/pages/scripts/0085...
# 27338        15  https://script.crazyegg.com/pages/scripts/0085...
# 27339        15  https://script.crazyegg.com/pages/scripts/0085...
# 27340        15  https://script.crazyegg.com/pages/scripts/0085...
# 27341        15  https://siteimproveanalytics.com/js/siteanalyz...
# 27342        15  https://siteimproveanalytics.com/js/siteanalyz...
# 27343        15  https://siteimproveanalytics.com/js/siteanalyz...
# 27344        15  https://siteimproveanalytics.com/js/siteanalyz...
# 27345        15  https://siteimproveanalytics.com/js/siteanalyz...
# 27346        15  https://siteimproveanalytics.com/js/siteanalyz...
# 27347        15  https://siteimproveanalytics.com/js/siteanalyz...
#
#                                            top_level_url  \
# 0                               https://www.nytimes.com/
# 1                               https://www.nytimes.com/
# 2                               https://www.nytimes.com/
# 3                               https://www.nytimes.com/
# 4                               https://www.nytimes.com/
# 5                               https://www.nytimes.com/
# 6                               https://www.nytimes.com/
# 7                               https://www.nytimes.com/
# 8                               https://www.nytimes.com/
# 9                               https://www.nytimes.com/
# 10                              https://www.nytimes.com/
# 11                              https://www.nytimes.com/
# 12                              https://www.nytimes.com/
# 13                              https://www.nytimes.com/
# 14                              https://www.nytimes.com/
# 15                              https://www.nytimes.com/
# 16                              https://www.nytimes.com/
# 17                              https://www.nytimes.com/
# 18                              https://www.nytimes.com/
# 19                              https://www.nytimes.com/
# 20                              https://www.nytimes.com/
# 21                              https://www.nytimes.com/
# 22                              https://www.nytimes.com/
# 23                              https://www.nytimes.com/
# 24                              https://www.nytimes.com/
# 25                              https://www.nytimes.com/
# 26                              https://www.nytimes.com/
# 27                              https://www.nytimes.com/
# 28                              https://www.nytimes.com/
# 29                              https://www.nytimes.com/
# ...                                                  ...
# 27318  https://engineering.berkeley.edu/engineering-f...
# 27319  https://engineering.berkeley.edu/engineering-f...
# 27320  https://engineering.berkeley.edu/engineering-f...
# 27321  https://engineering.berkeley.edu/engineering-f...
# 27322  https://engineering.berkeley.edu/engineering-f...
# 27323  https://engineering.berkeley.edu/engineering-f...
# 27324  https://engineering.berkeley.edu/engineering-f...
# 27325  https://engineering.berkeley.edu/engineering-f...
# 27326  https://engineering.berkeley.edu/engineering-f...
# 27327  https://engineering.berkeley.edu/engineering-f...
# 27328  https://engineering.berkeley.edu/engineering-f...
# 27329  https://engineering.berkeley.edu/engineering-f...
# 27330  https://engineering.berkeley.edu/engineering-f...
# 27331  https://engineering.berkeley.edu/engineering-f...
# 27332  https://engineering.berkeley.edu/engineering-f...
# 27333  https://engineering.berkeley.edu/engineering-f...
# 27334  https://engineering.berkeley.edu/engineering-f...
# 27335  https://engineering.berkeley.edu/engineering-f...
# 27336  https://engineering.berkeley.edu/engineering-f...
# 27337  https://engineering.berkeley.edu/engineering-f...
# 27338  https://engineering.berkeley.edu/engineering-f...
# 27339  https://engineering.berkeley.edu/engineering-f...
# 27340  https://engineering.berkeley.edu/engineering-f...
# 27341  https://engineering.berkeley.edu/engineering-f...
# 27342  https://engineering.berkeley.edu/engineering-f...
# 27343  https://engineering.berkeley.edu/engineering-f...
# 27344  https://engineering.berkeley.edu/engineering-f...
# 27345  https://engineering.berkeley.edu/engineering-f...
# 27346  https://engineering.berkeley.edu/engineering-f...
# 27347  https://engineering.berkeley.edu/engineering-f...
#
#                            symbol operation  \
# 0      window.navigator.userAgent       get
# 1      window.navigator.userAgent       get
# 2      window.navigator.userAgent       get
# 3        window.document.referrer       get
# 4          window.document.cookie       get
# 5          window.document.cookie       get
# 6          window.document.cookie       get
# 7          window.document.cookie       get
# 8          window.document.cookie       get
# 9          window.document.cookie       get
# 10         window.document.cookie       get
# 11         window.document.cookie       get
# 12         window.document.cookie       get
# 13         window.document.cookie       get
# 14         window.document.cookie       get
# 15         window.document.cookie       get
# 16         window.document.cookie       get
# 17         window.document.cookie       get
# 18         window.document.cookie       get
# 19         window.document.cookie       get
# 20         window.document.cookie       get
# 21         window.document.cookie       get
# 22         window.document.cookie       get
# 23         window.document.cookie       get
# 24         window.document.cookie       get
# 25         window.document.cookie       get
# 26         window.document.cookie       get
# 27         window.document.cookie       get
# 28         window.document.cookie       get
# 29         window.document.cookie       get
# ...                           ...       ...
# 27318      window.document.cookie       get
# 27319      window.document.cookie       set
# 27320      window.document.cookie       get
# 27321      window.document.cookie       get
# 27322      window.document.cookie       get
# 27323      window.document.cookie       get
# 27324      window.document.cookie       set
# 27325      window.document.cookie       get
# 27326      window.document.cookie       get
# 27327      window.document.cookie       get
# 27328      window.document.cookie       get
# 27329      window.document.cookie       get
# 27330      window.document.cookie       get
# 27331      window.document.cookie       get
# 27332      window.document.cookie       get
# 27333      window.document.cookie       get
# 27334      window.document.cookie       set
# 27335      window.document.cookie       get
# 27336  window.navigator.userAgent       get
# 27337     window.navigator.onLine       get
# 27338   window.navigator.language       get
# 27339  window.navigator.languages       get
# 27340  window.navigator.languages       get
# 27341      window.document.cookie       get
# 27342      window.document.cookie       get
# 27343      window.document.cookie       get
# 27344      window.document.cookie       get
# 27345      window.document.cookie       get
# 27346      window.document.cookie       get
# 27347      window.document.cookie       set
#
#                                                    value arguments  \
# 0      Mozilla/5.0 (X11; Linux x86_64; rv:72.0) Gecko...      None
# 1      Mozilla/5.0 (X11; Linux x86_64; rv:72.0) Gecko...      None
# 2      Mozilla/5.0 (X11; Linux x86_64; rv:72.0) Gecko...      None
# 3                                                             None
# 4      nyt-gdpr=0; nyt-geo=US; nyt-a=4Oe53a4sDRVl1-qj...      None
# 5      nyt-gdpr=0; nyt-geo=US; nyt-a=4Oe53a4sDRVl1-qj...      None
# 6      nyt-gdpr=0; nyt-geo=US; nyt-a=4Oe53a4sDRVl1-qj...      None
# 7      nyt-gdpr=0; nyt-geo=US; nyt-a=4Oe53a4sDRVl1-qj...      None
# 8      nyt-gdpr=0; nyt-geo=US; nyt-a=4Oe53a4sDRVl1-qj...      None
# 9      nyt-gdpr=0; nyt-geo=US; nyt-a=4Oe53a4sDRVl1-qj...      None
# 10     nyt-gdpr=0; nyt-geo=US; nyt-a=4Oe53a4sDRVl1-qj...      None
# 11     nyt-gdpr=0; nyt-geo=US; nyt-a=4Oe53a4sDRVl1-qj...      None
# 12     nyt-gdpr=0; nyt-geo=US; nyt-a=4Oe53a4sDRVl1-qj...      None
# 13     nyt-gdpr=0; nyt-geo=US; nyt-a=4Oe53a4sDRVl1-qj...      None
# 14     nyt-gdpr=0; nyt-geo=US; nyt-a=4Oe53a4sDRVl1-qj...      None
# 15     nyt-gdpr=0; nyt-geo=US; nyt-a=4Oe53a4sDRVl1-qj...      None
# 16     nyt-gdpr=0; nyt-geo=US; nyt-a=4Oe53a4sDRVl1-qj...      None
# 17     nyt-gdpr=0; nyt-geo=US; nyt-a=4Oe53a4sDRVl1-qj...      None
# 18     nyt-gdpr=0; nyt-geo=US; nyt-a=4Oe53a4sDRVl1-qj...      None
# 19     nyt-gdpr=0; nyt-geo=US; nyt-a=4Oe53a4sDRVl1-qj...      None
# 20     nyt-gdpr=0; nyt-geo=US; nyt-a=4Oe53a4sDRVl1-qj...      None
# 21     nyt-gdpr=0; nyt-geo=US; nyt-a=4Oe53a4sDRVl1-qj...      None
# 22     nyt-gdpr=0; nyt-geo=US; nyt-a=4Oe53a4sDRVl1-qj...      None
# 23     nyt-gdpr=0; nyt-geo=US; nyt-a=4Oe53a4sDRVl1-qj...      None
# 24     nyt-gdpr=0; nyt-geo=US; nyt-a=4Oe53a4sDRVl1-qj...      None
# 25     nyt-gdpr=0; nyt-geo=US; nyt-a=4Oe53a4sDRVl1-qj...      None
# 26     nyt-gdpr=0; nyt-geo=US; nyt-a=4Oe53a4sDRVl1-qj...      None
# 27     nyt-gdpr=0; nyt-geo=US; nyt-a=4Oe53a4sDRVl1-qj...      None
# 28     nyt-gdpr=0; nyt-geo=US; nyt-a=4Oe53a4sDRVl1-qj...      None
# 29     nyt-gdpr=0; nyt-geo=US; nyt-a=4Oe53a4sDRVl1-qj...      None
# ...                                                  ...       ...
# 27318  __utmc=41573937; __utmt=1; __utma=41573937.991...      None
# 27319  _ga=GA1.3.991307700.1588083347; path=/; expire...      None
# 27320  __utmc=41573937; __utmt=1; __utma=41573937.991...      None
# 27321  __utmc=41573937; __utmt=1; __utma=41573937.991...      None
# 27322  __utmc=41573937; __utmt=1; __utma=41573937.991...      None
# 27323  __utmc=41573937; __utmt=1; __utma=41573937.991...      None
# 27324  _gid=GA1.3.2145931961.1588083372; path=/; expi...      None
# 27325  __utmc=41573937; __utmt=1; __utma=41573937.991...      None
# 27326  __utmc=41573937; __utmt=1; __utma=41573937.991...      None
# 27327  __utmc=41573937; __utmt=1; __utma=41573937.991...      None
# 27328  __utmc=41573937; __utmt=1; __utma=41573937.991...      None
# 27329  __utmc=41573937; __utmt=1; __utma=41573937.991...      None
# 27330  __utmc=41573937; __utmt=1; __utma=41573937.991...      None
# 27331  __utmc=41573937; __utmt=1; __utma=41573937.991...      None
# 27332  __utmc=41573937; __utmt=1; __utma=41573937.991...      None
# 27333  __utmc=41573937; __utmt=1; __utma=41573937.991...      None
# 27334  _gat_UA-4659861-11=1; path=/; expires=Tue, 28 ...      None
# 27335  __utmc=41573937; __utmt=1; __utma=41573937.991...      None
# 27336  Mozilla/5.0 (X11; Linux x86_64; rv:72.0) Gecko...      None
# 27337                                               true      None
# 27338                                              en-US      None
# 27339                                     ["en-US","en"]      None
# 27340                                     ["en-US","en"]      None
# 27341  __utmc=41573937; __utmt=1; __utma=41573937.991...      None
# 
indx2 = findIdx(http_requests,'url', websites[2])
http_requests["context_id"] = [1] * (indx1)  + [2] * (indx2 - indx1) + [3] * (http_requests.shape[0] - indx2)

indx1 = findIdx(javascript, 'top_level_url', websites[1])
indx2 = findIdx(javascript, 'top_level_url', websites[2])
javascript["context_id"] = [1] * (indx1)  + [2] * (indx2 - indx1) + [3] * (javascript.shape[0] - indx2)

# %%
def findIdx(df, colname, keyword):
    for i, web in enumerate(df[colname].tolist()):
        if web.rfind(keyword) != -1:
            return i

# %%
for context_number in range(1,4):
        
        ############################# cookies #############################
        js_cookies = javascript_cookies[javascript_cookies.context_id == context_number]
    
        # first party cookies (filter by host)
        js_cookies_first = js_cookies[js_cookies.host.str.contains(web_dict.get(websites[context_number-1]))]

        # third party cookies (filter by host)
        js_cookies_third = js_cookies[~js_cookies.host.str.contains(web_dict.get(websites[context_number-1]))]

        js_cookies_third.to_csv(str(exp_number)+'-'+str(context_number)+'-ThirdCookies.csv', index=False)
        
        
        ############################# JS #############################
        js = javascript[javascript.context_id == context_number]
        
        # filter by script_url (get domain from script_url)
        temp = list(map(lambda x:x[1], js['script_url'].str.split(".")))
        js['temp'] = temp
        
        js_third = js[~js.script_url.str.contains(web_dict.get(websites[context_number-1]))]

        js_third.to_csv(str(exp_number)+'-'+str(context_number)+'-js.csv', index=False)
        
        
        ############################# HTTP REQUEST #############################
        temp = list(map(lambda x: get_host_from_headers(x), http_requests.headers.tolist()))
        http_requests["host"] = temp

        http_req_cookies = list(map(lambda x: get_cookies_from_headers(x), http_requests.headers.tolist()))
        http_requests["cookies"] = http_req_cookies

        # get domain from host (eg. "ade.googlesyndication.com" -> "googlesyndication")
        hr = http_requests[http_requests.context_id == context_number]

        temp = list(map(lambda x:x[-2], hr['host'].str.split(".")))
        hr['temp'] = temp
        
        hr_third = hr[~hr.temp.str.contains(web_dict.get(websites[context_number-1]))]

        hr_third.to_csv(str(exp_number)+'-'+str(context_number)+'-httprequest.csv', index=False)
# Out:
# /Users/rainyleon/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/rainyleon/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
js
# Out:
#        visit_id                                         script_url  \
# 25242        11                 https://use.typekit.net/zpy2xov.js
# 25243        11                 https://use.typekit.net/zpy2xov.js
# 25244        11                 https://use.typekit.net/zpy2xov.js
# 25245        11  https://siteimproveanalytics.com/js/siteanalyz...
# 25246        11  https://siteimproveanalytics.com/js/siteanalyz...
# 25247        11             https://ssl.google-analytics.com/ga.js
# 25248        11             https://ssl.google-analytics.com/ga.js
# 25249        11             https://ssl.google-analytics.com/ga.js
# 25250        11             https://ssl.google-analytics.com/ga.js
# 25251        11             https://ssl.google-analytics.com/ga.js
# 25252        11             https://ssl.google-analytics.com/ga.js
# 25253        11             https://ssl.google-analytics.com/ga.js
# 25254        11             https://ssl.google-analytics.com/ga.js
# 25255        11             https://ssl.google-analytics.com/ga.js
# 25256        11             https://ssl.google-analytics.com/ga.js
# 25257        11             https://ssl.google-analytics.com/ga.js
# 25258        11             https://ssl.google-analytics.com/ga.js
# 25259        11             https://ssl.google-analytics.com/ga.js
# 25260        11             https://ssl.google-analytics.com/ga.js
# 25261        11             https://ssl.google-analytics.com/ga.js
# 25262        11             https://ssl.google-analytics.com/ga.js
# 25263        11             https://ssl.google-analytics.com/ga.js
# 25264        11             https://ssl.google-analytics.com/ga.js
# 25265        11             https://ssl.google-analytics.com/ga.js
# 25266        11             https://ssl.google-analytics.com/ga.js
# 25267        11             https://ssl.google-analytics.com/ga.js
# 25268        11             https://ssl.google-analytics.com/ga.js
# 25269        11             https://ssl.google-analytics.com/ga.js
# 25270        11             https://ssl.google-analytics.com/ga.js
# 25271        11             https://ssl.google-analytics.com/ga.js
# ...         ...                                                ...
# 27318        15      https://www.google-analytics.com/analytics.js
# 27319        15      https://www.google-analytics.com/analytics.js
# 27320        15      https://www.google-analytics.com/analytics.js
# 27321        15      https://www.google-analytics.com/analytics.js
# 27322        15      https://www.google-analytics.com/analytics.js
# 27323        15      https://www.google-analytics.com/analytics.js
# 27324        15      https://www.google-analytics.com/analytics.js
# 27325        15      https://www.google-analytics.com/analytics.js
# 27326        15      https://www.google-analytics.com/analytics.js
# 27327        15      https://www.google-analytics.com/analytics.js
# 27328        15      https://www.google-analytics.com/analytics.js
# 27329        15      https://www.google-analytics.com/analytics.js
# 27330        15      https://www.google-analytics.com/analytics.js
# 27331        15      https://www.google-analytics.com/analytics.js
# 27332        15      https://www.google-analytics.com/analytics.js
# 27333        15      https://www.google-analytics.com/analytics.js
# 27334        15      https://www.google-analytics.com/analytics.js
# 27335        15      https://www.google-analytics.com/analytics.js
# 27336        15  https://script.crazyegg.com/pages/scripts/0085...
# 27337        15  https://script.crazyegg.com/pages/scripts/0085...
# 27338        15  https://script.crazyegg.com/pages/scripts/0085...
# 27339        15  https://script.crazyegg.com/pages/scripts/0085...
# 27340        15  https://script.crazyegg.com/pages/scripts/0085...
# 27341        15  https://siteimproveanalytics.com/js/siteanalyz...
# 27342        15  https://siteimproveanalytics.com/js/siteanalyz...
# 27343        15  https://siteimproveanalytics.com/js/siteanalyz...
# 27344        15  https://siteimproveanalytics.com/js/siteanalyz...
# 27345        15  https://siteimproveanalytics.com/js/siteanalyz...
# 27346        15  https://siteimproveanalytics.com/js/siteanalyz...
# 27347        15  https://siteimproveanalytics.com/js/siteanalyz...
#
#                                            top_level_url  \
# 25242                          https://www.berkeley.edu/
# 25243                          https://www.berkeley.edu/
# 25244                          https://www.berkeley.edu/
# 25245                          https://www.berkeley.edu/
# 25246                          https://www.berkeley.edu/
# 25247                          https://www.berkeley.edu/
# 25248                          https://www.berkeley.edu/
# 25249                          https://www.berkeley.edu/
# 25250                          https://www.berkeley.edu/
# 25251                          https://www.berkeley.edu/
# 25252                          https://www.berkeley.edu/
# 25253                          https://www.berkeley.edu/
# 25254                          https://www.berkeley.edu/
# 25255                          https://www.berkeley.edu/
# 25256                          https://www.berkeley.edu/
# 25257                          https://www.berkeley.edu/
# 25258                          https://www.berkeley.edu/
# 25259                          https://www.berkeley.edu/
# 25260                          https://www.berkeley.edu/
# 25261                          https://www.berkeley.edu/
# 25262                          https://www.berkeley.edu/
# 25263                          https://www.berkeley.edu/
# 25264                          https://www.berkeley.edu/
# 25265                          https://www.berkeley.edu/
# 25266                          https://www.berkeley.edu/
# 25267                          https://www.berkeley.edu/
# 25268                          https://www.berkeley.edu/
# 25269                          https://www.berkeley.edu/
# 25270                          https://www.berkeley.edu/
# 25271                          https://www.berkeley.edu/
# ...                                                  ...
# 27318  https://engineering.berkeley.edu/engineering-f...
# 27319  https://engineering.berkeley.edu/engineering-f...
# 27320  https://engineering.berkeley.edu/engineering-f...
# 27321  https://engineering.berkeley.edu/engineering-f...
# 27322  https://engineering.berkeley.edu/engineering-f...
# 27323  https://engineering.berkeley.edu/engineering-f...
# 27324  https://engineering.berkeley.edu/engineering-f...
# 27325  https://engineering.berkeley.edu/engineering-f...
# 27326  https://engineering.berkeley.edu/engineering-f...
# 27327  https://engineering.berkeley.edu/engineering-f...
# 27328  https://engineering.berkeley.edu/engineering-f...
# 27329  https://engineering.berkeley.edu/engineering-f...
# 27330  https://engineering.berkeley.edu/engineering-f...
# 27331  https://engineering.berkeley.edu/engineering-f...
# 27332  https://engineering.berkeley.edu/engineering-f...
# 27333  https://engineering.berkeley.edu/engineering-f...
# 27334  https://engineering.berkeley.edu/engineering-f...
# 27335  https://engineering.berkeley.edu/engineering-f...
# 27336  https://engineering.berkeley.edu/engineering-f...
# 27337  https://engineering.berkeley.edu/engineering-f...
# 27338  https://engineering.berkeley.edu/engineering-f...
# 27339  https://engineering.berkeley.edu/engineering-f...
# 27340  https://engineering.berkeley.edu/engineering-f...
# 27341  https://engineering.berkeley.edu/engineering-f...
# 27342  https://engineering.berkeley.edu/engineering-f...
# 27343  https://engineering.berkeley.edu/engineering-f...
# 27344  https://engineering.berkeley.edu/engineering-f...
# 27345  https://engineering.berkeley.edu/engineering-f...
# 27346  https://engineering.berkeley.edu/engineering-f...
# 27347  https://engineering.berkeley.edu/engineering-f...
#
#                            symbol operation  \
# 25242  window.navigator.userAgent       get
# 25243  window.navigator.userAgent       get
# 25244  window.navigator.userAgent       get
# 25245    window.document.referrer       get
# 25246    window.document.referrer       get
# 25247    window.document.referrer       get
# 25248      window.document.cookie       get
# 25249    window.screen.colorDepth       get
# 25250   window.navigator.language       get
# 25251    window.navigator.appName       get
# 25252   window.navigator.platform       get
# 25253  window.navigator.userAgent       get
# 25254      window.document.cookie       get
# 25255    window.document.referrer       get
# 25256      window.document.cookie       get
# 25257                 window.name       get
# 25258      window.document.cookie       get
# 25259  window.navigator.userAgent       get
# 25260      window.document.cookie       set
# 25261  window.navigator.userAgent       get
# 25262      window.document.cookie       set
# 25263  window.navigator.userAgent       get
# 25264      window.document.cookie       set
# 25265  window.navigator.userAgent       get
# 25266      window.document.cookie       set
# 25267      window.document.cookie       set
# 25268      window.document.cookie       get
# 25269      window.document.cookie       get
# 25270      window.document.cookie       get
# 25271      window.document.cookie       get
# ...                           ...       ...
# 27318      window.document.cookie       get
# 27319      window.document.cookie       set
# 27320      window.document.cookie       get
# 27321      window.document.cookie       get
# 27322      window.document.cookie       get
# 27323      window.document.cookie       get
# 27324      window.document.cookie       set
# 27325      window.document.cookie       get
# 27326      window.document.cookie       get
# 27327      window.document.cookie       get
# 27328      window.document.cookie       get
# 27329      window.document.cookie       get
# 27330      window.document.cookie       get
# 27331      window.document.cookie       get
# 27332      window.document.cookie       get
# 27333      window.document.cookie       get
# 27334      window.document.cookie       set
# 27335      window.document.cookie       get
# 27336  window.navigator.userAgent       get
# 27337     window.navigator.onLine       get
# 27338   window.navigator.language       get
# 27339  window.navigator.languages       get
# 27340  window.navigator.languages       get
# 27341      window.document.cookie       get
# 27342      window.document.cookie       get
# 27343      window.document.cookie       get
# 27344      window.document.cookie       get
# 27345      window.document.cookie       get
# 27346      window.document.cookie       get
# 27347      window.document.cookie       set
#
#                                                    value arguments  \
# 25242  Mozilla/5.0 (X11; Linux x86_64; rv:72.0) Gecko...      None
# 25243  Mozilla/5.0 (X11; Linux x86_64; rv:72.0) Gecko...      None
# 25244  Mozilla/5.0 (X11; Linux x86_64; rv:72.0) Gecko...      None
# 25245                                                         None
# 25246                                                         None
# 25247                                                         None
# 25248                                                         None
# 25249                                                 24      None
# 25250                                              en-US      None
# 25251                                           Netscape      None
# 25252                                       Linux x86_64      None
# 25253  Mozilla/5.0 (X11; Linux x86_64; rv:72.0) Gecko...      None
# 25254                                                         None
# 25255                                                         None
# 25256                                                         None
# 25257                                                         None
# 25258                                                         None
# 25259  Mozilla/5.0 (X11; Linux x86_64; rv:72.0) Gecko...      None
# 25260  __utma=41573937.991307700.1588083347.158808334...      None
# 25261  Mozilla/5.0 (X11; Linux x86_64; rv:72.0) Gecko...      None
# 25262  __utmb=41573937.0.10.1588083347; path=/; expir...      None
# 25263  Mozilla/5.0 (X11; Linux x86_64; rv:72.0) Gecko...      None
# 25264      __utmc=41573937; path=/; domain=berkeley.edu;      None
# 25265  Mozilla/5.0 (X11; Linux x86_64; rv:72.0) Gecko...      None
# 25266  __utmz=41573937.1588083347.1.1.utmcsr=(direct)...      None
# 25267  __utmv=; path=/; expires=Tue, 28 Apr 2020 14:1...      None
# 25268  __utma=41573937.991307700.1588083347.158808334...      None
# 25269  __utma=41573937.991307700.1588083347.158808334...      None
# 25270  __utma=41573937.991307700.1588083347.158808334...      None
# 25271  __utma=41573937.991307700.1588083347.158808334...      None
# ...                                                  ...       ...
# 27318  __utmc=41573937; __utmt=1; __utma=41573937.991...      None
# 27319  _ga=GA1.3.991307700.1588083347; path=/; expire...      None
# 27320  __utmc=41573937; __utmt=1; __utma=41573937.991...      None
# 27321  __utmc=41573937; __utmt=1; __utma=41573937.991...      None
# 27322  __utmc=41573937; __utmt=1; __utma=41573937.991...      None
# 27323  __utmc=41573937; __utmt=1; __utma=41573937.991...      None
# 27324  _gid=GA1.3.2145931961.1588083372; path=/; expi...      None
# 27325  __utmc=41573937; __utmt=1; __utma=41573937.991...      None
# 27326  __utmc=41573937; __utmt=1; __utma=41573937.991...      None
# 27327  __utmc=41573937; __utmt=1; __utma=41573937.991...      None
# 27328  __utmc=41573937; __utmt=1; __utma=41573937.991...      None
# 27329  __utmc=41573937; __utmt=1; __utma=41573937.991...      None
# 27330  __utmc=41573937; __utmt=1; __utma=41573937.991...      None
# 27331  __utmc=41573937; __utmt=1; __utma=41573937.991...      None
# 27332  __utmc=41573937; __utmt=1; __utma=41573937.991...      None
# 27333  __utmc=41573937; __utmt=1; __utma=41573937.991...      None
# 27334  _gat_UA-4659861-11=1; path=/; expires=Tue, 28 ...      None
# 27335  __utmc=41573937; __utmt=1; __utma=41573937.991...      None
# 27336  Mozilla/5.0 (X11; Linux x86_64; rv:72.0) Gecko...      None
# 27337                                               true      None
# 27338                                              en-US      None
# 27339                                     ["en-US","en"]      None
# 27340                                     ["en-US","en"]      None
# 27341  __utmc=41573937; __utmt=1; __utma=41573937.991...      None
# 27342  __utmc=41573937; __utmt=1; __utma=41573937.991...      None
# 27343  __utmc=41573937; __utmt=1; __utma=41573937.991...      None
# 27344  __utmc=41573937; __utmt=1; __utma=41573937.991...      None
# 27345  __utmc=41573937; __utmt=1; __utma=41573937.991...      None
# 27346  __utmc=41573937; __utmt=1; __utma=41573937.991...      None
# 27347  nmstat=1588083484512; expires=Mon, 23 Jan 2023...      None
#
#                      time_stamp  context_id                     temp
# 25242  2020-04-28T14:15:45.892Z           3                  typekit
# 25243  2020-04-28T14:15:46.985Z           3                  typekit
# 25244  2020-04-28T14:15:46.986Z           3                  typekit
# 25245  2020-04-28T14:15:46.986Z           3  com/js/siteanalyze_8343
# 25246  2020-04-28T14:15:46.988Z           3  com/js/siteanalyze_8343
# 25247  2020-04-28T14:15:46.990Z           3         google-analytics
# 25248  2020-04-28T14:15:46.991Z           3         google-analytics
# 25249  2020-04-28T14:15:46.993Z           3         google-analytics
# 25250  2020-04-28T14:15:46.993Z           3         google-analytics
# 25251  2020-04-28T14:15:46.995Z           3         google-analytics
# 25252  2020-04-28T14:15:46.996Z           3         google-analytics
# 25253  2020-04-28T14:15:46.997Z           3         google-analytics
