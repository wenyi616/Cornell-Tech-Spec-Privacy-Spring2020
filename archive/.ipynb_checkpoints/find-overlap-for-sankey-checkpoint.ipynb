# %%
import pandas as pd
import numpy as np
import collections
import math

# %%
exp_num = 1
unique_huge = pd.read_csv("../hugecookies/hugecookies-{}.csv".format(exp_num))

# %%
unique_huge.shape
# Out:
# (280812, 7)

# %%
unique_huge.dropna(inplace=True)
unique_huge.shape
# Out:
# (270433, 7)

# %%
unique_huge = unique_huge[unique_huge['value'].str.len() >= 8]
unique_huge.shape
# Out:
# (203074, 7)

# %%
unique_huge.drop(unique_huge[unique_huge.name.str.contains('Test|test|lang|SameSite|Samesite|sameSite|samesite|expires|Path|path|domain|Expires|max-age')].index, inplace=True)
unique_huge.drop(unique_huge[unique_huge.value.isin(['1','0','2','true','yes','YES','ok','nan','none','None','NO_DATA','null','setstatuscode~~1'])].index, inplace=True)
unique_huge.shape
# Out:
# (198045, 7)

# %%
l = ['cnn','nytimes','theguardian','washingtonpost','forbes',\
     'webmd','mayoclinic','myfitnesspal','medscape','verywellhealth',\
     'jhu','mit','edx','harvard','colledgeboard']

unique_huge['vname'] = unique_huge['visit_id'].apply(lambda x: l[math.ceil(x/5)-1])
unique_huge
# ls_news = ['cnn','nytimes','theguardian','washingtonpost','forbes']
# ls_health = ['webmd','mayoclinic','myfitnesspal','medscape','verywellhealth']
# ls_education = ['jhu','mit','edx','harvard','colledgeboard']
# name_dict = {1: ls_news, 2: ls_health, 3:ls_education}
# Out:
#         context_id  visit_id  \
# 0                1         1
# 3                1         1
# 6                1         1
# 7                1         1
# 8                1         1
# ...            ...       ...
# 280806           3        75
# 280807           3        75
# 280809           3        75
# 280810           3        75
# 280811           3        75
#
#                                                      host  \
# 0                                               .bing.com
# 3                                             .demdex.net
# 6                                             .adsrvr.org
# 7                                     .bounceexchange.com
# 8                                           .facebook.com
# ...                                                   ...
# 280806  https://assets.adobedtm.com/7a8a98de0363fbed05...
# 280807  https://assets.adobedtm.com/7a8a98de0363fbed05...
# 280809  https://assets.adobedtm.com/7a8a98de0363fbed05...
# 280810  https://assets.adobedtm.com/7a8a98de0363fbed05...
# 280811  https://assets.adobedtm.com/7a8a98de0363fbed05...
#
#                          name  \
# 0                        MUID
# 3                      demdex
# 6                        TDID
# 7       bounceClientVisit340c
# 8                          fr
# ...                       ...
# 280806            s_lastvisit
# 280807          s_lastvisit_s
# 280809                gpv_c32
# 280810                 gpv_pn
# 280811              kiwi_sess
#
#                                                     value  \
# 0                        23271CC522FB698D03CA127823796817
# 3                  41716664660881085583464462140903477176
# 6                    35549598-c1d5-4c6f-b6a9-61f2f82d6295
# 7       %7B%22vid%22%3A1588340781117590%2C%22did%22%3A...
# 8                 00uvqGJITlYgeR16V..BerCgt...1.0.BerCgt.
# ...                                                   ...
# 280806                                      1588342528058
# 280807                                      First%20Visit
# 280809                                          bigfuture
# 280810                      bigfuture%2Fget-in%2Fapplying
# 280811  {"user":{},"prev":{"siteCode":"","pageName":""...
#
#                       time_stamp              type          vname
# 0       2020-05-01T13:46:19.911Z  added-or-changed            cnn
# 3       2020-05-01T13:46:20.214Z  added-or-changed            cnn
# 6       2020-05-01T13:46:21.004Z  added-or-changed            cnn
# 7       2020-05-01T13:46:21.146Z  added-or-changed            cnn
# 8       2020-05-01T13:46:21.207Z  added-or-changed            cnn
# ...                          ...               ...            ...
# 280806  2020-05-01T14:15:28.283Z               get  colledgeboard
# 280807  2020-05-01T14:15:28.283Z               get  colledgeboard
# 280809  2020-05-01T14:15:28.283Z               get  colledgeboard
# 280810  2020-05-01T14:15:28.283Z               get  colledgeboard
# 280811  2020-05-01T14:15:28.283Z               get  colledgeboard
#
# [198045 rows x 8 columns]

# %%
unique_huge['namevalue'] = list(map(lambda a, b: (a, b), unique_huge["name"].astype(str), unique_huge["value"].astype(str)))

# %%
byoccur = unique_huge.groupby(["namevalue", "context_id"], as_index = False)['time_stamp'].count()
byoccur
#temp2.to_csv("unique_namevalue-3.csv", index=False)
# Out:
#                                               namevalue  context_id  \
# 0                                       (107, 20200501)           1
# 1                                       (108, 20200501)           1
# 2                                       (110, 20200501)           1
# 3                                       (112, 20200501)           1
# 4                                       (113, 20200501)           1
# ...                                                 ...         ...
# 1984  (yieldmo_id, gfbadb6bd95b3901ea14%7C1588340794...           1
# 1985                       (zuid, NJppPAXpgjXfYmXTpDZ7)           1
# 1986                       (zuid, TM6LMxYK3kC19y2AVTom)           1
# 1987                       (zuid, TM6LMxYK3kC19y2AVTom)           2
# 1988  (zync-uuid, 8d68cac9-9a8f-4e94-8ce4-c869ce9fdf...           1
#
#       time_stamp
# 0              5
# 1              4
# 2              3
# 3              2
# 4              9
# ...          ...
# 1984           3
# 1985           7
# 1986          16
# 1987           6
# 1988           5
#
# [1989 rows x 3 columns]

# %%
# clean host domain 
temp = list(map(lambda x:".".join(x.split(".")[:2]).replace('https://','').replace('www',''), unique_huge['host'].tolist()))                    
len(temp)
unique_huge['host_clean'] = temp

# %%
byvisit = pd.DataFrame(unique_huge.groupby(["namevalue", "context_id"], as_index = False)['vname'].apply(set).reset_index(name='byvname'))
byvisit
# Out:
#                                               namevalue  context_id  \
# 0                                       (107, 20200501)           1
# 1                                       (108, 20200501)           1
# 2                                       (110, 20200501)           1
# 3                                       (112, 20200501)           1
# 4                                       (113, 20200501)           1
# ...                                                 ...         ...
# 1984  (yieldmo_id, gfbadb6bd95b3901ea14%7C1588340794...           1
# 1985                       (zuid, NJppPAXpgjXfYmXTpDZ7)           1
# 1986                       (zuid, TM6LMxYK3kC19y2AVTom)           1
# 1987                       (zuid, TM6LMxYK3kC19y2AVTom)           2
# 1988  (zync-uuid, 8d68cac9-9a8f-4e94-8ce4-c869ce9fdf...           1
#
#                                   byvname
# 0                           {theguardian}
# 1                           {theguardian}
# 2                           {theguardian}
# 3                           {theguardian}
# 4     {theguardian, forbes, nytimes, cnn}
# ...                                   ...
# 1984                                {cnn}
# 1985                   {theguardian, cnn}
# 1986                             {forbes}
# 1987                              {webmd}
# 1988                             {forbes}
#
# [1989 rows x 3 columns]

# %%
# byhost = pd.DataFrame(unique_huge.groupby(["namevalue", "context_id"], as_index = False)['host_clean'].apply(list))
byhost = pd.DataFrame(unique_huge.groupby(["namevalue", "context_id"], as_index = False)['host_clean'].apply(set).reset_index(name='byhost'))
byhost
# Out:
#                                               namevalue  context_id  \
# 0                                       (107, 20200501)           1
# 1                                       (108, 20200501)           1
# 2                                       (110, 20200501)           1
# 3                                       (112, 20200501)           1
# 4                                       (113, 20200501)           1
# ...                                                 ...         ...
# 1984  (yieldmo_id, gfbadb6bd95b3901ea14%7C1588340794...           1
# 1985                       (zuid, NJppPAXpgjXfYmXTpDZ7)           1
# 1986                       (zuid, TM6LMxYK3kC19y2AVTom)           1
# 1987                       (zuid, TM6LMxYK3kC19y2AVTom)           2
# 1988  (zync-uuid, 8d68cac9-9a8f-4e94-8ce4-c869ce9fdf...           1
#
#                                byhost
# 0     {match.deepintent, .deepintent}
# 1     {match.deepintent, .deepintent}
# 2     {match.deepintent, .deepintent}
# 3     {match.deepintent, .deepintent}
# 4     {match.deepintent, .deepintent}
# ...                               ...
# 1984          {.yieldmo, ads.yieldmo}
# 1985       {b1sync.zemanta, .zemanta}
# 1986       {b1sync.zemanta, .zemanta}
# 1987       {b1sync.zemanta, .zemanta}
# 1988           {live.rezync, .rezync}
#
# [1989 rows x 3 columns]

# %%
highlight = pd.merge(byoccur, byhost, on=['namevalue',  'context_id'])
highlight = pd.merge(highlight, byvisit, on=['namevalue',  'context_id'])
highlight
# Out:
#                                               namevalue  context_id  \
# 0                                       (107, 20200501)           1
# 1                                       (108, 20200501)           1
# 2                                       (110, 20200501)           1
# 3                                       (112, 20200501)           1
# 4                                       (113, 20200501)           1
# ...                                                 ...         ...
# 1984  (yieldmo_id, gfbadb6bd95b3901ea14%7C1588340794...           1
# 1985                       (zuid, NJppPAXpgjXfYmXTpDZ7)           1
# 1986                       (zuid, TM6LMxYK3kC19y2AVTom)           1
# 1987                       (zuid, TM6LMxYK3kC19y2AVTom)           2
# 1988  (zync-uuid, 8d68cac9-9a8f-4e94-8ce4-c869ce9fdf...           1
#
#       time_stamp                           byhost  \
# 0              5  {match.deepintent, .deepintent}
# 1              4  {match.deepintent, .deepintent}
# 2              3  {match.deepintent, .deepintent}
# 3              2  {match.deepintent, .deepintent}
# 4              9  {match.deepintent, .deepintent}
# ...          ...                              ...
# 1984           3          {.yieldmo, ads.yieldmo}
# 1985           7       {b1sync.zemanta, .zemanta}
# 1986          16       {b1sync.zemanta, .zemanta}
# 1987           6       {b1sync.zemanta, .zemanta}
# 1988           5           {live.rezync, .rezync}
#
#                                   byvname
# 0                           {theguardian}
# 1                           {theguardian}
# 2                           {theguardian}
# 3                           {theguardian}
# 4     {theguardian, forbes, nytimes, cnn}
# ...                                   ...
# 1984                                {cnn}
# 1985                   {theguardian, cnn}
# 1986                             {forbes}
# 1987                              {webmd}
# 1988                             {forbes}
#
# [1989 rows x 5 columns]

# %%
# select only across contexts
ltd = []
Counter = collections.Counter(highlight.namevalue.tolist())

# %%
for key, value in Counter.items():
    if value == 1:
        ltd.append(key)

# %%
indtd = highlight[highlight['namevalue'].isin(ltd)].index
highlight.drop(indtd, inplace=True)
highlight
# Out:
#                                               namevalue  context_id  \
# 6                                       (131, 20200501)           1
# 7                                       (131, 20200501)           2
# 11    (A3, d=AQABBBoqrF4CEPdY3jmf7y0lqIos6X6BvLMFEgE...           1
# 12    (A3, d=AQABBBoqrF4CEPdY3jmf7y0lqIos6X6BvLMFEgE...           2
# 16    (A3, d=AQABBPcsrF4CENuOO3pHfRbNXEYpdY8MhvEFEgE...           2
# ...                                                 ...         ...
# 1965               (visitor-id, 2313428786589727000V10)           2
# 1973                      (wfivefivec, 4FlCNvXw1Juw7K5)           1
# 1974                      (wfivefivec, 4FlCNvXw1Juw7K5)           2
# 1986                       (zuid, TM6LMxYK3kC19y2AVTom)           1
# 1987                       (zuid, TM6LMxYK3kC19y2AVTom)           2
#
#       time_stamp                                             byhost  \
# 6              8                    {match.deepintent, .deepintent}
# 7              1                                      {.deepintent}
# 11            37  {pr-bh.ybp, cookiex.ngd, cms.analytics, beap-b...
# 12            22      {ads.yahoo, pr-bh.ybp, ups.analytics, .yahoo}
# 16             9               {cookiex.ngd, beap-bc.yahoo, .yahoo}
# ...          ...                                                ...
# 1965         139  {hbxlp.media, hbx.media, lgncal.media, context...
# 1973          13                           {.w55c, pm.w55c, i.w55c}
# 1974           3                                   {.w55c, pm.w55c}
# 1986          16                         {b1sync.zemanta, .zemanta}
# 1987           6                         {b1sync.zemanta, .zemanta}
#
#                              byvname
# 6     {theguardian, forbes, nytimes}
# 7                         {medscape}
# 11          {forbes, washingtonpost}
# 12                           {webmd}
# 16          {myfitnesspal, medscape}
# ...                              ...
# 1965                         {webmd}
# 1973                        {forbes}
# 1974                         {webmd}
# 1986                        {forbes}
# 1987                         {webmd}
#
# [272 rows x 5 columns]

# %%
highlight.to_csv("../sankey/sankey-name-{}.csv".format(exp_num), index=False)
