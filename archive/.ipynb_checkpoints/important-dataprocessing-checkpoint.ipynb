# %%
import numpy as np
import pandas as pd
import sqlite3

# %%
exp_number = 1

# %%
exp_path = "./raw-data/exp"+str(exp_number)+"/crawl-data.sqlite"
exp_path
# Out:
# './raw-data/exp1/crawl-data.sqlite'

# %%
conn = sqlite3.connect(exp_path)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-4-bfd3a5c0a682> in <module>()
# ----> 1 conn = sqlite3.connect(exp_path)
#
# OperationalError: unable to open database file

# %%
javascript_cookies = pd.read_sql_query("select visit_id, record_type, change_cause, host, name, value, time_stamp from javascript_cookies;", conn)
http_responses = pd.read_sql_query("select visit_id, url, method, headers, time_stamp from http_responses where response_status == 200;", conn)
http_requests = pd.read_sql_query("select visit_id, headers, referrer, Url, time_stamp from http_requests;", conn)
javascript = pd.read_sql_query("select visit_id, script_url, symbol, operation, value, arguments, time_stamp from javascript;", conn)
site_visits = pd.read_sql_query("select visit_id, site_url from site_visits;", conn)

# %%
conn.close()

# %%
site_visits
# Out:
#     visit_id                                           site_url
# 0          1                            http://www.nytimes.com/
# 1          2           https://www.nytimes.com/section/business
# 2          3  https://www.nytimes.com/2020/04/26/business/ca...
# 3          4             https://www.nytimes.com/section/health
# 4          5  https://www.nytimes.com/2020/04/21/business/sp...
# 5          6                             https://www.webmd.com/
# 6          7             https://www.webmd.com/baby/default.htm
# 7          8  https://www.webmd.com/skin-problems-and-treatm...
# 8          9             https://www.webmd.com/lung/coronavirus
# 9         10                https://www.webmd.com/drugs/2/index
# 10        11                          https://www.berkeley.edu/
# 11        12                     http://diversity.berkeley.edu/
# 12        13  https://www.berkeley.edu/about/history-discove...
# 13        14                 https://www.berkeley.edu/directory
# 14        15  https://engineering.berkeley.edu/engineering-f...

# %%
names = list(map(lambda x: x.split('.')[1], list(site_visits.site_url)))
websites = list( names[i] for i in [0,5,10])
websites
# Out:
# ['nytimes', 'webmd', 'berkeley']

# %%
context_number = 1

# %%
############################# cookies #############################

# %%
js_cookies = javascript_cookies[javascript_cookies.visit_id.isin(range(context_number*5+1, context_number*5+6))]
js_cookies
# Out:
#       visit_id       record_type change_cause  \
# 1540        11  added-or-changed     explicit
# 1541        11  added-or-changed     explicit
# 1542        11  added-or-changed     explicit
# 1543        11  added-or-changed     explicit
# 1544        11  added-or-changed     explicit
# 1545        11           deleted    overwrite
# 1546        11  added-or-changed     explicit
# 1547        11  added-or-changed     explicit
# 1548        11  added-or-changed     explicit
# 1549        11  added-or-changed     explicit
# 1550        11           deleted    overwrite
# 1551        11  added-or-changed     explicit
# 1552        11           deleted    overwrite
# 1553        11  added-or-changed     explicit
# 1554        11           deleted    overwrite
# 1555        11  added-or-changed     explicit
# 1556        11  added-or-changed     explicit
# 1557        11  added-or-changed     explicit
# 1558        11  added-or-changed     explicit
# 1559        11  added-or-changed     explicit
# 1560        11           deleted    overwrite
# 1561        11  added-or-changed     explicit
# 1562        11           deleted    overwrite
# 1563        11  added-or-changed     explicit
# 1564        11           deleted    overwrite
# 1565        11  added-or-changed     explicit
# 1566        11           deleted     explicit
# 1567        11  added-or-changed     explicit
# 1568        12  added-or-changed     explicit
# 1569        12  added-or-changed     explicit
# ...        ...               ...          ...
# 1616        13  added-or-changed     explicit
# 1617        13           deleted    overwrite
# 1618        13  added-or-changed     explicit
# 1619        13           deleted    overwrite
# 1620        13  added-or-changed     explicit
# 1621        13           deleted    overwrite
# 1622        13  added-or-changed     explicit
# 1623        13           deleted    overwrite
# 1624        13  added-or-changed     explicit
# 1625        13           deleted    overwrite
# 1626        13  added-or-changed     explicit
# 1627        13           deleted    overwrite
# 1628        13  added-or-changed     explicit
# 1629        13           deleted    overwrite
# 1630        13  added-or-changed     explicit
# 1631        13           deleted    overwrite
# 1632        13  added-or-changed     explicit
# 1633        13           deleted    overwrite
# 1634        13  added-or-changed     explicit
# 1635        14           deleted    overwrite
# 1636        14  added-or-changed     explicit
# 1637        14           deleted    overwrite
# 1638        14  added-or-changed     explicit
# 1639        14           deleted      expired
# 1640        14  added-or-changed     explicit
# 1641        15  added-or-changed     explicit
# 1642        15  added-or-changed     explicit
# 1643        15  added-or-changed     explicit
# 1644        15  added-or-changed     explicit
# 1645        15  added-or-changed     explicit
#
#                                      host                      name  \
# 1540                        .berkeley.edu                    __utma
# 1541                        .berkeley.edu                    __utmb
# 1542                        .berkeley.edu                    __utmc
# 1543                        .berkeley.edu                    __utmz
# 1544                        .berkeley.edu                    __utmt
# 1545                        .berkeley.edu                    __utmb
# 1546                        .berkeley.edu                    __utmb
# 1547                    .www.berkeley.edu                    nmstat
# 1548  8343.global.siteimproveanalytics.io            siteimproveses
# 1549  8343.global.siteimproveanalytics.io                    AWSELB
# 1550                        .berkeley.edu                    __utma
# 1551                        .berkeley.edu                    __utma
# 1552                        .berkeley.edu                    __utmb
# 1553                        .berkeley.edu                    __utmb
# 1554                        .berkeley.edu                    __utmz
# 1555                        .berkeley.edu                    __utmz
# 1556                     www.berkeley.edu     GATEWAY_EE_last_visit
# 1557                     www.berkeley.edu  GATEWAY_EE_last_activity
# 1558                     www.berkeley.edu        GATEWAY_EE_tracker
# 1559                     www.berkeley.edu     GATEWAY_EE_csrf_token
# 1560                     www.berkeley.edu     GATEWAY_EE_last_visit
# 1561                     www.berkeley.edu     GATEWAY_EE_last_visit
# 1562                     www.berkeley.edu  GATEWAY_EE_last_activity
# 1563                     www.berkeley.edu  GATEWAY_EE_last_activity
# 1564                     www.berkeley.edu        GATEWAY_EE_tracker
# 1565                     www.berkeley.edu        GATEWAY_EE_tracker
# 1566                     www.berkeley.edu     GATEWAY_EE_csrf_token
# 1567                     www.berkeley.edu     GATEWAY_EE_csrf_token
# 1568               diversity.berkeley.edu                    has_js
# 1569                        .berkeley.edu                       _ga
# ...                                   ...                       ...
# 1616                         .youtube.com        VISITOR_INFO1_LIVE
# 1617                         .youtube.com                       YSC
# 1618                         .youtube.com                       YSC
# 1619                         .youtube.com        VISITOR_INFO1_LIVE
# 1620                         .youtube.com        VISITOR_INFO1_LIVE
# 1621                         .youtube.com                       YSC
# 1622                         .youtube.com                       YSC
# 1623                         .youtube.com        VISITOR_INFO1_LIVE
# 1643  2020-04-28T14:17:39.460Z
# 1644  2020-04-28T14:17:39.485Z
# 1645  2020-04-28T14:17:39.851Z
#
# [106 rows x 7 columns]

# %%
# js_cookies.host.unique()

# %%
cookies_dict = {
  "nytimes": 'nytimes|nyt',
  "webmd": 'webmd',
  "berkeley": 'berkeley'
}

# %%
# pattern = cookies_dict.get(websites[context_number])
# pattern

# first party cookies (filter by host)
js_cookies_first = js_cookies[js_cookies.host.str.contains(cookies_dict.get(websites[context_number]))]

# third party cookies (filter by host)
js_cookies_third = js_cookies[~js_cookies.host.str.contains(cookies_dict.get(websites[context_number]))]

# print(js_cookies_first.shape)
# print(js_cookies_third.shape)

# %%
# js_cookies_first.to_csv('1-'+str(context_number+1)+'-FirstCookies.csv', index=False)

# %%
js_cookies_third['context_id'] = context_number+1
js_cookies_third.to_csv('1-'+str(context_number+1)+'-ThirdCookies.csv', index=False)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
# concat big cookies

# js_cookies_third['context_id'] = 3
# temp = js_cookies_third
# temp = temp.append(js_cookies_third)
# temp

# %%
# temp.to_csv('1-ThirdCookies.csv', index=False)

# %%
############################# JS #############################

# %%
js = javascript[javascript.visit_id.isin(range(context_number*5+1, context_number*5+6))]

# %%
# third party js (filter by script_url)
temp = list(map(lambda x:x[1], js['script_url'].str.split(".")))
js['temp'] = temp

js
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#        visit_id                                         script_url  \
# 25242        11                 https://use.typekit.net/zpy2xov.js
# 25243        11                 https://use.typekit.net/zpy2xov.js
# 25244        11                 https://use.typekit.net/zpy2xov.js
# 25245        11  https://siteimproveanalytics.com/js/siteanalyz...
# 25246        11  https://siteimproveanalytics.com/js/siteanalyz...
# ...         ...                                                ...
# 27343        15  https://siteimproveanalytics.com/js/siteanalyz...
# 27344        15  https://siteimproveanalytics.com/js/siteanalyz...
# 27345        15  https://siteimproveanalytics.com/js/siteanalyz...
# 27346        15  https://siteimproveanalytics.com/js/siteanalyz...
# 27347        15  https://siteimproveanalytics.com/js/siteanalyz...
#
#                            symbol operation  \
# 25242  window.navigator.userAgent       get
# 25243  window.navigator.userAgent       get
# 25244  window.navigator.userAgent       get
# 25245    window.document.referrer       get
# 25246    window.document.referrer       get
# ...                           ...       ...
# 27343      window.document.cookie       get
# 27344      window.document.cookie       get
# 27345      window.document.cookie       get
# 27346      window.document.cookie       get
# 27347      window.document.cookie       set
#
#                                                    value arguments  \
# 25242  Mozilla/5.0 (X11; Linux x86_64; rv:72.0) Gecko...      None
# 25243  Mozilla/5.0 (X11; Linux x86_64; rv:72.0) Gecko...      None
# 25244  Mozilla/5.0 (X11; Linux x86_64; rv:72.0) Gecko...      None
# 25245                                                         None
# 25246                                                         None
# ...                                                  ...       ...
# 27343  __utmc=41573937; __utmt=1; __utma=41573937.991...      None
# 27344  __utmc=41573937; __utmt=1; __utma=41573937.991...      None
# 27345  __utmc=41573937; __utmt=1; __utma=41573937.991...      None
# 27346  __utmc=41573937; __utmt=1; __utma=41573937.991...      None
# 27347  nmstat=1588083484512; expires=Mon, 23 Jan 2023...      None
#
#                      time_stamp                     temp
# 25242  2020-04-28T14:15:45.892Z                  typekit
# 25243  2020-04-28T14:15:46.985Z                  typekit
# 25244  2020-04-28T14:15:46.986Z                  typekit
# 25245  2020-04-28T14:15:46.986Z  com/js/siteanalyze_8343
# 25246  2020-04-28T14:15:46.988Z  com/js/siteanalyze_8343
# ...                         ...                      ...
# 27343  2020-04-28T14:17:39.961Z  com/js/siteanalyze_8343
# 27344  2020-04-28T14:17:39.965Z  com/js/siteanalyze_8343
# 27345  2020-04-28T14:17:39.965Z  com/js/siteanalyze_8343
# 27346  2020-04-28T14:17:39.965Z  com/js/siteanalyze_8343
# 27347  2020-04-28T14:17:39.966Z  com/js/siteanalyze_8343
#
# [2106 rows x 8 columns]

# %%
# js.script_url.unique()

# %%
# list(map(lambda x: x.split('.')[1], list(js.script_url)))

# %%
# third party  (filter by script_url)
js_third = js[~js.script_url.str.contains(cookies_dict.get(websites[context_number]))]
js_third
# Out:
#        visit_id                                         script_url  \
# 25242        11                 https://use.typekit.net/zpy2xov.js
# 25243        11                 https://use.typekit.net/zpy2xov.js
# 25244        11                 https://use.typekit.net/zpy2xov.js
# 25245        11  https://siteimproveanalytics.com/js/siteanalyz...
# 25246        11  https://siteimproveanalytics.com/js/siteanalyz...
# ...         ...                                                ...
# 27343        15  https://siteimproveanalytics.com/js/siteanalyz...
# 27344        15  https://siteimproveanalytics.com/js/siteanalyz...
# 27345        15  https://siteimproveanalytics.com/js/siteanalyz...
# 27346        15  https://siteimproveanalytics.com/js/siteanalyz...
# 27347        15  https://siteimproveanalytics.com/js/siteanalyz...
#
#                            symbol operation  \
# 25242  window.navigator.userAgent       get
# 25243  window.navigator.userAgent       get
# 25244  window.navigator.userAgent       get
# 25245    window.document.referrer       get
# 25246    window.document.referrer       get
# ...                           ...       ...
# 27343      window.document.cookie       get
# 27344      window.document.cookie       get
# 27345      window.document.cookie       get
# 27346      window.document.cookie       get
# 27347      window.document.cookie       set
#
#                                                    value arguments  \
# 25242  Mozilla/5.0 (X11; Linux x86_64; rv:72.0) Gecko...      None
# 25243  Mozilla/5.0 (X11; Linux x86_64; rv:72.0) Gecko...      None
# 25244  Mozilla/5.0 (X11; Linux x86_64; rv:72.0) Gecko...      None
# 25245                                                         None
# 25246                                                         None
# ...                                                  ...       ...
# 27343  __utmc=41573937; __utmt=1; __utma=41573937.991...      None
# 27344  __utmc=41573937; __utmt=1; __utma=41573937.991...      None
# 27345  __utmc=41573937; __utmt=1; __utma=41573937.991...      None
# 27346  __utmc=41573937; __utmt=1; __utma=41573937.991...      None
# 27347  nmstat=1588083484512; expires=Mon, 23 Jan 2023...      None
#
#                      time_stamp                     temp
# 25242  2020-04-28T14:15:45.892Z                  typekit
# 25243  2020-04-28T14:15:46.985Z                  typekit
# 25244  2020-04-28T14:15:46.986Z                  typekit
# 25245  2020-04-28T14:15:46.986Z  com/js/siteanalyze_8343
# 25246  2020-04-28T14:15:46.988Z  com/js/siteanalyze_8343
# ...                         ...                      ...
# 27343  2020-04-28T14:17:39.961Z  com/js/siteanalyze_8343
# 27344  2020-04-28T14:17:39.965Z  com/js/siteanalyze_8343
# 27345  2020-04-28T14:17:39.965Z  com/js/siteanalyze_8343
# 27346  2020-04-28T14:17:39.965Z  com/js/siteanalyze_8343
# 27347  2020-04-28T14:17:39.966Z  com/js/siteanalyze_8343
#
# [2047 rows x 8 columns]

# %%
js_third['context_id'] = context_number+1


js_third.to_csv('1-'+str(context_number+1)+'-js.csv', index=False)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
############################# HTTP REQUEST #############################

# %%
def get_host_from_headers(x):
    temp = x.replace('"','').split('],[')
    for t in temp:
            pair = t.replace(']]','').replace('[[','').split(',')
            if "Host" in pair:
                host_value = pair[1]
    return host_value

def get_cookies_from_headers(x):
    ls = x.replace('"','').split('],[')
    for l in ls:
        ta = l.replace(']]','').split(',')
        if "Cookie" in ta:
            return ta[-1]
    return ''

# %%
temp = list(map(lambda x: get_host_from_headers(x), http_requests.headers.tolist()))

http_requests["host"] = temp


http_req_cookies = list(map(lambda x: get_cookies_from_headers(x), http_requests.headers.tolist()))

http_requests["cookies"] = http_req_cookies

http_requests
# Out:
#       visit_id                                            headers  \
# 0            1  [["Host","www.nytimes.com"],["User-Agent","Moz...
# 1            1  [["Host","www.nytimes.com"],["User-Agent","Moz...
# 2            1  [["Host","g1.nyt.com"],["User-Agent","Mozilla/...
# 3            1  [["Host","www.nytimes.com"],["User-Agent","Moz...
# 4            1  [["Host","www.nytimes.com"],["User-Agent","Moz...
# ...        ...                                                ...
# 3724        15  [["Host","use.typekit.net"],["User-Agent","Moz...
# 3725        15  [["Host","use.typekit.net"],["User-Agent","Moz...
# 3726        15  [["Host","use.typekit.net"],["User-Agent","Moz...
# 3727        15  [["Host","use.typekit.net"],["User-Agent","Moz...
# 3728        15  [["Host","8343.global.siteimproveanalytics.io"...
#
#                                                referrer  \
# 0
# 1
# 2                              https://www.nytimes.com/
# 3                              https://www.nytimes.com/
# 4                              https://www.nytimes.com/
# ...                                                 ...
# 3724  https://engineering.berkeley.edu/engineering-f...
# 3725  https://engineering.berkeley.edu/engineering-f...
# 3726  https://engineering.berkeley.edu/engineering-f...
# 3727  https://engineering.berkeley.edu/engineering-f...
# 3728  https://engineering.berkeley.edu/engineering-f...
#
#                                                     url  \
# 0                               http://www.nytimes.com/
# 1                              https://www.nytimes.com/
# 2     https://g1.nyt.com/fonts/css/web-fonts.5810def...
# 3     https://www.nytimes.com/vi-assets/static-asset...
# 4     https://www.nytimes.com/vi-assets/static-asset...
# ...                                                 ...
# 3724  https://use.typekit.net/af/442215/000000000000...
# 3725  https://use.typekit.net/af/cef9f3/000000000000...
# 3726  https://use.typekit.net/af/c1b4f7/000000000000...
# 3727  https://use.typekit.net/af/1709eb/000000000000...
# 3728  https://8343.global.siteimproveanalytics.io/im...
#
#                     time_stamp                                 host  \
# 0     2020-04-28T14:10:29.517Z                      www.nytimes.com
# 1     2020-04-28T14:10:29.566Z                      www.nytimes.com
# 2     2020-04-28T14:10:29.697Z                           g1.nyt.com
# 3     2020-04-28T14:10:29.697Z                      www.nytimes.com
# 4     2020-04-28T14:10:29.737Z                      www.nytimes.com
# ...                        ...                                  ...
# 3724  2020-04-28T14:17:39.689Z                      use.typekit.net
# 3725  2020-04-28T14:17:39.689Z                      use.typekit.net
# 3726  2020-04-28T14:17:39.689Z                      use.typekit.net
# 3727  2020-04-28T14:17:39.689Z                      use.typekit.net
# 3728  2020-04-28T14:17:39.996Z  8343.global.siteimproveanalytics.io
#
#                                                 cookies
# 0
# 1                                nyt-gdpr=0; nyt-geo=US
# 2
# 3     nyt-gdpr=0; nyt-geo=US; nyt-a=4Oe53a4sDRVl1-qj...
# 4     nyt-gdpr=0; nyt-geo=US; nyt-a=4Oe53a4sDRVl1-qj...
# ...                                                 ...
# 3724
# 3725
# 3726
# 3727
# 3728  siteimproveses=cfa01349-7863-434e-8687-71121d7...
#
# [3729 rows x 7 columns]

# %%
hr = http_requests[http_requests.visit_id.isin(range(context_number*5+1, context_number*5+6))]

temp = list(map(lambda x:x[-2], hr['host'].str.split(".")))
hr['temp'] = temp

hr
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
#       visit_id                                            headers  \
# 3053        11  [["Host","ade.googlesyndication.com"],["User-A...
# 3054        11  [["Host","pagead2.googlesyndication.com"],["Us...
# 3055        11  [["Host","pagead2.googlesyndication.com"],["Us...
# 3056        11  [["Host","ade.googlesyndication.com"],["User-A...
# 3057        11  [["Host","pagead2.googlesyndication.com"],["Us...
# ...        ...                                                ...
# 3724        15  [["Host","use.typekit.net"],["User-Agent","Moz...
# 3725        15  [["Host","use.typekit.net"],["User-Agent","Moz...
# 3726        15  [["Host","use.typekit.net"],["User-Agent","Moz...
# 3727        15  [["Host","use.typekit.net"],["User-Agent","Moz...
# 3728        15  [["Host","8343.global.siteimproveanalytics.io"...
#
#                                                referrer  \
# 3053                https://www.webmd.com/drugs/2/index
# 3054                https://www.webmd.com/drugs/2/index
# 3055                https://www.webmd.com/drugs/2/index
# 3056                https://www.webmd.com/drugs/2/index
# 3057                https://www.webmd.com/drugs/2/index
# ...                                                 ...
# 3724  https://engineering.berkeley.edu/engineering-f...
# 3725  https://engineering.berkeley.edu/engineering-f...
# 3726  https://engineering.berkeley.edu/engineering-f...
# 3727  https://engineering.berkeley.edu/engineering-f...
# 3728  https://engineering.berkeley.edu/engineering-f...
#
#                                                     url  \
# 3053  https://ade.googlesyndication.com/ddm/activity...
# 3054  https://pagead2.googlesyndication.com/pcs/acti...
# 3055  https://pagead2.googlesyndication.com/pcs/acti...
# 3056  https://ade.googlesyndication.com/ddm/activity...
# 3057  https://pagead2.googlesyndication.com/pcs/acti...
# ...                                                 ...
# 3724  https://use.typekit.net/af/442215/000000000000...
# 3725  https://use.typekit.net/af/cef9f3/000000000000...
# 3726  https://use.typekit.net/af/c1b4f7/000000000000...
# 3727  https://use.typekit.net/af/1709eb/000000000000...
# 3728  https://8343.global.siteimproveanalytics.io/im...
#
#                     time_stamp                                 host  \
# 3053  2020-04-28T14:15:43.440Z            ade.googlesyndication.com
# 3054  2020-04-28T14:15:43.441Z        pagead2.googlesyndication.com
# 3055  2020-04-28T14:15:43.441Z        pagead2.googlesyndication.com
# 3056  2020-04-28T14:15:43.442Z            ade.googlesyndication.com
# 3057  2020-04-28T14:15:43.443Z        pagead2.googlesyndication.com
# ...                        ...                                  ...
# 3724  2020-04-28T14:17:39.689Z                      use.typekit.net
# 3725  2020-04-28T14:17:39.689Z                      use.typekit.net
# 3726  2020-04-28T14:17:39.689Z                      use.typekit.net
# 3727  2020-04-28T14:17:39.689Z                      use.typekit.net
# 3728  2020-04-28T14:17:39.996Z  8343.global.siteimproveanalytics.io
#
#                                                 cookies                  temp
# 3053                                                        googlesyndication
# 3054                                                        googlesyndication
# 3055                                                        googlesyndication
# 3056                                                        googlesyndication
# 3057                                                        googlesyndication
# ...                                                 ...                   ...
# 3724                                                                  typekit
# 3725                                                                  typekit
# 3726                                                                  typekit
# 3727                                                                  typekit
# 3728  siteimproveses=cfa01349-7863-434e-8687-71121d7...  siteimproveanalytics
#
# [676 rows x 8 columns]

# %%
# third party  (filter by script_url)
hr_third = hr[~hr.temp.str.contains(cookies_dict.get(websites[context_number]))]
hr_third
# Out:
#       visit_id                                            headers  \
# 3053        11  [["Host","ade.googlesyndication.com"],["User-A...
# 3054        11  [["Host","pagead2.googlesyndication.com"],["Us...
# 3055        11  [["Host","pagead2.googlesyndication.com"],["Us...
# 3056        11  [["Host","ade.googlesyndication.com"],["User-A...
# 3057        11  [["Host","pagead2.googlesyndication.com"],["Us...
# ...        ...                                                ...
# 3724        15  [["Host","use.typekit.net"],["User-Agent","Moz...
# 3725        15  [["Host","use.typekit.net"],["User-Agent","Moz...
# 3726        15  [["Host","use.typekit.net"],["User-Agent","Moz...
# 3727        15  [["Host","use.typekit.net"],["User-Agent","Moz...
# 3728        15  [["Host","8343.global.siteimproveanalytics.io"...
#
#                                                referrer  \
# 3053                https://www.webmd.com/drugs/2/index
# 3054                https://www.webmd.com/drugs/2/index
# 3055                https://www.webmd.com/drugs/2/index
# 3056                https://www.webmd.com/drugs/2/index
# 3057                https://www.webmd.com/drugs/2/index
# ...                                                 ...
# 3724  https://engineering.berkeley.edu/engineering-f...
# 3725  https://engineering.berkeley.edu/engineering-f...
# 3726  https://engineering.berkeley.edu/engineering-f...
# 3727  https://engineering.berkeley.edu/engineering-f...
# 3728  https://engineering.berkeley.edu/engineering-f...
#
#                                                     url  \
# 3053  https://ade.googlesyndication.com/ddm/activity...
# 3054  https://pagead2.googlesyndication.com/pcs/acti...
# 3055  https://pagead2.googlesyndication.com/pcs/acti...
# 3056  https://ade.googlesyndication.com/ddm/activity...
# 3057  https://pagead2.googlesyndication.com/pcs/acti...
# ...                                                 ...
# 3724  https://use.typekit.net/af/442215/000000000000...
# 3725  https://use.typekit.net/af/cef9f3/000000000000...
# 3726  https://use.typekit.net/af/c1b4f7/000000000000...
# 3727  https://use.typekit.net/af/1709eb/000000000000...
# 3728  https://8343.global.siteimproveanalytics.io/im...
#
#                     time_stamp                                 host  \
# 3053  2020-04-28T14:15:43.440Z            ade.googlesyndication.com
# 3054  2020-04-28T14:15:43.441Z        pagead2.googlesyndication.com
# 3055  2020-04-28T14:15:43.441Z        pagead2.googlesyndication.com
# 3056  2020-04-28T14:15:43.442Z            ade.googlesyndication.com
# 3057  2020-04-28T14:15:43.443Z        pagead2.googlesyndication.com
# ...                        ...                                  ...
# 3724  2020-04-28T14:17:39.689Z                      use.typekit.net
# 3725  2020-04-28T14:17:39.689Z                      use.typekit.net
# 3726  2020-04-28T14:17:39.689Z                      use.typekit.net
# 3727  2020-04-28T14:17:39.689Z                      use.typekit.net
# 3728  2020-04-28T14:17:39.996Z  8343.global.siteimproveanalytics.io
#
#                                                 cookies                  temp
# 3053                                                        googlesyndication
# 3054                                                        googlesyndication
# 3055                                                        googlesyndication
# 3056                                                        googlesyndication
# 3057                                                        googlesyndication
# ...                                                 ...                   ...
# 3724                                                                  typekit
# 3725                                                                  typekit
# 3726                                                                  typekit
# 3727                                                                  typekit
# 3728  siteimproveses=cfa01349-7863-434e-8687-71121d7...  siteimproveanalytics
#
# [261 rows x 8 columns]

# %%
hr_third['context_id'] = context_number+1

hr_third.to_csv('1-'+str(context_number+1)+'-httprequest.csv', index=False)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
# experiments_df = pd.DataFrame(pd.read_csv('experiments.csv')  , columns = ['Exp', 'Websites']) 
# experiments_df

# %%
# experiment_num = 1

# temp = pd.DataFrame([[experiment_num, names]], columns = ['Exp', 'Websites']) 

# experiments_df = pd.concat([experiments_df,temp])

# experiments_df

# %%
# experiments_df.to_csv('experiments.csv', index=False)
