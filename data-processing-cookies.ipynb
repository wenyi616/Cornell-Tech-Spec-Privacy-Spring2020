# %%
import numpy as np
import pandas as pd
import math

# %%
# cookies (set/change httpresponce, js)

cookies = pd.read_csv("./tables/1-3-cookies.csv")
httprequests = pd.read_csv("./tables/1-3-httprequest.csv")
js = pd.read_csv("./tables/1-3-js.csv")

# %%
set_cookies = cookies[["visit_id", "name", "value", "time_stamp"]]

# %%
# set cookies
set_cookies["type"] = ["set"] * set_cookies.shape[0]
# Out:
# /Users/rainyleon/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
js_cookies = js[js.symbol == 'window.document.cookie']
js_cookies = js_cookies[js_cookies.value.notnull()]

# %%
js_cookies_list = list(map(lambda x:x.replace(" ","").split(';'), js_cookies.value.tolist()))

# %%
# js_cookies["cookies_ls"] = js_cookies_list

# %%
js_cookies_ls_dict = list(map(lambda x:sep_cookies(x), js_cookies_list))

# %%
def sep_cookies(ls):
    res = []
    for l in ls:
        idx = l.find('=')
        if idx > 0:
            res.append((l[:idx], l[idx+1:]))
    return res

# %%
js_cookies['cookies_dict'] = js_cookies_ls_dict

# %%
js_cookies_temp = js_cookies[['visit_id','script_url', 'cookies_dict', "time_stamp"]]

# %%
ids = []
hosts = []
c_names = []
c_values = []
t_stamps = []
for _, row in js_cookies_temp.iterrows():
    Id = row.visit_id
    host = row.script_url
    for name, value in row.cookies_dict:
        ids.append(Id)
        hosts.append(host)
        c_names.append(name)
        c_values.append(value)
        t_stamps.append(row.time_stamp)

# %%
js_cookies_new = pd.DataFrame({"visit_id":ids, "name":c_names, "value":c_values, "time_stamp":t_stamps })

# %%
# cookie use tables
js_cookies_new["type"] = ["use"] * js_cookies_new.shape[0]

# %%
httprequests = httprequests[httprequests.cookies.notnull()]

# %%
ids = []
#hosts = []
c_names = []
c_values = []
t_stamps = []
for _, row in httprequests.iterrows():
    Id = row.visit_id
    #host = row.script_url
    idx = row.cookies.find('=')
    if idx > 0:
        ids.append(row.visit_id)
        c_names.append(row.cookies[:idx])
        c_values.append(row.cookies[idx+1:])
        t_stamps.append(row.time_stamp)

# %%
httpcookies = pd.DataFrame({"visit_id":ids, "name":c_names, "value":c_values, "time_stamp":t_stamps })

# %%
httpcookies['type'] = ['send'] * httpcookies.shape[0]

# %%
httpcookies
# Out:
#     visit_id            name  \
# 0          3  siteimproveses
# 1          3          __stid
# 2          3          __stid
# 3          3          __stid
# 4          3          __stid
# 5          3          __stid
# 6          3          __stid
# 7          3          __stid
# 8          3          __stid
# 9          3            TDID
# 10         3               U
# 11         3          _cc_cc
# 12         3          __stid
# 13         3          __stid
# 14         3          __stid
# 15         3           rlas3
# 16         3              EE
# 17         3           IQver
# 18         3          __stid
# 19         3              pi
# 20         3          demdex
# 21         3           IQver
# 22         3         _rxuuid
# 23         3           IQver
# 24         3              mc
# 25         3           IQver
# 26         3          __stid
# 27         3           rlas3
# 28         3          __stid
# 29         3           uuid2
# ..       ...             ...
# ...

# %%
bigcookies = pd.concat([set_cookies, js_cookies_new, httpcookies], ignore_index=True)

# %%
bigcookies.to_csv("bigcookies-1-3.csv", index=False)

# %%
##### concatenate

# %%
bigcookies1 = pd.read_csv("bigcookies-1-1.csv")
bigcookies2 = pd.read_csv("bigcookies-1-2.csv")
bigcookies3 = pd.read_csv("bigcookies-1-3.csv")

# %%
hugecookies = pd.concat([bigcookies1,bigcookies2,bigcookies3])

# %%
hugecookies.to_csv("hugecookies-1.csv", index=False)
