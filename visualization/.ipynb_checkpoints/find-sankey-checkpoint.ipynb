# %%
import pandas as pd
import numpy as np
import collections
import math

# %%
exp_num = 2
unique_huge = pd.read_csv("../hugecookies/hugecookies-{}.csv".format(exp_num))

# %%
unique_huge.shape
# Out:
# (197370, 7)

# %%
unique_huge.dropna(inplace=True)
unique_huge.shape
# Out:
# (191841, 7)

# %%
unique_huge = unique_huge[unique_huge['value'].str.len() >= 8]
unique_huge.shape
# Out:
# (146194, 7)

# %%
unique_huge.drop(unique_huge[unique_huge.name.str.contains('Test|test|lang|SameSite|Samesite|sameSite|samesite|expires|Path|path|domain|Expires|max-age')].index, inplace=True)
unique_huge.drop(unique_huge[unique_huge.value.isin(['1','0','2','true','yes','YES','ok','nan','none','None','NO_DATA','null','setstatuscode~~1'])].index, inplace=True)
unique_huge.shape
# Out:
# (141778, 7)

# %%
unique_huge
# Out:
#         context_id  visit_id  \
# 0                1        26
# 1                1        26
# 2                1        26
# 3                1        26
# 4                1        26
# 5                1        26
# 6                1        26
# 7                1        26
# 10               1        26
# 11               1        26
# 12               1        26
# 13               1        26
# 14               1        26
# 15               1        26
# 16               1        26
# 19               1        26
# 20               1        26
# 21               1        26
# 22               1        26
# 23               1        26
# 24               1        26
# 25               1        26
# 26               1        26
# 27               1        26
# 28               1        26
# 29               1        26
# 30               1        26
# 31               1        26
# 32               1        26
# 33               1        26
# ...            ...       ...
# 197330           3        75
# 197331           3        75
# 197332           3        75
# 197334           3        75
# 197335           3        75
# 197336           3        75
# 197337           3        75
# 197339           3        75
# 197340           3        75
# 197341           3        75
# 197342           3        75
# 197344           3        75
# 197347           3        75
# 197348           3        75
# 197351           3        75
# 197352           3        75
# 197353           3        75
# 197355           3        75
# 197356           3        75
# 197357           3        75
# 197358           3        75
# 197359           3        75
# 197360           3        75
# 197362           3        75
# 197363           3        75
# 197364           3        75
# 197365           3        75
# 197367           3        75
# 197368           3        75
# 197369           3        75
#
#                                                      host  \
# 0                                             .demdex.net
# 1                                             .demdex.net
# 2                                          .mid.rkdms.com
# 3                                          .mid.rkdms.com
# 4                                             .adsrvr.org
# 5                                             .adsrvr.org
# 6                                             .adsrvr.org
# 7                                             .adsrvr.org
# 10                                            .demdex.net
# 11                                            .demdex.net
# 12                                       .everesttech.net
# 13                                            .demdex.net
# 14                                            .demdex.net
# 15                                        .dpm.demdex.net
# 16                                        .dpm.demdex.net
# 19                                            .demdex.net
# 20                                            .demdex.net
# 21                                            .demdex.net
# 22                                            .demdex.net
# 23                                    .bounceexchange.com
# 24                                            .demdex.net
# 25                                            .demdex.net
# 26                                     .www.ugdturner.com
# 27                                    .rubiconproject.com
# 28                                    .rubiconproject.com
# 29                                    .rubiconproject.com
# 30                                    .rubiconproject.com
# 31                                            .demdex.net
# 32                                            .demdex.net
# 33                                            .demdex.net
# ...                                                   ...
# 197330  https://assets.adobedtm.com/7a8a98de0363fbed05...
# 197331  https://assets.adobedtm.com/7a8a98de0363fbed05...
# 197332  https://assets.adobedtm.com/7a8a98de0363fbed05...
# 197334  https://assets.adobedtm.com/7a8a98de0363fbed05...
# 197335  https://assets.adobedtm.com/7a8a98de0363fbed05...
# 197336  https://assets.adobedtm.com/7a8a98de0363fbed05...
# 197337  https://assets.adobedtm.com/7a8a98de0363fbed05...
# 197339  https://assets.adobedtm.com/7a8a98de0363fbed05...
# 197340  https://assets.adobedtm.com/7a8a98de0363fbed05...
# 197341  https://assets.adobedtm.com/7a8a98de0363fbed05...
# 197342  https://assets.adobedtm.com/7a8a98de0363fbed05...
# 197344  https://assets.adobedtm.com/7a8a98de0363fbed05...
# 197347  https://assets.adobedtm.com/7a8a98de0363fbed05...
# 197348  https://assets.adobedtm.com/7a8a98de0363fbed05...
# 197351  https://assets.adobedtm.com/7a8a98de0363fbed05...
# 197352  https://assets.adobedtm.com/7a8a98de0363fbed05...
# 197353  https://assets.adobedtm.com/7a8a98de0363fbed05...
# 197355  https://assets.adobedtm.com/7a8a98de0363fbed05...
# 197356  https://assets.adobedtm.com/7a8a98de0363fbed05...
# 197357  https://assets.adobedtm.com/7a8a98de0363fbed05...
# 197358  https://assets.adobedtm.com/7a8a98de0363fbed05...
# 197359  https://assets.adobedtm.com/7a8a98de0363fbed05...
# 197360  https://assets.adobedtm.com/7a8a98de0363fbed05...
# 197362  https://assets.adobedtm.com/7a8a98de0363fbed05...
# 197363  https://assets.adobedtm.com/7a8a98de0363fbed05...
# 197364  https://assets.adobedtm.com/7a8a98de0363fbed05...
# 197365  https://assets.adobedtm.com/7a8a98de0363fbed05...
# 197367  https://assets.adobedtm.com/7a8a98de0363fbed05...
# 197368  https://assets.adobedtm.com/7a8a98de0363fbed05...
# 197369  https://assets.adobedtm.com/7a8a98de0363fbed05...
#
#                                             name  \
# 0                                         demdex
# 1                                         demdex
# 2                                      sessionid
# 3                                      sessionid
# 4                                           TDID
# 5                                           TDID
# 6                                          TDCPM
# 7                                          TDCPM
# 10                                        demdex
# 11                                        demdex
# 12                                    ev_sync_dd
# 13                                        demdex
# 14                                        demdex
# 15                                           dpm
# 16                                           dpm
# 19                                        demdex
# 20                                        demdex
# 21                                         dextp
# 22                                         dextp
# 23                         bounceClientVisit340c
# 24                                         dextp
# 25                                         dextp
# 26                                           ug1
# 27                                         khaos
# 28                                         khaos
# 29                                         audit
# 30                                         audit
# 31                                         dextp
# 32                                         dextp
# 33                                         dextp
# ...                                          ...
# 197330                                   _uetsid
# 197331                                       _ga
# 197332                                      _gid
# 197334                                      _fbp
# 197335                            OptanonConsent
# 197336                               s_lastvisit
# 197337                             s_lastvisit_s
# 197339                                   gpv_c32
# 197340                                    gpv_pn
# 197341                                 kiwi_sess
# 197342  AMCV_5E1B123F5245B29B0A490D45%40AdobeOrg
# 197344                    lv-profile-widget-data
# 197347                            OptanonConsent
# 197348                                      mbox
# 197351                                 kiwi_life
# 197352                                    AWSELB
# 197353                                AWSELBCORS
# 197355                                       _gu
# 197356                                       _gs
# 197357                                       _gw
# 197358                                   _uetsid
# 197359                                       _ga
# 197360                                      _gid
# 197362                                      _fbp
# 197363                            OptanonConsent
# 197364                               s_lastvisit
# 197365                             s_lastvisit_s
# 197367                                   gpv_c32
# 197368                                    gpv_pn
# 197369                                 kiwi_sess
#
#                                                     value  \
# 0                  84904851894188318364191955014500747933
# 1                  84904851894188318364191955014500747933
# 2         h-e14976d9ab3296d42cee5c4f65a8134c_t-1588368987
# 3         h-e14976d9ab3296d42cee5c4f65a8134c_t-1588368987
# 4                    4a08e5f6-4ac8-4633-823a-043c8389ba41
# 5                    4a08e5f6-4ac8-4633-823a-043c8389ba41
# 6       CAESFwoIcHVibWF0aWMSCwiegKrXtoi3OBAFEhkKCmxpdm...
# 7       CAESFwoIcHVibWF0aWMSCwiegKrXtoi3OBAFEhkKCmxpdm...
# 10                 84904851894188318364191955014500747933
# 11                 84904851894188318364191955014500747933
# 12                                               20200501
# 13                 84904851894188318364191955014500747933
# 14                 84904851894188318364191955014500747933
# 15                 84904851894188318364191955014500747933
# 16                 84904851894188318364191955014500747933
# 19                 84904851894188318364191955014500747933
# 20                 84904851894188318364191955014500747933
# 21          285689-1-1588368970065|144230-1-1588369543033
# 22          285689-1-1588368970065|144230-1-1588369543033
# 23      %7B%22vid%22%3A1588369543314820%2C%22did%22%3A...
# 24      285689-1-1588368970065|144230-1-1588369543033|...
# 25      285689-1-1588368970065|144230-1-1588369543033|...
# 26                       5eac988908e6970a3f961d001627a1f4
# 27                                       K9OPVKOR-1O-FQOZ
# 28                                       K9OPVKOR-1O-FQOZ
# 29      1|9U9qySAk7MERM3uQ6i2Wsamq0IoPY0kxt5EWIXf30zhG...
# 30      1|9U9qySAk7MERM3uQ6i2Wsamq0IoPY0kxt5EWIXf30zhG...
# 31      285689-1-1588368970065|144230-1-1588369543033|...
# 32      285689-1-1588368970065|144230-1-1588369543033|...
# 33      285689-1-1588368970065|144230-1-1588369543033|...
# ...                                                   ...
# 197330           _uet95017a68-9558-d5a1-105e-e8721cf574d6
# 197331                        GA1.2.1338618929.1588370907
# 197332                        GA1.2.1271236449.1588370907
# 197334                      fb.1.1588370921478.1575749086
# 197335  landingPath=NotLandingPage&datestamp=Fri+May+0...
# 197336                                      1588370964892
# 197337                                      First%20Visit
# 197339                                          bigfuture
# 197340                      bigfuture%2Fget-in%2Fapplying
# 197341  {"user":{},"prev":{"siteCode":"","pageName":""...
# 197342  -432600572%7CMCIDTS%7C18384%7CMCMID%7C04796367...
# 197344                         %7B%22users%22%3A%5B%5D%7D
# 197347  landingPath=NotLandingPage&datestamp=Fri+May+0...
# 197348  session#72a3445247664b48924e02aa0b10b01f#15883...
# 197351  {"mktg":{"dateSet":"2020-05-01T22:08:26.698Z",...
# 197352  7B4D2B5F0EF98CCD86B85E828732EC911E0DC17C63010D...
# 197353  7B4D2B5F0EF98CCD86B85E828732EC911E0DC17C63010D...
# 197355               7bf8d8da-da85-4d66-90b7-f86d55bf8957
# 197356  2.s()c%5BDesktop%2CFirefox%2C233%3A766%3A57050...
# 197357    2.u%5B%2C%2C%2C%2C%5Dv%5B~frekw%2C~1%2C~0%5Da()
# 197358           _uet95017a68-9558-d5a1-105e-e8721cf574d6
# 197359                        GA1.2.1338618929.1588370907
# 197360                        GA1.2.1271236449.1588370907
# 197362                      fb.1.1588370921478.1575749086
# 197363  landingPath=NotLandingPage&datestamp=Fri+May+0...
# 197364                                      1588370964892
# 197365                                      First%20Visit
# 197367                                          bigfuture
# 197368                      bigfuture%2Fget-in%2Fapplying
# 197369  {"user":{},"prev":{"siteCode":"","pageName":""...
#
#                       time_stamp              type
# 0       2020-05-01T21:45:28.723Z           deleted
# 1       2020-05-01T21:45:28.723Z  added-or-changed
# 2       2020-05-01T21:45:32.464Z           deleted
# 3       2020-05-01T21:45:32.464Z  added-or-changed
# 4       2020-05-01T21:45:32.474Z           deleted
# 5       2020-05-01T21:45:32.474Z  added-or-changed
# 6       2020-05-01T21:45:32.475Z           deleted
# 7       2020-05-01T21:45:32.475Z  added-or-changed
# 10      2020-05-01T21:45:37.027Z           deleted
# 11      2020-05-01T21:45:37.028Z  added-or-changed
# 12      2020-05-01T21:45:37.376Z  added-or-changed
# 13      2020-05-01T21:45:40.325Z           deleted
# 14      2020-05-01T21:45:40.326Z  added-or-changed
# 15      2020-05-01T21:45:40.326Z           deleted
# 16      2020-05-01T21:45:40.327Z  added-or-changed
# 19      2020-05-01T21:45:42.869Z           deleted
# 20      2020-05-01T21:45:42.869Z  added-or-changed
# 21      2020-05-01T21:45:43.082Z           deleted
# 22      2020-05-01T21:45:43.082Z  added-or-changed
# 23      2020-05-01T21:45:43.342Z  added-or-changed
# 24      2020-05-01T21:45:44.622Z           deleted
# 25      2020-05-01T21:45:44.628Z  added-or-changed
# 26      2020-05-01T21:45:45.597Z  added-or-changed
# 27      2020-05-01T21:45:45.879Z           deleted
# 28      2020-05-01T21:45:45.879Z  added-or-changed
# 29      2020-05-01T21:45:45.880Z           deleted
# 30      2020-05-01T21:45:45.880Z  added-or-changed
# 31      2020-05-01T21:45:47.266Z           deleted
# 32      2020-05-01T21:45:47.267Z  added-or-changed
# 33      2020-05-01T21:45:48.287Z           deleted
# ...                          ...               ...
# 197330  2020-05-01T22:09:25.021Z               get
# 197331  2020-05-01T22:09:25.021Z               get
# 197332  2020-05-01T22:09:25.021Z               get
# 197334  2020-05-01T22:09:25.021Z               get
# 197335  2020-05-01T22:09:25.021Z               get
# 197336  2020-05-01T22:09:25.021Z               get
# 197337  2020-05-01T22:09:25.021Z               get
# 197339  2020-05-01T22:09:25.021Z               get
# 197340  2020-05-01T22:09:25.021Z               get
# 197341  2020-05-01T22:09:25.021Z               get
# 197342  2020-05-01T22:09:25.022Z               get
# 197344  2020-05-01T22:09:25.022Z               get
# 197347  2020-05-01T22:09:25.022Z               get
# 197348  2020-05-01T22:09:25.022Z               get
# 197351  2020-05-01T22:09:25.022Z               get
# 197352  2020-05-01T22:09:25.022Z               get
# 197353  2020-05-01T22:09:25.022Z               get
# 197355  2020-05-01T22:09:25.022Z               get
# 197356  2020-05-01T22:09:25.022Z               get
# 197357  2020-05-01T22:09:25.022Z               get
# 197358  2020-05-01T22:09:25.022Z               get
# 197359  2020-05-01T22:09:25.022Z               get
# 197360  2020-05-01T22:09:25.022Z               get
# 197362  2020-05-01T22:09:25.022Z               get
# 197363  2020-05-01T22:09:25.022Z               get
# 197364  2020-05-01T22:09:25.022Z               get
# 197365  2020-05-01T22:09:25.022Z               get
# 197367  2020-05-01T22:09:25.022Z               get
# 197368  2020-05-01T22:09:25.022Z               get
# 197369  2020-05-01T22:09:25.022Z               get
#
# [141778 rows x 7 columns]

# %%
ls_news = ['cnn','nytimes','theguardian','washingtonpost','forbes']
ls_health = ['webmd','mayoclinic','myfitnesspal','medscape','verywellhealth']
ls_education = ['jhu','mit','edx','harvard','colledgeboard']
name_dict = {1: ls_news, 2: ls_health, 3:ls_education}
order_ls = [[1,2,3],[2,1,3],[3,1,2],[3,2,1],[1,3,2],[2,3,1]]
order = order_ls[exp_num-1]
l = name_dict[order[0]] + name_dict[order[1]] + name_dict[order[2]]

# %%
l
# Out:
# ['webmd',
#  'mayoclinic',
#  'myfitnesspal',
#  'medscape',
#  'verywellhealth',
#  'cnn',
#  'nytimes',
#  'theguardian',
#  'washingtonpost',
#  'forbes',
#  'jhu',
#  'mit',
#  'edx',
#  'harvard',
#  'colledgeboard']

# %%
unique_huge['vname'] = unique_huge['visit_id'].apply(lambda x: l[math.ceil(x/5)-1])
unique_huge[:10]
# Out:
#     context_id  visit_id            host       name  \
# 0            1        26     .demdex.net     demdex
# 1            1        26     .demdex.net     demdex
# 2            1        26  .mid.rkdms.com  sessionid
# 3            1        26  .mid.rkdms.com  sessionid
# 4            1        26     .adsrvr.org       TDID
# 5            1        26     .adsrvr.org       TDID
# 6            1        26     .adsrvr.org      TDCPM
# 7            1        26     .adsrvr.org      TDCPM
# 10           1        26     .demdex.net     demdex
# 11           1        26     .demdex.net     demdex
#
#                                                 value  \
# 0              84904851894188318364191955014500747933
# 1              84904851894188318364191955014500747933
# 2     h-e14976d9ab3296d42cee5c4f65a8134c_t-1588368987
# 3     h-e14976d9ab3296d42cee5c4f65a8134c_t-1588368987
# 4                4a08e5f6-4ac8-4633-823a-043c8389ba41
# 5                4a08e5f6-4ac8-4633-823a-043c8389ba41
# 6   CAESFwoIcHVibWF0aWMSCwiegKrXtoi3OBAFEhkKCmxpdm...
# 7   CAESFwoIcHVibWF0aWMSCwiegKrXtoi3OBAFEhkKCmxpdm...
# 10             84904851894188318364191955014500747933
# 11             84904851894188318364191955014500747933
#
#                   time_stamp              type vname
# 0   2020-05-01T21:45:28.723Z           deleted   cnn
# 1   2020-05-01T21:45:28.723Z  added-or-changed   cnn
# 2   2020-05-01T21:45:32.464Z           deleted   cnn
# 3   2020-05-01T21:45:32.464Z  added-or-changed   cnn
# 4   2020-05-01T21:45:32.474Z           deleted   cnn
# 5   2020-05-01T21:45:32.474Z  added-or-changed   cnn
# 6   2020-05-01T21:45:32.475Z           deleted   cnn
# 7   2020-05-01T21:45:32.475Z  added-or-changed   cnn
# 10  2020-05-01T21:45:37.027Z           deleted   cnn
# 11  2020-05-01T21:45:37.028Z  added-or-changed   cnn

# %%
unique_huge['namevalue'] = list(map(lambda a, b: (a, b), unique_huge["name"].astype(str), unique_huge["value"].astype(str)))

# %%
byoccur = unique_huge.groupby(["namevalue", "context_id"], as_index = False)['time_stamp'].count()
byoccur[:10]
#temp2.to_csv("unique_namevalue-3.csv", index=False)
# Out:
#                                            namevalue  context_id  time_stamp
# 0                                    (113, 20200501)           1           1
# 1                                    (131, 20200501)           1           1
# 2                                    (131, 20200501)           2           1
# 3  (33x_ps, u%3D76839448493146%3As1%3D15883690020...           2          20
# 4  (A3, d=AQABBFCWrF4CEOk_HrROnnxMZ2lVKqQaT5AFEgE...           2           3
# 5  (A3, d=AQABBFCWrF4CEOk_HrROnnxMZ2lVKqQaT5AFEgE...           1          46
# 6  (A3, d=AQABBFCWrF4CEOk_HrROnnxMZ2lVKqQaT5AFEgE...           2          34
# 7  (A3, d=AQABBP6crF4CEJcqq89wRSEwJAdA1lJLliQFEgE...           1           3
# 8  (A3, d=AQABBP6crF4CEJcqq89wRSEwJAdA1lJLliQFEgE...           1          12
# 9  (A3, d=AQABBP6crF4CEJcqq89wRSEwJAdA1lJLliQFEgE...           3          12

# %%
# clean host domain 
temp = list(map(lambda x:".".join(x.split(".")[:3]).replace('https://','').replace('www',''), unique_huge['host'].tolist()))                    
temp = list(map(lambda x:".".join(x.split("/")[:1]), temp))                    
len(temp)
unique_huge['host_clean'] = temp
unique_huge[:10]
# Out:
#     context_id  visit_id            host       name  \
# 0            1        26     .demdex.net     demdex
# 1            1        26     .demdex.net     demdex
# 2            1        26  .mid.rkdms.com  sessionid
# 3            1        26  .mid.rkdms.com  sessionid
# 4            1        26     .adsrvr.org       TDID
# 5            1        26     .adsrvr.org       TDID
# 6            1        26     .adsrvr.org      TDCPM
# 7            1        26     .adsrvr.org      TDCPM
# 10           1        26     .demdex.net     demdex
# 11           1        26     .demdex.net     demdex
#
#                                                 value  \
# 0              84904851894188318364191955014500747933
# 1              84904851894188318364191955014500747933
# 2     h-e14976d9ab3296d42cee5c4f65a8134c_t-1588368987
# 3     h-e14976d9ab3296d42cee5c4f65a8134c_t-1588368987
# 4                4a08e5f6-4ac8-4633-823a-043c8389ba41
# 5                4a08e5f6-4ac8-4633-823a-043c8389ba41
# 6   CAESFwoIcHVibWF0aWMSCwiegKrXtoi3OBAFEhkKCmxpdm...
# 7   CAESFwoIcHVibWF0aWMSCwiegKrXtoi3OBAFEhkKCmxpdm...
# 10             84904851894188318364191955014500747933
# 11             84904851894188318364191955014500747933
#
#                   time_stamp              type vname  \
# 0   2020-05-01T21:45:28.723Z           deleted   cnn
# 1   2020-05-01T21:45:28.723Z  added-or-changed   cnn
# 2   2020-05-01T21:45:32.464Z           deleted   cnn
# 3   2020-05-01T21:45:32.464Z  added-or-changed   cnn
# 4   2020-05-01T21:45:32.474Z           deleted   cnn
# 5   2020-05-01T21:45:32.474Z  added-or-changed   cnn
# 6   2020-05-01T21:45:32.475Z           deleted   cnn
# 7   2020-05-01T21:45:32.475Z  added-or-changed   cnn
# 10  2020-05-01T21:45:37.027Z           deleted   cnn
# 11  2020-05-01T21:45:37.028Z  added-or-changed   cnn
#
#                                             namevalue   host_clean
# 0    (demdex, 84904851894188318364191955014500747933)  .demdex.net
# 1    (demdex, 84904851894188318364191955014500747933)  .demdex.net
# 2   (sessionid, h-e14976d9ab3296d42cee5c4f65a8134c...   .mid.rkdms
# 3   (sessionid, h-e14976d9ab3296d42cee5c4f65a8134c...   .mid.rkdms
# 4        (TDID, 4a08e5f6-4ac8-4633-823a-043c8389ba41)  .adsrvr.org
# 5        (TDID, 4a08e5f6-4ac8-4633-823a-043c8389ba41)  .adsrvr.org
# 6   (TDCPM, CAESFwoIcHVibWF0aWMSCwiegKrXtoi3OBAFEh...  .adsrvr.org
# 7   (TDCPM, CAESFwoIcHVibWF0aWMSCwiegKrXtoi3OBAFEh...  .adsrvr.org
# 10   (demdex, 84904851894188318364191955014500747933)  .demdex.net
# 11   (demdex, 84904851894188318364191955014500747933)  .demdex.net

# %%
byvisit = pd.DataFrame(unique_huge.groupby(["namevalue", "context_id"], as_index = False)['vname'].apply(set).reset_index(name='byvname'))
byvisit[:10]
# Out:
#                                            namevalue  context_id  \
# 0                                    (113, 20200501)           1
# 1                                    (131, 20200501)           1
# 2                                    (131, 20200501)           2
# 3  (33x_ps, u%3D76839448493146%3As1%3D15883690020...           2
# 4  (A3, d=AQABBFCWrF4CEOk_HrROnnxMZ2lVKqQaT5AFEgE...           2
# 5  (A3, d=AQABBFCWrF4CEOk_HrROnnxMZ2lVKqQaT5AFEgE...           1
# 6  (A3, d=AQABBFCWrF4CEOk_HrROnnxMZ2lVKqQaT5AFEgE...           2
# 7  (A3, d=AQABBP6crF4CEJcqq89wRSEwJAdA1lJLliQFEgE...           1
# 8  (A3, d=AQABBP6crF4CEJcqq89wRSEwJAdA1lJLliQFEgE...           1
# 9  (A3, d=AQABBP6crF4CEJcqq89wRSEwJAdA1lJLliQFEgE...           3
#
#                    byvname
# 0            {theguardian}
# 1            {theguardian}
# 2               {medscape}
# 3                  {webmd}
# 4                  {webmd}
# 5    {theguardian, forbes}
# 6  {webmd, verywellhealth}
# 7                 {forbes}
# 8                 {forbes}
# 9          {colledgeboard}

# %%
# byhost = pd.DataFrame(unique_huge.groupby(["namevalue", "context_id"], as_index = False)['host_clean'].apply(list))
byhost = pd.DataFrame(unique_huge.groupby(["namevalue", "context_id"], as_index = False)['host_clean'].apply(set).reset_index(name='byhost'))
byhost[:10]
# Out:
#                                            namevalue  context_id  \
# 0                                    (113, 20200501)           1
# 1                                    (131, 20200501)           1
# 2                                    (131, 20200501)           2
# 3  (33x_ps, u%3D76839448493146%3As1%3D15883690020...           2
# 4  (A3, d=AQABBFCWrF4CEOk_HrROnnxMZ2lVKqQaT5AFEgE...           2
# 5  (A3, d=AQABBFCWrF4CEOk_HrROnnxMZ2lVKqQaT5AFEgE...           1
# 6  (A3, d=AQABBFCWrF4CEOk_HrROnnxMZ2lVKqQaT5AFEgE...           2
# 7  (A3, d=AQABBP6crF4CEJcqq89wRSEwJAdA1lJLliQFEgE...           1
# 8  (A3, d=AQABBP6crF4CEJcqq89wRSEwJAdA1lJLliQFEgE...           1
# 9  (A3, d=AQABBP6crF4CEJcqq89wRSEwJAdA1lJLliQFEgE...           3
#
#                                               byhost
# 0                                  {.deepintent.com}
# 1                             {match.deepintent.com}
# 2                                  {.deepintent.com}
# 3  {cms-xch.33across.com, ssc.33across.com, cms-x...
# 4  {ups.analytics.yahoo, pr-bh.ybp.yahoo, .yahoo....
# 5  {pr.ybp.yahoo, cms.analytics.yahoo, ups.analyt...
# 6  {ads.yahoo.com, cookiex.ngd.yahoo, ups.analyti...
# 7       {pr-bh.ybp.yahoo, ads.yahoo.com, .yahoo.com}
# 8  {ups.analytics.yahoo, cms.analytics.yahoo, coo...
# 9                   {sp.analytics.yahoo, .yahoo.com}

# %%
highlight = pd.merge(byoccur, byhost, on=['namevalue',  'context_id'])
highlight = pd.merge(highlight, byvisit, on=['namevalue',  'context_id'])
highlight[:10]
# Out:
#                                            namevalue  context_id  time_stamp  \
# 0                                    (113, 20200501)           1           1
# 1                                    (131, 20200501)           1           1
# 2                                    (131, 20200501)           2           1
# 3  (33x_ps, u%3D76839448493146%3As1%3D15883690020...           2          20
# 4  (A3, d=AQABBFCWrF4CEOk_HrROnnxMZ2lVKqQaT5AFEgE...           2           3
# 5  (A3, d=AQABBFCWrF4CEOk_HrROnnxMZ2lVKqQaT5AFEgE...           1          46
# 6  (A3, d=AQABBFCWrF4CEOk_HrROnnxMZ2lVKqQaT5AFEgE...           2          34
# 7  (A3, d=AQABBP6crF4CEJcqq89wRSEwJAdA1lJLliQFEgE...           1           3
# 8  (A3, d=AQABBP6crF4CEJcqq89wRSEwJAdA1lJLliQFEgE...           1          12
# 9  (A3, d=AQABBP6crF4CEJcqq89wRSEwJAdA1lJLliQFEgE...           3          12
#
#                                               byhost                  byvname
# 0                                  {.deepintent.com}            {theguardian}
# 1                             {match.deepintent.com}            {theguardian}
# 2                                  {.deepintent.com}               {medscape}
# 3  {cms-xch.33across.com, ssc.33across.com, cms-x...                  {webmd}
# 4  {ups.analytics.yahoo, pr-bh.ybp.yahoo, .yahoo....                  {webmd}
# 5  {pr.ybp.yahoo, cms.analytics.yahoo, ups.analyt...    {theguardian, forbes}
# 6  {ads.yahoo.com, cookiex.ngd.yahoo, ups.analyti...  {webmd, verywellhealth}
# 7       {pr-bh.ybp.yahoo, ads.yahoo.com, .yahoo.com}                 {forbes}
# 8  {ups.analytics.yahoo, cms.analytics.yahoo, coo...                 {forbes}
# 9                   {sp.analytics.yahoo, .yahoo.com}          {colledgeboard}

# %%
# select only across contexts
ltd = []
Counter = collections.Counter(highlight.namevalue.tolist())

# %%
for key, value in Counter.items():
    if value == 1:
        ltd.append(key)

# %%
indtd = highlight[highlight['namevalue'].isin(ltd)].index
highlight.drop(indtd, inplace=True)
highlight[:10]
print(highlight.shape)
# Out:
# (376, 5)

# %%
highlight.to_csv("../visualization/sankey-helper-{}.csv".format(exp_num), index=False)

# %%
# import ast

# %%
# hightlight = pd.read_csv('sankey-helper-1.csv', converters={'byhost':ast.literal_eval, 'byvname': ast.literal_eval})

# %%
highlight[:10]
# Out:
#                                             namevalue  context_id  time_stamp  \
# 1                                     (131, 20200501)           1           1
# 2                                     (131, 20200501)           2           1
# 5   (A3, d=AQABBFCWrF4CEOk_HrROnnxMZ2lVKqQaT5AFEgE...           1          46
# 6   (A3, d=AQABBFCWrF4CEOk_HrROnnxMZ2lVKqQaT5AFEgE...           2          34
# 8   (A3, d=AQABBP6crF4CEJcqq89wRSEwJAdA1lJLliQFEgE...           1          12
# 9   (A3, d=AQABBP6crF4CEJcqq89wRSEwJAdA1lJLliQFEgE...           3          12
# 11  (AA003, AXx6phkQm5zlntnaHnXNhOSt6auIK1woAqXNBG...           1           5
# 12  (AA003, AXx6phkQm5zlntnaHnXNhOSt6auIK1woAqXNBG...           2           1
# 14  (ADGRX_UID, 6ae2f17c-8bf4-11ea-9039-5a65b40255bc)           1          12
# 15  (ADGRX_UID, 6ae2f17c-8bf4-11ea-9039-5a65b40255bc)           2           1
#
#                                                byhost                  byvname
# 1                              {match.deepintent.com}            {theguardian}
# 2                                   {.deepintent.com}               {medscape}
# 5   {pr.ybp.yahoo, cms.analytics.yahoo, ups.analyt...    {theguardian, forbes}
# 6   {ads.yahoo.com, cookiex.ngd.yahoo, ups.analyti...  {webmd, verywellhealth}
# 8   {ups.analytics.yahoo, cms.analytics.yahoo, coo...                 {forbes}
# 9                    {sp.analytics.yahoo, .yahoo.com}          {colledgeboard}
# 11                                     {ad.atdmt.com}                 {forbes}
# 12                                       {.atdmt.com}                  {webmd}
# 14                         {cm.adgrx.com, .adgrx.com}    {theguardian, forbes}
# 15                                       {.adgrx.com}           {myfitnesspal}

# %%
keywords = """deepintent
yahoo
advertising
ib-ibi
mookie1
atdmt
casalemedia
exelator
bttrack
doubleclick
contextweb
nr-data
pubmatic
bing
adsrvr
tapad
adsymptotic
scorecardresearch
crwdcntrl
districtm
krxd
1rx
agkn
amazon-adsystem
adentifi
adnxs
spotxchange
rubiconproject
bidr
bluekai
dnacdn
bidswitch
myvisualiq
ipredictive
quantserve
media.net
demdex
everesttech
extend.tv
facebook
openx
mathtag
mxptint
twitter
rlcdn
rkdms
owneriq
sitescout
sharethrough
simpli
taboola
3lift
myvisualiq
turn.com
adform
w55c
zemanta
tribalfusion
linkedin
iasds01
dotomi
appier
acuityplatform
advangelists
mfadsrvr
zorosrv
smartadserver
rfihub
srv
creativecdn
addthis
gumgum
yieldmo"""
keywords = keywords.split("\n")

# %%
# keywords = keywords.split("\n")
keywords
# Out:
# ['deepintent',
#  'yahoo',
#  'advertising',
#  'ib-ibi',
#  'mookie1',
#  'atdmt',
#  'casalemedia',
#  'exelator',
#  'bttrack',
#  'doubleclick',
#  'contextweb',
#  'nr-data',
#  'pubmatic',
#  'bing',
#  'adsrvr',
#  'tapad',
#  'adsymptotic',
#  'scorecardresearch',
#  'crwdcntrl',
#  'districtm',
#  'krxd',
#  '1rx',
#  'agkn',
#  'amazon-adsystem',
#  'adentifi',
#  'adnxs',
#  'spotxchange',
#  'rubiconproject',
#  'bidr',
#  'bluekai',
#  'dnacdn',
#  'bidswitch',
#  'myvisualiq',
#  'ipredictive',
#  'quantserve',
#  'media.net',
#  'demdex',
#  'everesttech',
#  'extend.tv',
#  'facebook',
#  'openx',
#  'mathtag',
#  'mxptint',
#  'twitter',
#  'rlcdn',
#  'rkdms',
#  'owneriq',
#  'sitescout',
#  'sharethrough',
#  'simpli',
#  'taboola',
#  '3lift',
#  'myvisualiq',
#  'turn.com',
#  'adform',
#  'w55c',
#  'zemanta',
#  'tribalfusion',
#  'linkedin',
#  'iasds01',
#  'dotomi',
#  'appier',
#  'acuityplatform',
#  'advangelists',
#  'mfadsrvr',
#  'zorosrv',
#  'smartadserver',
#  'rfihub',
#  'srv',
#  'creativecdn',
#  'addthis',
#  'gumgum',
#  'yieldmo']

# %%
len(keywords)
# Out:
# 73

# %%
nv_ls = highlight.namevalue.tolist()
origin_hosts = highlight.byhost.tolist()
origin_web = highlight.byvname.tolist()
contexts_ls = highlight.context_id.tolist()

# %%
nv_ls
# Out:
# [('131', '20200501'),
#  ('131', '20200501'),
#  ('A3',
#   'd=AQABBFCWrF4CEOk_HrROnnxMZ2lVKqQaT5AFEgEBAQHnrV62XgAAAAAA_SMAAAcIUJasXqQaT5A&S=AQAAAvjI0jyNMcmjKGD3DMvOzA8'),
#  ('A3',
#   'd=AQABBFCWrF4CEOk_HrROnnxMZ2lVKqQaT5AFEgEBAQHnrV62XgAAAAAA_SMAAAcIUJasXqQaT5A&S=AQAAAvjI0jyNMcmjKGD3DMvOzA8'),
#  ('A3',
#   'd=AQABBP6crF4CEJcqq89wRSEwJAdA1lJLliQFEgEBAQHurV62XgAAAAAA_SMAAAcI_pysXlJLliQ&S=AQAAAuz2jwhHw4nKSGxdPMAt_w4'),
#  ('A3',
#   'd=AQABBP6crF4CEJcqq89wRSEwJAdA1lJLliQFEgEBAQHurV62XgAAAAAA_SMAAAcI_pysXlJLliQ&S=AQAAAuz2jwhHw4nKSGxdPMAt_w4'),
#  ('AA003',
#   'AXx6phkQm5zlntnaHnXNhOSt6auIK1woAqXNBGjAGZTUZe5gu1b68apuqMK-DPu07ik'),
#  ('AA003',
#   'AXx6phkQm5zlntnaHnXNhOSt6auIK1woAqXNBGjAGZTUZe5gu1b68apuqMK-DPu07ik'),
#  ('ADGRX_UID', '6ae2f17c-8bf4-11ea-9039-5a65b40255bc'),
#  ('ADGRX_UID', '6ae2f17c-8bf4-11ea-9039-5a65b40255bc'),
#  ('ANON_ID',
#   'annr6ioZdUQd82Hp9vcghtYVg6iAZdthasdflU1ZdR7Y2XjyLMpntZajJLVRnVV4kT2YZbsOMw7D4'),
#  ('ANON_ID',
#   'annr6ioZdUQd82Hp9vcghtYVg6iAZdthasdflU1ZdR7Y2XjyLMpntZajJLVRnVV4kT2YZbsOMw7D4'),
#  ('ANON_ID_old',
#   'annr6ioZdUQd82Hp9vcghtYVg6iAZdthasdflU1ZdR7Y2XjyLMpntZajJLVRnVV4kT2YZbsOMw7D4'),
#  ('ANON_ID_old',
#   'annr6ioZdUQd82Hp9vcghtYVg6iAZdthasdflU1ZdR7Y2XjyLMpntZajJLVRnVV4kT2YZbsOMw7D4'),
#  ('APID', 'UPc6f8abae-8bf7-11ea-b3b0-0eef058309dd'),
#  ('APID', 'UPc6f8abae-8bf7-11ea-b3b0-0eef058309dd'),
#  ('APID', 'UPc9731ebc-8bf3-11ea-8299-028bb717ffad'),
#  ('APID', 'UPc9731ebc-8bf3-11ea-8299-028bb717ffad'),
#  ('APIDTS', '1588369005'),
#  ('APIDTS', '1588369005'),
#  ('APIDTS', '1588370695'),
#  ('APIDTS', '1588370695'),
#  ('ASP.NET_SessionId', 'vqra04uap4p05e3apus1kjpk'),
#  ('ASP.NET_SessionId', 'vqra04uap4p05e3apus1kjpk'),
#  ('ATN', '1.1588368985.4344126832823465990.AYJMLXAA-O4SFnuW_vg'),
#  ('ATN', '1.1588368985.4344126832823465990.AYJMLXAA-O4SFnuW_vg'),
#  ('B', '295iba9fap77u&b=3&s=10'),
#  ('B', '295iba9fap77u&b=3&s=10'),
#  ('B', '90joqkhfap5ig&b=3&s=vr'),
#  ('B', '90joqkhfap5ig&b=3&s=vr'),
#  ('CDIUSER', 'di_b4c1a501160144718220d'),
#  ('CDIUSER', 'di_b4c1a501160144718220d'),
#  ('CMDD', 'AAKLqQQAB35GAQAEAaAC'),
#  ('CMDD', 'AAKLqQQAB35GAQAEAaAC'),
#  ('CMID', 'XqyWYNHM43gAABBJRNgAAAAW'),
#  ('CMID', 'XqyWYNHM43gAABBJRNgAAAAW'),
#  ('CMRUM3',
#   '2d5eac96662760CAESEC5tatNjfJvy7ivU0Mcp4bY&2f5eac97722760IR76SwUR1JuDkK5'),
#  ('CMRUM3',
#   '2d5eac96662760CAESEC5tatNjfJvy7ivU0Mcp4bY&2f5eac97722760IR76SwUR1JuDkK5'),
#  ('CMST', 'XqyWYF6smGcH'),
#  ('CMST', 'XqyWYF6smGcH'),
#  ('DMADT', 'h5bDZYqcRFy0UX7jRWeP1w'),
#  ('DMADT', 'h5bDZYqcRFy0UX7jRWeP1w'),
#  ('DPSync2',
#   '1588896000%3A164%7C1588377600%3A174%7C1589500800%3A200_201_197_219'),
#  ('DPSync2',
#   '1588896000%3A164%7C1588377600%3A174%7C1589500800%3A200_201_197_219'),
#  ('DotomiUser', '719005448783790810$3$7535207$$1'),
#  ('DotomiUser', '719005448783790810$3$7535207$$1'),
#  ('EE', '"4f7db909f6839f0d8e02bc46baf40842"'),
#  ('EE', '"4f7db909f6839f0d8e02bc46baf40842"'),
#  ('EE', '\\4f7db909f6839f0d8e02bc46baf40842\\'),
#  ('EE', '\\4f7db909f6839f0d8e02bc46baf40842\\'),
#  ('GLOBALID',
#   '2uKlc8-sIBd984cSkD72DtzNhbXch0xQrDqATsWhaKLIzV6KrA5CwNbQj4NE6QusMlK5OsrNsrMC4Q2'),
#  ('GLOBALID',
#   '2uKlc8-sIBd984cSkD72DtzNhbXch0xQrDqATsWhaKLIzV6KrA5CwNbQj4NE6QusMlK5OsrNsrMC4Q2'),
#  ('GUC', 'AQEBAQFere5etkIbPgQg'),
#  ('GUC', 'AQEBAQFere5etkIbPgQg'),
#  ('GUC', 'AQEBAQFeredetkIgIATD'),
#  ('GUC', 'AQEBAQFeredetkIgIATD'),
#  ('HAPLB8A', 's86168|XqyWu'),
#  ('HAPLB8A', 's86168|XqyWu'),
#  ('HAPLB8S', 's8621|XqyXc'),
#  ('HAPLB8S', 's8621|XqyXc'),
#  ('IDE', 'AHWqTUkuwocq_GOy8EUG2TVRn4BBRN0f3lONr52CxJvDY3Dm9s0woC8SPOLEqW1-'),
#  ('_auid', '5sKMruQmA22VIhD7XpesXg'),
#  ('_auid', '5sKMruQmA22VIhD7XpesXg'),
#  ('_cc_id', 'eec3a44b3067856f788807355877b6c4'),
#  ('_cc_id', 'eec3a44b3067856f788807355877b6c4'),
#  ('_kuid_', 'NYMIY4GB'),
#  ('_kuid_', 'NYMIY4GB'),
#  ('_rxuuid',
#   '%7B%22rx_uuid%22%3A%22RX-5780459a-36b1-4651-a0c6-d64fce43f46a-005%22%2C%22nxtrdr%22%3Afalse%7D'),
#  ('_rxuuid',
#   '%7B%22rx_uuid%22%3A%22RX-5780459a-36b1-4651-a0c6-d64fce43f46a-005%22%2C%22nxtrdr%22%3Afalse%7D'),
#  ('_rxuuid',
#   '%7B%22rx_uuid%22%3A%22RX-5780459a-36b1-4651-a0c6-d64fce43f46a-005%22%7D'),
#  ('_rxuuid',
#   '%7B%22rx_uuid%22%3A%22RX-5780459a-36b1-4651-a0c6-d64fce43f46a-005%22%7D'),
#  ('_ssum', 'eyI1IjoxNTg4MzY5MjY5ODI3LCI3IjoxNTg4MzY5MjY5ODI3fQ'),
#  ('_ssum', 'eyI1IjoxNTg4MzY5MjY5ODI3LCI3IjoxNTg4MzY5MjY5ODI3fQ'),
#  ('_usd_webmd.com', '05df5920-c5ef-4998-b450-d68fbfb55a84'),
#  ('_usd_webmd.com', '05df5920-c5ef-4998-b450-d68fbfb55a84'),
#  ('ab', '0001%3AR0u8hBwSvoiEpLwNGYqmMmlVOquGB9zg'),
#  ('ab', '0001%3AR0u8hBwSvoiEpLwNGYqmMmlVOquGB9zg'),
#  ('ad-id', 'A31p7rchFEb8p7Kmn5DZ_Tc'),
#  ('ad-id', 'A31p7rchFEb8p7Kmn5DZ_Tc'),
#  ('audience', 'd910b0e0-8bf3-11ea-8d0a-1d99161f1601'),
#  ('audience', 'd910b0e0-8bf3-11ea-8d0a-1d99161f1601'),
#  ('audit',
#   '1|9U9qySAk7MERM3uQ6i2Wsamq0IoPY0kxt5EWIXf30zhGARq8S15AkkZ0sWH4p8MWYLsQelA3twVWL9FD22Ryv/19fq37pzg5wFCfoC+4IsWi0813hHAhj1Dfv570ZGhx'),
#  ('audit',
#   '1|9U9qySAk7MERM3uQ6i2Wsamq0IoPY0kxt5EWIXf30zhGARq8S15AkkZ0sWH4p8MWYLsQelA3twVWL9FD22Ryv/19fq37pzg5wFCfoC+4IsWi0813hHAhj1Dfv570ZGhx'),
#  ('auid', '505042665005'),
#  ('auid', '505042665005'),
#  ('avnguid', 'av-4feaf505-cba9-4048-bd31-259e2fae436a'),
#  ('avnguid', 'av-4feaf505-cba9-4048-bd31-259e2fae436a'),
#  ('bcookie', '\\v=2&2466b91d-e3c6-49d0-80c2-6c321b66223d\\'),
#  ('bcookie', '\\v=2&2466b91d-e3c6-49d0-80c2-6c321b66223d\\'),
#  ('bito', 'AAEr0U69WS0AAA-7wkcStg'),
#  ('bito', 'AAEr0U69WS0AAA-7wkcStg'),
#  ('bku', '53R99arVgaT9xV/N'),
#  ('bku', '53R99arVgaT9xV/N'),
#  ('data-dmx',
#   'eyJhbGciOiJFUzI1NiIsInR5cCI6IkpXVCJ9.eyJzaWQiOjEwMDA1LCJ1c3IiOiJxZ1llc2dZYk1XSkxOMkphUzB4RmFsUnliME5PYTFwVVMyWlpTRkZZTkZaeSJ9.eulD18pvyZkl_CHu4V96g_HRZ2FHECwCve-QfSZUkwxzRIZoIU9tztxmK0KsQ-e-g7-wtr2hMQJoit9MzZs2sQ~~1'),
#  ('data-emx', '1298045627963393635brt224841588369294880361a5~~1'),
#  ('data-emx', '1298045627963393635brt224841588369294880361a5~~1'),
#  ('data-mf', '1374024f-133c-4d45-b4d2-18d85c58b631~~1'),
#  ('data-mf', '1374024f-133c-4d45-b4d2-18d85c58b631~~1'),
#  ('data-p', 'fgkpm1NBAOfL~~1'),
#  ('data-p', 'fgkpm1NBAOfL~~1'),
#  ('data-pb', 'D72FE388-0A4D-4D14-842C-451A05DAFA46~~1'),
#  ('data-pb', 'D72FE388-0A4D-4D14-842C-451A05DAFA46~~1'),
#  ('data-r', 'K9OPVKOR-1O-FQOZ~~1'),
#  ('data-r', 'K9OPVKOR-1O-FQOZ~~1'),
#  ('data-rbh', 'P2XXCp00YxQybwUjKLRi~~1'),
#  ('data-rbh', 'P2XXCp00YxQybwUjKLRi~~1'),
#  ('data-rk', '3459549065789871615~~1'),
#  ('data-rk', '3459549065789871615~~1'),
#  ('data-sh', 'd424aef7-cb96-435b-9c89-dff1ece5ac07~~1'),
#  ('data-sh', 'd424aef7-cb96-435b-9c89-dff1ece5ac07~~1'),
#  ('data-sov', '64947d13ab1db1e54214d7ef~~1'),
#  ('data-sov', '64947d13ab1db1e54214d7ef~~1'),
#  ('data-sy', '1D78D3A7EB8046D789BFAD45B997BDA3~~3'),
#  ('data-sy', '1D78D3A7EB8046D789BFAD45B997BDA3~~3'),
#  ('data-tx', '19207df3-a53d-4e2f-8ba4-ed45796269c4~~1'),
#  ('data-tx', '19207df3-a53d-4e2f-8ba4-ed45796269c4~~1'),
#  ('data-xu', 'IR76SwUR1JuDkK5~~1'),
#  ('data-xu', 'IR76SwUR1JuDkK5~~1'),
#  ('demdex', '09963385900232412880327237888049590875'),
#  ('demdex', '09963385900232412880327237888049590875'),
#  ('demdex', '84904851894188318364191955014500747933'),
#  ('demdex', '84904851894188318364191955014500747933'),
#  ('dextp', '285689-1-1588368970065'),
#  ('dextp', '285689-1-1588368970065'),
#  ('dpm', '09963385900232412880327237888049590875'),
#  ('dpm', '09963385900232412880327237888049590875'),
#  ('dpm', '84904851894188318364191955014500747933'),
#  ('dpm', '84904851894188318364191955014500747933'),
#  ('eud',
#   'H4sIAAAAAAAAAOOSMXR2dA12dSoLM4kvKDbydMwszXJ0SQ_KT0xxNQjiNTS1sDA2szQyMDA3MV3FCOebmBkYGbxiRJE3AwAqbF8yTQAAAA'),
#  ('eud',
#   'H4sIAAAAAAAAAOOSMXR2dA12dSoLM4kvKDbydMwszXJ0SQ_KT0xxNQjiNTS1sDA2szQyMDA3MV3FCOebmBkYGbxiRJE3AwAqbF8yTQAAAA'),
#  ('euds',
#   'H4sIAAAAAAAAAOOSMXR2dA12dSoLM4kvKDbydMwszXJ0SQ_KT0xxNQAAsM0rHB4AAAA'),
#  ('euds',
#   'H4sIAAAAAAAAAOOSMXR2dA12dSoLM4kvKDbydMwszXJ0SQ_KT0xxNQAAsM0rHB4AAAA'),
#  ('ev_sync_dd', '20200501'),
#  ('ev_sync_dd', '20200501'),
#  ('everest_g_v2', 'g_surferid~XqyWTwAAAD2xAA9x'),
#  ('everest_g_v2', 'g_surferid~XqyWTwAAAD2xAA9x'),
#  ('everest_g_v2', 'g_surferid~Xqyc-gAAAG3bbAFU'),
#  ('everest_g_v2', 'g_surferid~Xqyc-gAAAG3bbAFU'),
#  ('extendtv_user_id', '0c386e1f-b96d-4691-a81f-81989d2f6ee9'),
#  ('extendtv_user_id', '0c386e1f-b96d-4691-a81f-81989d2f6ee9'),
#  ('fr', '0HyxDR1LlxupDWyR9..BerJz_...1.0.BerJz_.'),
#  ('fr', '0HyxDR1LlxupDWyR9..BerJz_...1.0.BerJz_.'),
#  ('fr', '0STthMiUITfKh6mZX..BerJZE..F6s.1.0.BerJZE.'),
#  ('fr', '0STthMiUITfKh6mZX..BerJZE..F6s.1.0.BerJZE.'),
#  ('i', '44d8d45d-6ca0-0eb9-1af9-79e4bc5ecf09|1588369002'),
#  ('i', '44d8d45d-6ca0-0eb9-1af9-79e4bc5ecf09|1588369002'),
#  ('icu', 'ChgIis9MEAoYAiACKAIwxa6y9QU4AkACSAIQxa6y9QUYAQ..'),
#  ('icu', 'ChgIis9MEAoYAiACKAIwxa6y9QU4AkACSAIQxa6y9QUYAQ..'),
#  ('khaos', 'K9OPVKOR-1O-FQOZ'),
#  ('khaos', 'K9OPVKOR-1O-FQOZ'),
#  ('li_sugr', '48947ee2-a06a-4058-93ec-61b2412869d2'),
#  ('li_sugr', '48947ee2-a06a-4058-93ec-61b2412869d2'),
#  ('lidc',
#   '\\b=VGST07:g=1732:u=1:i=1588370687:t=1588457087:s=AQHZwT0jTsqxM_0gB2QzzUF5-YNaNIyT\\'),
#  ('lidc',
#   '\\b=VGST07:g=1732:u=1:i=1588370687:t=1588457087:s=AQHZwT0jTsqxM_0gB2QzzUF5-YNaNIyT\\'),
#  ('ljt_reader', '64947d13ab1db1e54214d7ef'),
#  ('ljt_reader', '64947d13ab1db1e54214d7ef'),
#  ('ljtrtb', 'eJyrrgUAAXUA%2BQ%3D%3D'),
#  ('ljtrtb', 'eJyrrgUAAXUA%2BQ%3D%3D'),
#  ('loc',
#   'jgFQ1i7taklKhSNj6gDbre5HdjcBtyG9tvvCUQ6_QrLyTMgNmFPWFLmRZTnIBw9yBCkMIritA09RoKnSot9qKe3Qz9q1tkIw1jXtdpyZpGI'),
#  ('loc',
#   'jgFQ1i7taklKhSNj6gDbre5HdjcBtyG9tvvCUQ6_QrLyTMgNmFPWFLmRZTnIBw9yBCkMIritA09RoKnSot9qKe3Qz9q1tkIw1jXtdpyZpGI'),
#  ('mc', '5eac966c-4281b-63921-68be4'),
#  ('rlas3', 'Zwd1mn6D8ZbIhtDiJPJkvJwtos6qJ5IzCpJs3Q8EcVk='),
#  ('rud',
#   'H4sIAAAAAAAAAOMSNjYxtTQ1sTQwMzW3sLQwNzQzNBXiM9R11A3ySA72D0sPMHeW4jU0tbAwNrM0MjAwNzEDANJXc1Y0AAAA'),
#  ('rud',
#   'H4sIAAAAAAAAAOMSNjYxtTQ1sTQwMzW3sLQwNzQzNBXiM9R11A3ySA72D0sPMHeW4jU0tbAwNrM0MjAwNzEDANJXc1Y0AAAA'),
#  ('ruds',
#   'H4sIAAAAAAAAAOMSNjYxtTQ1sTQwMzW3sLQwNzQzNBXiM9R11A3ySA72D0sPMHcGAE2p1bUlAAAA'),
#  ('ruds',
#   'H4sIAAAAAAAAAOMSNjYxtTQ1sTQwMzW3sLQwNzQzNBXiM9R11A3ySA72D0sPMHcGAE2p1bUlAAAA'),
#  ('sa-user-id',
#   's%3A0-7306acfe-03b1-46bb-5666-476696748fd5.Qqdy%2FRjFDawxEXIZa%2FMYHNbPKSoAgZfMkJR35a9XEG8'),
#  ('sa-user-id',
#   's%3A0-7306acfe-03b1-46bb-5666-476696748fd5.Qqdy%2FRjFDawxEXIZa%2FMYHNbPKSoAgZfMkJR35a9XEG8'),
#  ('sa-user-id-v2',
#   's%3A0-7306acfe-03b1-46bb-5666-476696748fd5%24ip%2418.188.215.201.SSQmEvnwdpmVZnmGEVwNV2fRqaBCT3aAQ8uFwhpiaHI'),
#  ('sa-user-id-v2',
#   's%3A0-7306acfe-03b1-46bb-5666-476696748fd5%24ip%2418.188.215.201.SSQmEvnwdpmVZnmGEVwNV2fRqaBCT3aAQ8uFwhpiaHI'),
#  ('sc', '13%3A81813'),
#  ('sc', '13%3A81813'),
#  ('ses10', '225890^1&265746^2'),
#  ('ses10', '225890^1&265746^2'),
#  ('ses15', '66536^2&205204^1&225302^1&225890^1&228682^2&265746^5'),
#  ('ses15', '66536^2&205204^1&225302^1&225890^1&228682^2&265746^5'),
#  ('ses2', '153530^1&208958^1'),
#  ('ses2', '153530^1&208958^1'),
#  ('ses9', '119514^1&208958^1'),
#  ('ses9', '119514^1&208958^1'),
#  ('sessionid', 'h-e14976d9ab3296d42cee5c4f65a8134c_t-1588368987'),
#  ('sessionid', 'h-e14976d9ab3296d42cee5c4f65a8134c_t-1588368987'),
#  ('si', 'Q6416554001585350391P'),
#  ('si', 'Q6416554001585350391P'),
#  ('ssi', '91fdf8dc-17bf-42e7-b7b4-ad6e5cfbb50a#1588368987559'),
#  ('ssi', '91fdf8dc-17bf-42e7-b7b4-ad6e5cfbb50a#1588368987559'),
#  ('stx_user_id', 'd424aef7-cb96-435b-9c89-dff1ece5ac07'),
#  ('stx_user_id', 'd424aef7-cb96-435b-9c89-dff1ece5ac07'),
#  ('suid', 'B4832DB3D91942E6B034837CC4CE11A3'),
#  ('suid', 'B4832DB3D91942E6B034837CC4CE11A3'),
#  ('suid_legacy', 'B4832DB3D91942E6B034837CC4CE11A3'),
#  ('suid_legacy', 'B4832DB3D91942E6B034837CC4CE11A3'),
#  ('t_gid', 'd7ca31f6-9e82-4074-b5eb-bf0d1b81383d-tuct5a61bcf'),
#  ('t_gid', 'd7ca31f6-9e82-4074-b5eb-bf0d1b81383d-tuct5a61bcf'),
#  ('tluid', '7246350687518985932'),
#  ('tluid', '7246350687518985932'),
#  ('ts', '1588369365'),
#  ('ts', '1588369365'),
#  ('tuuid', '1374024f-133c-4d45-b4d2-18d85c58b631'),
#  ('tuuid', '1374024f-133c-4d45-b4d2-18d85c58b631'),
#  ('tuuid', '624755b3-03c1-4ad9-8e56-84d8c3e03b25'),
#  ('tuuid', '624755b3-03c1-4ad9-8e56-84d8c3e03b25'),
#  ('tuuid', 'd7ba95e4-9bbd-43e0-bcd7-58603b2a0090'),
#  ('tuuid', 'd7ba95e4-9bbd-43e0-bcd7-58603b2a0090'),
#  ('tuuid_lu', '1588368974'),
#  ('tuuid_lu', '1588368974'),
#  ('tuuid_lu', '1588368976'),
#  ('tuuid_lu', '1588368976'),
#  ('tuuid_lu', '1588369264'),
#  ('tuuid_lu', '1588369264'),
#  ('u', 'P2XXCp00YxQybwUjKLRi'),
#  ('u', 'P2XXCp00YxQybwUjKLRi'),
#  ('ud',
#   '"eJxrXxzq6XKLQcEkzTwlydLAMs3MwtgyzSDFItXAKCnZxCwpMc3EwMLEaHFZatGCpaXFqSlJh5ZU5JTkNK0uiw91jHdz9PX0iVzullmUmpZfsQIsFuYatMjcaEl%252BUWb6otDgxUUpaQyLSopPBe94KQYAscEqvQ%253D%253D"'),
#  ('ud',
#   '"eJxrXxzq6XKLQcEkzTwlydLAMs3MwtgyzSDFItXAKCnZxCwpMc3EwMLEaHFZatGCpaXFqSlJh5ZU5JTkNK0uiw91jHdz9PX0iVzullmUmpZfsQIsFuYatMjcaEl%252BUWb6otDgxUUpaQyLSopPBe94KQYAscEqvQ%253D%253D"'),
#  ('ud',
#   '\\eJxrXxzq6XKLQcEkzTwlydLAMs3MwtgyzSDFItXAKCnZxCwpMc3EwMLEaHFZatGCpaXFqSlJh5ZU5JTkNK0uiw91jHdz9PX0iVzullmUmpZfsQIsFuYatMjcaEl%252BUWb6otDgxUUpaQyLSopPBe94KQYAscEqvQ%253D%253D\\'),
#  ('ud',
#   '\\eJxrXxzq6XKLQcEkzTwlydLAMs3MwtgyzSDFItXAKCnZxCwpMc3EwMLEaHFZatGCpaXFqSlJh5ZU5JTkNK0uiw91jHdz9PX0iVzullmUmpZfsQIsFuYatMjcaEl%252BUWb6otDgxUUpaQyLSopPBe94KQYAscEqvQ%253D%253D\\'),
#  ('uid', '5675351577416297248'),
#  ('uid', '5675351577416297248'),
#  ('uid', '5eac964f9b15a010'),
#  ('uid', '5eac964f9b15a010'),
#  ('uid', '7675122843652995469'),
#  ('uid', '7675122843652995469'),
#  ('univ_id',
#   '537072971|4a08e5f6-4ac8-4633-823a-043c8389ba41|1588369004693675'),
#  ('univ_id',
#   '537072971|4a08e5f6-4ac8-4633-823a-043c8389ba41|1588369004693675'),
#  ('uuid', '315d5eac-964f-4800-89ed-6edbc03dead4'),
#  ('uuid', '315d5eac-964f-4800-89ed-6edbc03dead4'),
#  ('uuid2', '1298045627963393635'),
#  ('uuid2', '1298045627963393635'),
#  ('vis10', '225890^1&265746^2&268826^2'),
#  ('vis10', '225890^1&265746^2&268826^2'),
#  ('vis15',
#   '66536^2&119514^3&205204^1&225302^1&225890^1&228682^2&265746^6&268826^3'),
#  ('vis15',
#   '66536^2&119514^3&205204^1&225302^1&225890^1&228682^2&265746^6&268826^3'),
#  ('vis2', '153530^2&208958^1'),
#  ('vis2', '153530^2&208958^1'),
#  ('vis9', '119514^1&208958^1'),
#  ('vis9', '119514^1&208958^1'),
#  ('visitor-id', '2313705626589788000V10'),
#  ('visitor-id', '2313705626589788000V10'),
#  ('vst', 'u_aef68cae-87a8-4247-8dcf-9bd89b70ea74'),
#  ('vst', 'u_aef68cae-87a8-4247-8dcf-9bd89b70ea74'),
#  ('wfivefivec', 'IR76SwUR1JuDkK5'),
#  ('wfivefivec', 'IR76SwUR1JuDkK5'),
#  ('yieldmo_id', 'ga61bdf473153413d4ec%7C1588368975792%7C0%7C'),
#  ('yieldmo_id', 'ga61bdf473153413d4ec%7C1588368975792%7C0%7C'),
#  ('zuid', 'KHZ89MT9KlK-f1O8NSb0'),
#  ('zuid', 'KHZ89MT9KlK-f1O8NSb0')]

# %%
# origin_web

# %%
order
# Out:
# [2, 1, 3]

# %%
dict_ls = collections.defaultdict(set)

# %%
for i in range(1, len(nv_ls)):
    if nv_ls[i-1] != nv_ls[i]:
        continue
    u_hosts = origin_hosts[i].union(origin_hosts[i-1])
    if order.index(contexts_ls[i]) < order.index(contexts_ls[i-1]):
        in_webs = origin_web[i]
        out_webs = origin_web[i-1]
    else:
        in_webs = origin_web[i-1]
        out_webs = origin_web[i]
    for domain in keywords:
        if any(domain in string for string in u_hosts):
            for in_web in in_webs:
                for out_web in out_webs:
                    dict_ls[in_web].add((out_web, domain))

# %%
dict_ls['forbes']
# Out:
# {('colledgeboard', 'advertising'),
#  ('colledgeboard', 'demdex'),
#  ('colledgeboard', 'doubleclick'),
#  ('colledgeboard', 'everesttech'),
#  ('colledgeboard', 'facebook'),
#  ('colledgeboard', 'yahoo'),
#  ('edx', 'adsymptotic'),
#  ('edx', 'doubleclick'),
#  ('edx', 'facebook'),
#  ('edx', 'linkedin'),
#  ('harvard', 'doubleclick'),
#  ('harvard', 'facebook'),
#  ('jhu', 'doubleclick'),
#  ('jhu', 'facebook'),
#  ('mit', 'doubleclick')}

# %%
# f = open("dict.txt","w")
# f.write( str(dict_ls) )
# f.close()

# %%
count_dict = collections.defaultdict(int)
for in_node, nodes_set in dict_ls.items():
    for out_node, host in nodes_set:
        count_dict[(in_node, out_node)] += 1

# %%
inbounds = [inbound for inbound, _ in count_dict.keys()]
outbounds = [outbound for _, outbound in count_dict.keys()]
weight = list(count_dict.values())

# %%
count_df = pd.DataFrame({'inbound': inbounds, 'outbound': outbounds, 'weight': weight})

# %%
count_df.to_csv('inout_weight_{}.csv'.format(exp_num), index=False)
