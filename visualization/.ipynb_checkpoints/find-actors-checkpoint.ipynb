# %%
import numpy as np
import pandas as pd
import ast
import collections

# %%
exp_num = 6
df = pd.read_csv('sankey-helper-{}.csv'.format(exp_num), \
                 converters={'byhost':ast.literal_eval, 'byvname': ast.literal_eval})

# %%
df[:5]
# Out:
#                                            namevalue  context_id  time_stamp  \
# 0                                ('131', '20200502')           1           6
# 1                                ('131', '20200502')           2           1
# 2  ('A3', 'd=AQABBKPMrF4CEKCi8LpQuotbEk2A-M-xq1YF...           1          21
# 3  ('A3', 'd=AQABBKPMrF4CEKCi8LpQuotbEk2A-M-xq1YF...           2          44
# 4  ('A3', 'd=AQABBKPMrF4CEKCi8LpQuotbEk2A-M-xq1YF...           3          12
#
#                                               byhost  \
# 0                             {match.deepintent.com}
# 1                                  {.deepintent.com}
# 2  {cms.analytics.yahoo, pr.ybp.yahoo, pr-bh.ybp....
# 3  {ads.yahoo.com, cookiex.ngd.yahoo, service.ids...
# 4                   {sp.analytics.yahoo, .yahoo.com}
#
#                                byvname
# 0                {forbes, theguardian}
# 1                           {medscape}
# 2  {cnn, nytimes, forbes, theguardian}
# 3    {verywellhealth, webmd, medscape}
# 4                      {colledgeboard}

# %%
keywords = """deepintent
yahoo
advertising
ib-ibi
mookie1
atdmt
casalemedia
exelator
bttrack
doubleclick
contextweb
nr-data
pubmatic
bing
adsrvr
tapad
adsymptotic
scorecardresearch
crwdcntrl
districtm
krxd
1rx
agkn
amazon-adsystem
adentifi
adnxs
spotxchange
rubiconproject
bidr
bluekai
dnacdn
bidswitch
myvisualiq
ipredictive
quantserve
media.net
demdex
everesttech
extend.tv
facebook
openx
mathtag
mxptint
twitter
rlcdn
rkdms
owneriq
sitescout
sharethrough
simpli
taboola
3lift
myvisualiq
turn.com
adform
w55c
zemanta
tribalfusion
linkedin
iasds01
dotomi
appier
acuityplatform
advangelists
mfadsrvr
zorosrv
smartadserver
rfihub
srv
creativecdn
addthis
gumgum
yieldmo"""
keywords = keywords.split("\n")

# %%
nv_ls = df.namevalue.tolist()
origin_hosts = df.byhost.tolist()
origin_web = df.byvname.tolist()
contexts_ls = df.context_id.tolist()

# %%
ls_news = ['cnn','nytimes','theguardian','washingtonpost','forbes']
ls_health = ['webmd','mayoclinic','myfitnesspal','medscape','verywellhealth']
ls_education = ['jhu','mit','edx','harvard','colledgeboard']
name_dict = {1: ls_news, 2: ls_health, 3:ls_education}
order_ls = [[1,2,3],[2,1,3],[3,1,2],[3,2,1],[1,3,2],[2,3,1]]
order = order_ls[exp_num-1]
l = name_dict[order[0]] + name_dict[order[1]] + name_dict[order[2]]

# %%
dict_ls = collections.defaultdict(set)

# %%
for i in range(1, len(nv_ls)):
    if nv_ls[i-1] != nv_ls[i]:
        continue
    u_hosts = origin_hosts[i].union(origin_hosts[i-1])
    if order.index(contexts_ls[i]) < order.index(contexts_ls[i-1]):
        in_webs = origin_web[i]
        out_webs = origin_web[i-1]
    else:
        in_webs = origin_web[i-1]
        out_webs = origin_web[i]
    for domain in keywords:
        if any(domain in string for string in u_hosts):
            for in_web in in_webs:
                for out_web in out_webs:
                    dict_ls[in_web].add((out_web, domain))

# %%
inbounds = []
outbounds = []
trackers = []

# %%
for key, s in dict_ls.items():
    for outbound, tracker in s:
        inbounds.append(key)
        outbounds.append(outbound)
        trackers.append(tracker)

# %%
df_2 = pd.DataFrame({"exp":[exp_num]*len(inbounds), "from":inbounds, "to":outbounds, "by": trackers})

# %%
df_2.shape
# Out:
# (500, 4)

# %%
big_df = pd.concat([big_df, df_2])

# %%
big_df.shape
# Out:
# (1674, 4)

# %%
df_2[:10]
# Out:
#    exp      from              to              by
# 0    6  medscape  washingtonpost     advertising
# 1    6  medscape             cnn           yahoo
# 2    6  medscape     theguardian  acuityplatform
# 3    6  medscape          forbes    sharethrough
# 4    6  medscape  washingtonpost           openx
# 5    6  medscape  washingtonpost           yahoo
# 6    6  medscape         nytimes           adnxs
# 7    6  medscape     theguardian      deepintent
# 8    6  medscape         nytimes          rfihub
# 9    6  medscape     theguardian      contextweb

# %%
big_df.to_csv("linkage_details.csv", index=False)

# %%
big_df.groupby(['exp', 'from', 'to'])['by'].apply(set).reset_index(name='by')
# Out:
#      exp            from              to  \
# 0      1             cnn      mayoclinic
# 1      1             cnn        medscape
# 2      1             cnn    myfitnesspal
# 3      1             cnn  verywellhealth
# 4      1             cnn           webmd
# 5      1          forbes      mayoclinic
# 6      1          forbes        medscape
# 7      1          forbes    myfitnesspal
# 8      1          forbes  verywellhealth
# 9      1          forbes           webmd
# 10     1        medscape   colledgeboard
# 11     1        medscape             edx
# 12     1        medscape         harvard
# 13     1        medscape             jhu
# 14     1        medscape             mit
# 15     1    myfitnesspal   colledgeboard
# 16     1    myfitnesspal             edx
# 17     1    myfitnesspal         harvard
# 18     1    myfitnesspal             jhu
# 19     1    myfitnesspal             mit
# 20     1         nytimes      mayoclinic
# 21     1         nytimes        medscape
# 22     1         nytimes    myfitnesspal
# 23     1         nytimes  verywellhealth
# 24     1         nytimes           webmd
# 25     1     theguardian        medscape
# 26     1  verywellhealth   colledgeboard
# 27     1  verywellhealth             edx
# 28     1  verywellhealth         harvard
# 29     1  verywellhealth             jhu
# ..   ...             ...             ...
# 201    6    myfitnesspal             cnn
# 202    6    myfitnesspal   colledgeboard
# 203    6    myfitnesspal             edx
# 204    6    myfitnesspal          forbes
# 205    6    myfitnesspal         harvard
# 206    6    myfitnesspal             jhu
# 207    6    myfitnesspal             mit
# 208    6    myfitnesspal         nytimes
# 209    6    myfitnesspal     theguardian
# 210    6    myfitnesspal  washingtonpost
# 211    6  verywellhealth             cnn
# 212    6  verywellhealth   colledgeboard
# 213    6  verywellhealth             edx
# 214    6  verywellhealth          forbes
# 215    6  verywellhealth         harvard
# 216    6  verywellhealth             jhu
# 217    6  verywellhealth             mit
# 218    6  verywellhealth         nytimes
# 219    6  verywellhealth     theguardian
# 220    6  verywellhealth  washingtonpost
# 221    6           webmd             cnn
# 222    6           webmd   colledgeboard
# 223    6           webmd             edx
# 224    6           webmd          forbes
# 225    6           webmd         harvard
# 226    6           webmd             jhu
# 227    6           webmd             mit
# 228    6           webmd         nytimes
# 229    6           webmd     theguardian
# 230    6           webmd  washingtonpost
#
#                                                     by
# 0                                     {rubiconproject}
# 1                                     {rubiconproject}
# 2                                     {rubiconproject}
# 3                                     {rubiconproject}
# 4                                     {rubiconproject}
# 5    {doubleclick, mathtag, bing, scorecardresearch...
# 6                         {deepintent, rubiconproject}
# 7    {doubleclick, sharethrough, openx, advertising...
# 8                                     {rubiconproject}
# 9    {dnacdn, turn.com, zemanta, yahoo, media.net, ...
# 10   {doubleclick, demdex, facebook, yahoo, nr-data...
# 11       {adsymptotic, doubleclick, nr-data, facebook}
# 12                    {doubleclick, nr-data, facebook}
# 13                             {doubleclick, facebook}
# 14                                       {doubleclick}
# 15                   {yahoo, doubleclick, everesttech}
# 16                                       {doubleclick}
# 17                                       {doubleclick}
# 18                                       {doubleclick}
# 19                                       {doubleclick}
# 20                                    {rubiconproject}
# 21                        {deepintent, rubiconproject}
# 22                                    {rubiconproject}
# 23                                    {rubiconproject}
# 24                                    {rubiconproject}
# 25                                        {deepintent}
# 26                              {doubleclick, nr-data}
# 27                              {doubleclick, nr-data}
# 28                              {doubleclick, nr-data}
# 29                                       {doubleclick}
# ..                                                 ...
# 201  {yahoo, bidswitch, adsrvr, amazon-adsystem, ow...
# 202  {doubleclick, advertising, bing, demdex, yahoo...
# 203                      {doubleclick, bing, facebook}
# 204  {yahoo, adsrvr, amazon-adsystem, bing, adform,...
# 205                            {doubleclick, facebook}
# 206                            {doubleclick, facebook}
# 207                                      {doubleclick}
# 208  {doubleclick, sharethrough, openx, advertising...
# 209  {yahoo, bidswitch, adsrvr, amazon-adsystem, ow...
# 210  {doubleclick, sharethrough, openx, advertising...
# 211  {dnacdn, turn.com, yahoo, bidswitch, nr-data, ...
# 212  {doubleclick, advertising, yahoo, nr-data, eve...
# 213                             {doubleclick, nr-data}
# 214  {turn.com, sharethrough, doubleclick, quantser...
# 215                             {doubleclick, nr-data}
# 216                                      {doubleclick}
# 217                                      {doubleclick}
# 218  {mxptint, doubleclick, sharethrough, mathtag, ...
# 219  {turn.com, yahoo, bidswitch, pubmatic, adsrvr,...
# 220  {doubleclick, sharethrough, advertising, adfor...
# 221  {addthis, turn.com, zemanta, yahoo, creativecd...
# 222  {doubleclick, advertising, demdex, facebook, y...
# 223               {adsymptotic, doubleclick, facebook}
# 224  {addthis, turn.com, zemanta, myvisualiq, yahoo...
# 225                            {doubleclick, facebook}
# 226                   {doubleclick, twitter, facebook}
# 227                                      {doubleclick}
# 228  {yahoo, media.net, twitter, rfihub, amazon-ads...
# 229  {turn.com, zemanta, yahoo, creativecdn, media....
# 230  {doubleclick, sharethrough, openx, advertising...
#
# [231 rows x 4 columns]
