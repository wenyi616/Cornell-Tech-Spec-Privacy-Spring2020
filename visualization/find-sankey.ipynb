# %%
import pandas as pd
import numpy as np
import collections
import math

# %%
exp_num = 6
unique_huge = pd.read_csv("../hugecookies/hugecookies-{}.csv".format(exp_num))

# %%
unique_huge.shape
# Out:
# (281392, 7)

# %%
unique_huge.dropna(inplace=True)
unique_huge.shape
# Out:
# (271535, 7)

# %%
unique_huge = unique_huge[unique_huge['value'].str.len() >= 8]
unique_huge.shape
# Out:
# (205184, 7)

# %%
unique_huge.drop(unique_huge[unique_huge.name.str.contains('Test|test|lang|SameSite|Samesite|sameSite|samesite|expires|Path|path|domain|Expires|max-age')].index, inplace=True)
unique_huge.drop(unique_huge[unique_huge.value.isin(['1','0','2','true','yes','YES','ok','nan','none','None','NO_DATA','null','setstatuscode~~1'])].index, inplace=True)
unique_huge.shape
# Out:
# (200035, 7)

# %%
unique_huge
# Out:
#         context_id  visit_id  \
# 0                1        51
# 1                1        51
# 4                1        51
# 5                1        51
# 6                1        51
# ...            ...       ...
# 281386           3        50
# 281387           3        50
# 281389           3        50
# 281390           3        50
# 281391           3        50
#
#                                                      host           name  \
# 0                                             .demdex.net         demdex
# 1                                             .demdex.net         demdex
# 4                                             .adsrvr.org           TDID
# 5                                             .adsrvr.org           TDID
# 6                                             .adsrvr.org          TDCPM
# ...                                                   ...            ...
# 281386  https://assets.adobedtm.com/7a8a98de0363fbed05...    s_lastvisit
# 281387  https://assets.adobedtm.com/7a8a98de0363fbed05...  s_lastvisit_s
# 281389  https://assets.adobedtm.com/7a8a98de0363fbed05...        gpv_c32
# 281390  https://assets.adobedtm.com/7a8a98de0363fbed05...         gpv_pn
# 281391  https://assets.adobedtm.com/7a8a98de0363fbed05...      kiwi_sess
#
#                                                     value  \
# 0                  36551071651606209352351350566654624168
# 1                  36551071651606209352351350566654624168
# 4                    b304d3f5-a06c-4fb6-be25-3ee29ee2e85e
# 5                    b304d3f5-a06c-4fb6-be25-3ee29ee2e85e
# 6       CAESGQoKbGl2ZWludGVudBILCMSr8-3CkLc4EAUSFwoIcH...
# ...                                                   ...
# 281386                                      1588383672090
# 281387                                      First%20Visit
# 281389                                          bigfuture
# 281390                      bigfuture%2Fget-in%2Fapplying
# 281391  {"user":{},"prev":{"siteCode":"","pageName":""...
#
#                       time_stamp              type
# 0       2020-05-02T01:41:24.389Z           deleted
# 1       2020-05-02T01:41:24.389Z  added-or-changed
# 4       2020-05-02T01:41:26.630Z           deleted
# 5       2020-05-02T01:41:26.631Z  added-or-changed
# 6       2020-05-02T01:41:26.632Z           deleted
# ...                          ...               ...
# 281386  2020-05-02T01:41:12.228Z               get
# 281387  2020-05-02T01:41:12.228Z               get
# 281389  2020-05-02T01:41:12.228Z               get
# 281390  2020-05-02T01:41:12.228Z               get
# 281391  2020-05-02T01:41:12.228Z               get
#
# [200035 rows x 7 columns]

# %%
ls_news = ['cnn','nytimes','theguardian','washingtonpost','forbes']
ls_health = ['webmd','mayoclinic','myfitnesspal','medscape','verywellhealth']
ls_education = ['jhu','mit','edx','harvard','colledgeboard']
name_dict = {1: ls_news, 2: ls_health, 3:ls_education}
order_ls = [[1,2,3],[2,1,3],[3,1,2],[3,2,1],[1,3,2],[2,3,1]]
order = order_ls[exp_num-1]
l = name_dict[order[0]] + name_dict[order[1]] + name_dict[order[2]]

# %%
# l

# %%
unique_huge['vname'] = unique_huge['visit_id'].apply(lambda x: l[math.ceil(x/5)-1])
unique_huge[:10]
# Out:
#     context_id  visit_id                 host                   name  \
# 0            1        51          .demdex.net                 demdex
# 1            1        51          .demdex.net                 demdex
# 4            1        51          .adsrvr.org                   TDID
# 5            1        51          .adsrvr.org                   TDID
# 6            1        51          .adsrvr.org                  TDCPM
# 7            1        51          .adsrvr.org                  TDCPM
# 8            1        51       .mid.rkdms.com              sessionid
# 9            1        51       .mid.rkdms.com              sessionid
# 10           1        51  .bounceexchange.com  bounceClientVisit340c
# 11           1        51   .www.ugdturner.com                    ug1
#
#                                                 value  \
# 0              36551071651606209352351350566654624168
# 1              36551071651606209352351350566654624168
# 4                b304d3f5-a06c-4fb6-be25-3ee29ee2e85e
# 5                b304d3f5-a06c-4fb6-be25-3ee29ee2e85e
# 6   CAESGQoKbGl2ZWludGVudBILCMSr8-3CkLc4EAUSFwoIcH...
# 7   CAESGQoKbGl2ZWludGVudBILCMSr8-3CkLc4EAUSFwoIcH...
# 8     h-ca7dc096bf65cfd6ed8235cbe44b7db1_t-1588382897
# 9     h-ca7dc096bf65cfd6ed8235cbe44b7db1_t-1588382897
# 10  %7B%22vid%22%3A1588383686922212%2C%22did%22%3A...
# 11                   5eaccfc706cad60a3f9c0d0014240342
#
#                   time_stamp              type vname
# 0   2020-05-02T01:41:24.389Z           deleted   cnn
# 1   2020-05-02T01:41:24.389Z  added-or-changed   cnn
# 4   2020-05-02T01:41:26.630Z           deleted   cnn
# 5   2020-05-02T01:41:26.631Z  added-or-changed   cnn
# 6   2020-05-02T01:41:26.632Z           deleted   cnn
# 7   2020-05-02T01:41:26.632Z  added-or-changed   cnn
# 8   2020-05-02T01:41:26.667Z           deleted   cnn
# 9   2020-05-02T01:41:26.668Z  added-or-changed   cnn
# 10  2020-05-02T01:41:26.943Z  added-or-changed   cnn
# 11  2020-05-02T01:41:27.463Z  added-or-changed   cnn

# %%
unique_huge['namevalue'] = list(map(lambda a, b: (a, b), unique_huge["name"].astype(str), unique_huge["value"].astype(str)))

# %%
byoccur = unique_huge.groupby(["namevalue", "context_id"], as_index = False)['time_stamp'].count()
byoccur[:10]
#temp2.to_csv("unique_namevalue-3.csv", index=False)
# Out:
#                                            namevalue  context_id  time_stamp
# 0                                    (107, 20200502)           1           5
# 1                                    (108, 20200502)           1           4
# 2                                    (110, 20200502)           1           3
# 3                                    (112, 20200502)           1           2
# 4                                    (113, 20200502)           1           7
# 5                                    (129, 20200502)           1           6
# 6                                    (131, 20200502)           1           6
# 7                                    (131, 20200502)           2           1
# 8  (33x_ps, u%3D76839656056297%3As1%3D15883829090...           2          19
# 9                (3pi, 175#1588383168199#1249748497)           2           1

# %%
# clean host domain 
temp = list(map(lambda x:".".join(x.split(".")[:3]).replace('https://','').replace('www',''), unique_huge['host'].tolist()))                    
temp = list(map(lambda x:".".join(x.split("/")[:1]), temp))                    
len(temp)
unique_huge['host_clean'] = temp
unique_huge
# Out:
#         context_id  visit_id  \
# 0                1        51
# 1                1        51
# 4                1        51
# 5                1        51
# 6                1        51
# ...            ...       ...
# 281386           3        50
# 281387           3        50
# 281389           3        50
# 281390           3        50
# 281391           3        50
#
#                                                      host           name  \
# 0                                             .demdex.net         demdex
# 1                                             .demdex.net         demdex
# 4                                             .adsrvr.org           TDID
# 5                                             .adsrvr.org           TDID
# 6                                             .adsrvr.org          TDCPM
# ...                                                   ...            ...
# 281386  https://assets.adobedtm.com/7a8a98de0363fbed05...    s_lastvisit
# 281387  https://assets.adobedtm.com/7a8a98de0363fbed05...  s_lastvisit_s
# 281389  https://assets.adobedtm.com/7a8a98de0363fbed05...        gpv_c32
# 281390  https://assets.adobedtm.com/7a8a98de0363fbed05...         gpv_pn
# 281391  https://assets.adobedtm.com/7a8a98de0363fbed05...      kiwi_sess
#
#                                                     value  \
# 0                  36551071651606209352351350566654624168
# 1                  36551071651606209352351350566654624168
# 4                    b304d3f5-a06c-4fb6-be25-3ee29ee2e85e
# 5                    b304d3f5-a06c-4fb6-be25-3ee29ee2e85e
# 6       CAESGQoKbGl2ZWludGVudBILCMSr8-3CkLc4EAUSFwoIcH...
# ...                                                   ...
# 281386                                      1588383672090
# 281387                                      First%20Visit
# 281389                                          bigfuture
# 281390                      bigfuture%2Fget-in%2Fapplying
# 281391  {"user":{},"prev":{"siteCode":"","pageName":""...
#
#                       time_stamp              type          vname  \
# 0       2020-05-02T01:41:24.389Z           deleted            cnn
# 1       2020-05-02T01:41:24.389Z  added-or-changed            cnn
# 4       2020-05-02T01:41:26.630Z           deleted            cnn
# 5       2020-05-02T01:41:26.631Z  added-or-changed            cnn
# 6       2020-05-02T01:41:26.632Z           deleted            cnn
# ...                          ...               ...            ...
# 281386  2020-05-02T01:41:12.228Z               get  colledgeboard
# 281387  2020-05-02T01:41:12.228Z               get  colledgeboard
# 281389  2020-05-02T01:41:12.228Z               get  colledgeboard
# 281390  2020-05-02T01:41:12.228Z               get  colledgeboard
# 281391  2020-05-02T01:41:12.228Z               get  colledgeboard
#
#                                                 namevalue           host_clean
# 0        (demdex, 36551071651606209352351350566654624168)          .demdex.net
# 1        (demdex, 36551071651606209352351350566654624168)          .demdex.net
# 4            (TDID, b304d3f5-a06c-4fb6-be25-3ee29ee2e85e)          .adsrvr.org
# 5            (TDID, b304d3f5-a06c-4fb6-be25-3ee29ee2e85e)          .adsrvr.org
# 6       (TDCPM, CAESGQoKbGl2ZWludGVudBILCMSr8-3CkLc4EA...          .adsrvr.org
# ...                                                   ...                  ...
# 281386                       (s_lastvisit, 1588383672090)  assets.adobedtm.com
# 281387                     (s_lastvisit_s, First%20Visit)  assets.adobedtm.com
# 281389                               (gpv_c32, bigfuture)  assets.adobedtm.com
# 281390            (gpv_pn, bigfuture%2Fget-in%2Fapplying)  assets.adobedtm.com
# 281391  (kiwi_sess, {"user":{},"prev":{"siteCode":"","...  assets.adobedtm.com
#
# [200035 rows x 10 columns]

# %%
byvisit = pd.DataFrame(unique_huge.groupby(["namevalue", "context_id"], as_index = False)['vname'].apply(set).reset_index(name='byvname'))
byvisit[:10]
# Out:
#                                            namevalue  context_id  \
# 0                                    (107, 20200502)           1
# 1                                    (108, 20200502)           1
# 2                                    (110, 20200502)           1
# 3                                    (112, 20200502)           1
# 4                                    (113, 20200502)           1
# 5                                    (129, 20200502)           1
# 6                                    (131, 20200502)           1
# 7                                    (131, 20200502)           2
# 8  (33x_ps, u%3D76839656056297%3As1%3D15883829090...           2
# 9                (3pi, 175#1588383168199#1249748497)           2
#
#                           byvname
# 0           {theguardian, forbes}
# 1           {theguardian, forbes}
# 2           {theguardian, forbes}
# 3                        {forbes}
# 4  {theguardian, forbes, nytimes}
# 5           {theguardian, forbes}
# 6           {theguardian, forbes}
# 7                      {medscape}
# 8                         {webmd}
# 9                  {myfitnesspal}

# %%
# byhost = pd.DataFrame(unique_huge.groupby(["namevalue", "context_id"], as_index = False)['host_clean'].apply(list))
byhost = pd.DataFrame(unique_huge.groupby(["namevalue", "context_id"], as_index = False)['host_clean'].apply(set).reset_index(name='byhost'))
byhost[:10]
# Out:
#                                            namevalue  context_id  \
# 0                                    (107, 20200502)           1
# 1                                    (108, 20200502)           1
# 2                                    (110, 20200502)           1
# 3                                    (112, 20200502)           1
# 4                                    (113, 20200502)           1
# 5                                    (129, 20200502)           1
# 6                                    (131, 20200502)           1
# 7                                    (131, 20200502)           2
# 8  (33x_ps, u%3D76839656056297%3As1%3D15883829090...           2
# 9                (3pi, 175#1588383168199#1249748497)           2
#
#                                               byhost
# 0            {.deepintent.com, match.deepintent.com}
# 1            {.deepintent.com, match.deepintent.com}
# 2            {.deepintent.com, match.deepintent.com}
# 3            {.deepintent.com, match.deepintent.com}
# 4            {.deepintent.com, match.deepintent.com}
# 5            {.deepintent.com, match.deepintent.com}
# 6                             {match.deepintent.com}
# 7                                  {.deepintent.com}
# 8  {cms-xch-chicago.33across.com, ssc-cms.33acros...
# 9                                    {.id5-sync.com}

# %%
highlight = pd.merge(byoccur, byhost, on=['namevalue',  'context_id'])
highlight = pd.merge(highlight, byvisit, on=['namevalue',  'context_id'])
highlight[:10]
# Out:
#                                            namevalue  context_id  time_stamp  \
# 0                                    (107, 20200502)           1           5
# 1                                    (108, 20200502)           1           4
# 2                                    (110, 20200502)           1           3
# 3                                    (112, 20200502)           1           2
# 4                                    (113, 20200502)           1           7
# 5                                    (129, 20200502)           1           6
# 6                                    (131, 20200502)           1           6
# 7                                    (131, 20200502)           2           1
# 8  (33x_ps, u%3D76839656056297%3As1%3D15883829090...           2          19
# 9                (3pi, 175#1588383168199#1249748497)           2           1
#
#                                               byhost  \
# 0            {.deepintent.com, match.deepintent.com}
# 1            {.deepintent.com, match.deepintent.com}
# 2            {.deepintent.com, match.deepintent.com}
# 3            {.deepintent.com, match.deepintent.com}
# 4            {.deepintent.com, match.deepintent.com}
# 5            {.deepintent.com, match.deepintent.com}
# 6                             {match.deepintent.com}
# 7                                  {.deepintent.com}
# 8  {cms-xch-chicago.33across.com, ssc-cms.33acros...
# 9                                    {.id5-sync.com}
#
#                           byvname
# 0           {theguardian, forbes}
# 1           {theguardian, forbes}
# 2           {theguardian, forbes}
# 3                        {forbes}
# 4  {theguardian, forbes, nytimes}
# 5           {theguardian, forbes}
# 6           {theguardian, forbes}
# 7                      {medscape}
# 8                         {webmd}
# 9                  {myfitnesspal}

# %%
# select only across contexts
ltd = []
Counter = collections.Counter(highlight.namevalue.tolist())

# %%
for key, value in Counter.items():
    if value == 1:
        ltd.append(key)

# %%
indtd = highlight[highlight['namevalue'].isin(ltd)].index
highlight.drop(indtd, inplace=True)
highlight[:10]
print(highlight.shape)
# Out:
# (409, 5)

# %%
highlight.to_csv("../visualization/sankey-helper-{}.csv".format(exp_num), index=False)

# %%
# import ast

# %%
# hightlight = pd.read_csv('sankey-helper-1.csv', converters={'byhost':ast.literal_eval, 'byvname': ast.literal_eval})

# %%
hightlight[:10]
# Out:
#                                            namevalue  context_id  time_stamp  \
# 0                                ('131', '20200501')           1           8
# 1                                ('131', '20200501')           2           1
# 2  ('A3', 'd=AQABBBoqrF4CEPdY3jmf7y0lqIos6X6BvLMF...           1          37
# 3  ('A3', 'd=AQABBBoqrF4CEPdY3jmf7y0lqIos6X6BvLMF...           2          22
# 4  ('A3', 'd=AQABBPcsrF4CENuOO3pHfRbNXEYpdY8MhvEF...           2           9
# 5  ('A3', 'd=AQABBPcsrF4CENuOO3pHfRbNXEYpdY8MhvEF...           3          12
# 6  ('APID', 'UP5375626e-8bb3-11ea-8a1b-02b46a2b33...           1          18
# 7  ('APID', 'UP5375626e-8bb3-11ea-8a1b-02b46a2b33...           2          20
# 8                           ('APIDTS', '1588341417')           1           2
# 9                           ('APIDTS', '1588341417')           2           6
#
#                                               byhost  \
# 0                    {match.deepintent, .deepintent}
# 1                                      {.deepintent}
# 2  {.yahoo, pr-bh.ybp, ups.analytics, cms.analyti...
# 3      {pr-bh.ybp, .yahoo, ads.yahoo, ups.analytics}
# 4               {.yahoo, beap-bc.yahoo, cookiex.ngd}
# 5                             {sp.analytics, .yahoo}
# 6  {.yahoo, .advertising, pr-bh.ybp, cms.analytic...
# 7  {.advertising, pr-bh.ybp, ups.analytics, pixel...
# 8                                           {.yahoo}
# 9                         {pr-bh.ybp, ups.analytics}
#
#                           byvname
# 0  {theguardian, forbes, nytimes}
# 1                      {medscape}
# 2        {forbes, washingtonpost}
# 3                         {webmd}
# 4        {myfitnesspal, medscape}
# 5                 {colledgeboard}
# 6                        {forbes}
# 7           {myfitnesspal, webmd}
# 8                        {forbes}
# 9                         {webmd}

# %%
keywords = """deepintent
yahoo
advertising
ib-ibi
mookie1
atdmt
casalemedia
exelator
bttrack
doubleclick
contextweb
nr-data
pubmatic
bing
adsrvr
tapad
adsymptotic
scorecardresearch
crwdcntrl
districtm
krxd
1rx
agkn
amazon-adsystem
adentifi
adnxs
spotxchange
rubiconproject
bidr
bluekai
dnacdn
bidswitch
myvisualiq
ipredictive
quantserve
media.net
demdex
everesttech
extend.tv
facebook
openx
mathtag
mxptint
twitter
rlcdn
rkdms
owneriq
sitescout
sharethrough
simpli
taboola
3lift
myvisualiq
turn.com
adform
w55c
zemanta
tribalfusion
linkedin
iasds01
dotomi
appier
acuityplatform
advangelists
mfadsrvr
zorosrv
smartadserver
rfihub
srv
creativecdn
addthis
gumgum
yieldmo"""
keywords = keywords.split("\n")

# %%
# keywords = keywords.split("\n")
keywords
# Out:
# ['deepintent',
#  'yahoo',
#  'advertising',
#  'ib-ibi',
#  'mookie1',
#  'atdmt',
#  'casalemedia',
#  'exelator',
#  'bttrack',
#  'doubleclick',
#  'contextweb',
#  'nr-data',
#  'pubmatic',
#  'bing',
#  'adsrvr',
#  'tapad',
#  'adsymptotic',
#  'scorecardresearch',
#  'crwdcntrl',
#  'districtm',
#  'krxd',
#  '1rx',
#  'agkn',
#  'amazon-adsystem',
#  'adentifi',
#  'adnxs',
#  'spotxchange',
#  'rubiconproject',
#  'bidr',
#  'bluekai',
#  'dnacdn',
#  'bidswitch',
#  'myvisualiq',
#  'ipredictive',
#  'quantserve',
#  'media.net',
#  'demdex',
#  'everesttech',
#  'extend.tv',
#  'facebook',
#  'openx',
#  'mathtag',
#  'mxptint',
#  'twitter',
#  'rlcdn',
#  'rkdms',
#  'owneriq',
#  'sitescout',
#  'sharethrough',
#  'simpli',
#  'taboola',
#  '3lift',
#  'myvisualiq',
#  'turn.com',
#  'adform',
#  'w55c',
#  'zemanta',
#  'tribalfusion',
#  'linkedin',
#  'iasds01',
#  'dotomi',
#  'appier',
#  'acuityplatform',
#  'advangelists',
#  'mfadsrvr',
#  'zorosrv',
#  'smartadserver',
#  'rfihub',
#  'srv',
#  'creativecdn',
#  'addthis',
#  'gumgum',
#  'yieldmo']

# %%
len(keywords)
# Out:
# 73

# %%
nv_ls = hightlight.namevalue.tolist()
origin_hosts = hightlight.byhost.tolist()
origin_web = hightlight.byvname.tolist()
contexts_ls = hightlight.context_id.tolist()

# %%
# origin_web

# %%
dict_ls = collections.defaultdict(set)

# %%
for i in range(1, len(nv_ls)):
    if nv_ls[i-1] != nv_ls[i]:
        continue
    u_hosts = origin_hosts[i].union(origin_hosts[i-1])
    if order.index(contexts_ls[i]) < order.index(contexts_ls[i-1]):
        in_webs = origin_web[i]
        out_webs = origin_web[i-1]
    else:
        in_webs = origin_web[i-1]
        out_webs = origin_web[i]
    for domain in keywords:
        if any(domain in string for string in u_hosts):
            for in_web in in_webs:
                for out_web in out_webs:
                    dict_ls[in_web].add((out_web, domain))

# %%
dict_ls
# Out:
# defaultdict(set,
#             {'medscape': {('cnn', 'rubiconproject'),
#               ('colledgeboard', 'demdex'),
#               ('colledgeboard', 'doubleclick'),
#               ('colledgeboard', 'everesttech'),
#               ('colledgeboard', 'facebook'),
#               ('colledgeboard', 'nr-data'),
#               ('colledgeboard', 'yahoo'),
#               ('edx', 'adsymptotic'),
#               ('edx', 'doubleclick'),
#               ('edx', 'facebook'),
#               ('edx', 'nr-data'),
#               ('forbes', 'deepintent'),
#               ('forbes', 'rubiconproject'),
#               ('harvard', 'doubleclick'),
#               ('harvard', 'facebook'),
#               ('harvard', 'nr-data'),
#               ('jhu', 'doubleclick'),
#               ('jhu', 'facebook'),
#               ('mit', 'doubleclick'),
#               ('nytimes', 'deepintent'),
#               ('nytimes', 'rubiconproject'),
#               ('theguardian', 'deepintent'),
#               ('washingtonpost', 'rubiconproject')},
#              'webmd': {('cnn', 'rubiconproject'),
#               ('forbes', '1rx'),
#               ('forbes', '3lift'),
#               ('forbes', 'adentifi'),
#               ('forbes', 'adform'),
#               ('forbes', 'adnxs'),
#               ('forbes', 'adsrvr'),
#               ('forbes', 'adsymptotic'),
#               ('forbes', 'advertising'),
#               ('forbes', 'agkn'),
#               ('forbes', 'amazon-adsystem'),
#               ('forbes', 'atdmt'),
#               ('forbes', 'bidr'),
#               ('forbes', 'bidswitch'),
#               ('forbes', 'bluekai'),
#               ('forbes', 'bttrack'),
#               ('forbes', 'casalemedia'),
#               ('forbes', 'contextweb'),
#               ('forbes', 'crwdcntrl'),
#               ('forbes', 'demdex'),
#               ('forbes', 'districtm'),
#               ('forbes', 'dnacdn'),
#               ('forbes', 'doubleclick'),
#               ('forbes', 'everesttech'),
#               ('forbes', 'exelator'),
#               ('forbes', 'facebook'),
#               ('forbes', 'ib-ibi'),
#               ('forbes', 'ipredictive'),
#               ('forbes', 'krxd'),
#               ('forbes', 'mathtag'),
#               ('forbes', 'mookie1'),
#               ('forbes', 'mxptint'),
#               ('forbes', 'openx'),
#               ('forbes', 'owneriq'),
#               ('forbes', 'pubmatic'),
#               ('forbes', 'quantserve'),
#               ('forbes', 'rlcdn'),
#               ('forbes', 'rubiconproject'),
#               ('forbes', 'scorecardresearch'),
#               ('forbes', 'sharethrough'),
#               ('forbes', 'simpli'),
#               ('forbes', 'sitescout'),
#               ('forbes', 'spotxchange'),
#               ('forbes', 'srv'),
#               ('forbes', 'taboola'),
#               ('forbes', 'tapad'),
#               ('forbes', 'twitter'),
#               ('forbes', 'w55c'),
#               ('forbes', 'yahoo'),
#               ('forbes', 'zemanta'),
#               ('nytimes', 'rubiconproject'),
#               ('washingtonpost', 'adnxs'),
#               ('washingtonpost', 'adsrvr'),
#               ('washingtonpost', 'amazon-adsystem'),
#               ('washingtonpost', 'bidswitch'),
#               ('washingtonpost', 'casalemedia'),
#               ('washingtonpost', 'districtm'),
#               ('washingtonpost', 'doubleclick'),
#               ('washingtonpost', 'everesttech'),
#               ('washingtonpost', 'krxd'),
#               ('washingtonpost', 'openx'),
#               ('washingtonpost', 'rkdms'),
#               ('washingtonpost', 'rubiconproject'),
#               ('washingtonpost', 'scorecardresearch'),
#               ('washingtonpost', 'sharethrough'),
#               ('washingtonpost', 'sitescout'),
#               ('washingtonpost', 'srv'),
#               ('washingtonpost', 'yahoo')},
#              'myfitnesspal': {('cnn', 'rubiconproject'),
#               ('colledgeboard', 'doubleclick'),
#               ('colledgeboard', 'everesttech'),
#               ('colledgeboard', 'yahoo'),
#               ('edx', 'doubleclick'),
#               ('forbes', 'adform'),
#               ('forbes', 'adnxs'),
#               ('forbes', 'advertising'),
#               ('forbes', 'amazon-adsystem'),
#               ('forbes', 'bidr'),
#               ('forbes', 'bing'),
#               ('forbes', 'bluekai'),
#               ('forbes', 'casalemedia'),
#               ('forbes', 'contextweb'),
#               ('forbes', 'doubleclick'),
#               ('forbes', 'myvisualiq'),
#               ('forbes', 'openx'),
#               ('forbes', 'rubiconproject'),
#               ('forbes', 'scorecardresearch'),
#               ('forbes', 'sharethrough'),
#               ('forbes', 'taboola'),
#               ('forbes', 'yahoo'),
#               ('harvard', 'doubleclick'),
#               ('jhu', 'doubleclick'),
#               ('mit', 'doubleclick'),
#               ('nytimes', 'rubiconproject'),
#               ('washingtonpost', 'adnxs'),
#               ('washingtonpost', 'amazon-adsystem'),
#               ('washingtonpost', 'casalemedia'),
#               ('washingtonpost', 'doubleclick'),
#               ('washingtonpost', 'openx'),
#               ('washingtonpost', 'rubiconproject'),
#               ('washingtonpost', 'scorecardresearch'),
#               ('washingtonpost', 'sharethrough')},
#              'verywellhealth': {('cnn', 'rubiconproject'),
#               ('colledgeboard', 'doubleclick'),
#               ('colledgeboard', 'nr-data'),
#               ('edx', 'doubleclick'),
#               ('edx', 'nr-data'),
#               ('forbes', 'rubiconproject'),
#               ('harvard', 'doubleclick'),
#               ('harvard', 'nr-data'),
#               ('jhu', 'doubleclick'),
#               ('mit', 'doubleclick'),
#               ('nytimes', 'rubiconproject'),
#               ('washingtonpost', 'rubiconproject')},
#              'mayoclinic': {('cnn', 'rubiconproject'),
#               ('forbes', 'bing'),
#               ('forbes', 'doubleclick'),
#               ('forbes', 'mathtag'),
#               ('forbes', 'rubiconproject'),
#               ('forbes', 'scorecardresearch'),
#               ('nytimes', 'rubiconproject'),
#               ('washingtonpost', 'doubleclick'),
#               ('washingtonpost', 'nr-data'),
#               ('washingtonpost', 'rubiconproject'),
#               ('washingtonpost', 'scorecardresearch')}})

# %%
# f = open("dict.txt","w")
# f.write( str(dict_ls) )
# f.close()

# %%
count_dict = collections.defaultdict(int)
for in_node, nodes_set in dict_ls.items():
    for out_node, host in nodes_set:
        count_dict[(in_node, out_node)] += 1

# %%
count_dict
# Out:
# defaultdict(int,
#             {('medscape', 'cnn'): 1,
#              ('medscape', 'edx'): 4,
#              ('medscape', 'nytimes'): 2,
#              ('medscape', 'forbes'): 2,
#              ('medscape', 'harvard'): 3,
#              ('medscape', 'theguardian'): 1,
#              ('medscape', 'colledgeboard'): 6,
#              ('medscape', 'jhu'): 2,
#              ('medscape', 'mit'): 1,
#              ('medscape', 'washingtonpost'): 1,
#              ('webmd', 'cnn'): 1,
#              ('webmd', 'forbes'): 49,
#              ('webmd', 'washingtonpost'): 17,
#              ('webmd', 'nytimes'): 1,
#              ('myfitnesspal', 'cnn'): 1,
#              ('myfitnesspal', 'forbes'): 17,
#              ('myfitnesspal', 'washingtonpost'): 8,
#              ('myfitnesspal', 'edx'): 1,
#              ('myfitnesspal', 'nytimes'): 1,
#              ('myfitnesspal', 'colledgeboard'): 3,
#              ('myfitnesspal', 'mit'): 1,
#              ('myfitnesspal', 'harvard'): 1,
#              ('myfitnesspal', 'jhu'): 1,
#              ('verywellhealth', 'forbes'): 1,
#              ('verywellhealth', 'harvard'): 2,
#              ('verywellhealth', 'cnn'): 1,
#              ('verywellhealth', 'colledgeboard'): 2,
#              ('verywellhealth', 'edx'): 2,
#              ('verywellhealth', 'nytimes'): 1,
#              ('verywellhealth', 'jhu'): 1,
#              ('verywellhealth', 'washingtonpost'): 1,
#              ('verywellhealth', 'mit'): 1,
#              ('mayoclinic', 'forbes'): 5,
#              ('mayoclinic', 'cnn'): 1,
#              ('mayoclinic', 'washingtonpost'): 4,
#              ('mayoclinic', 'nytimes'): 1})
