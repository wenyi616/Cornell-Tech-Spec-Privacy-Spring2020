# %%
import numpy as np
import pandas as pd
import sqlite3

# %%
exp_path = "./raw-data/4-28/crawl-data.sqlite"

# %%
conn = sqlite3.connect(exp_path)

# %%
javascript_cookies = pd.read_sql_query("select visit_id, record_type, change_cause, host, name, value, time_stamp from javascript_cookies;", conn)
http_responses = pd.read_sql_query("select visit_id, url, method, headers, time_stamp from http_responses where response_status == 200;", conn)
http_requests = pd.read_sql_query("select visit_id, headers, referrer, Url, time_stamp from http_requests;", conn)
javascript = pd.read_sql_query("select visit_id, script_url, symbol, operation, value, arguments, time_stamp from javascript;", conn)
site_visits = pd.read_sql_query("select visit_id, site_url from site_visits;", conn)

# %%
conn.close()

# %%
site_visits
# Out:
#     visit_id                                           site_url
# 0          1                            http://www.nytimes.com/
# 1          2           https://www.nytimes.com/section/business
# 2          3  https://www.nytimes.com/2020/04/26/business/ca...
# 3          4             https://www.nytimes.com/section/health
# 4          5  https://www.nytimes.com/2020/04/21/business/sp...
# 5          6                             https://www.webmd.com/
# 6          7             https://www.webmd.com/baby/default.htm
# 7          8  https://www.webmd.com/skin-problems-and-treatm...
# 8          9             https://www.webmd.com/lung/coronavirus
# 9         10                https://www.webmd.com/drugs/2/index
# 10        11                          https://www.berkeley.edu/
# 11        12                     http://diversity.berkeley.edu/
# 12        13  https://www.berkeley.edu/about/history-discove...
# 13        14                 https://www.berkeley.edu/directory
# 14        15  https://engineering.berkeley.edu/engineering-f...

# %%
names = list(map(lambda x: x.split('.')[1], list(site_visits.site_url)))
websites = list( names[i] for i in [0,5,10])
websites
# Out:
# ['nytimes', 'webmd', 'berkeley']

# %%
# 0 - 1,2,3,4,5
# 1 - 6,7,8,9,10
# 2 - 11,12,13,14,15

context_number = 2

# %%
############################# cookies #############################

# %%
js_cookies = javascript_cookies[javascript_cookies.visit_id.isin(range(context_number*5+1, context_number*5+6))]
js_cookies
# Out:
#       visit_id       record_type change_cause                       host  \
# 1540        11  added-or-changed     explicit              .berkeley.edu
# 1541        11  added-or-changed     explicit              .berkeley.edu
# 1542        11  added-or-changed     explicit              .berkeley.edu
# 1543        11  added-or-changed     explicit              .berkeley.edu
# 1544        11  added-or-changed     explicit              .berkeley.edu
# ...        ...               ...          ...                        ...
# 1641        15  added-or-changed     explicit  .engineering.berkeley.edu
# 1642        15  added-or-changed     explicit  .engineering.berkeley.edu
# 1643        15  added-or-changed     explicit  .engineering.berkeley.edu
# 1644        15  added-or-changed     explicit  .engineering.berkeley.edu
# 1645        15  added-or-changed     explicit  .engineering.berkeley.edu
#
#                     name                                              value  \
# 1540              __utma  41573937.991307700.1588083347.1588083347.15880...
# 1541              __utmb                           41573937.0.10.1588083347
# 1542              __utmc                                           41573937
# 1543              __utmz  41573937.1588083347.1.1.utmcsr=(direct)|utmccn...
# 1544              __utmt                                                  1
# ...                  ...                                                ...
# 1641                 _ga                         GA1.3.991307700.1588083347
# 1642                _gid                        GA1.3.2145931961.1588083372
# 1643  _gat_UA-4659861-10                                                  1
# 1644  _gat_UA-4659861-11                                                  1
# 1645              nmstat                                      1588083484512
#
#                     time_stamp
# 1540  2020-04-28T14:15:46.729Z
# 1541  2020-04-28T14:15:46.730Z
# 1542  2020-04-28T14:15:46.732Z
# 1543  2020-04-28T14:15:46.734Z
# 1544  2020-04-28T14:15:46.745Z
# ...                        ...
# 1641  2020-04-28T14:17:39.197Z
# 1642  2020-04-28T14:17:39.198Z
# 1643  2020-04-28T14:17:39.460Z
# 1644  2020-04-28T14:17:39.485Z
# 1645  2020-04-28T14:17:39.851Z
#
# [106 rows x 7 columns]

# %%
# js_cookies.host.unique()

# %%
cookies_dict = {
  "nytimes": 'nytimes|nyt',
  "webmd": 'webmd',
  "berkeley": 'berkeley'
}

# %%
# pattern = cookies_dict.get(websites[context_number])
# pattern

# first party cookies (filter by host)
js_cookies_first = js_cookies[js_cookies.host.str.contains(cookies_dict.get(websites[context_number]))]

# third party cookies (filter by host)
js_cookies_third = js_cookies[~js_cookies.host.str.contains(cookies_dict.get(websites[context_number]))]

# print(js_cookies_first.shape)
# print(js_cookies_third.shape)

# %%
js_cookies_first.to_csv('1-'+str(context_number+1)+'-FirstCookies.csv', index=False)

# %%
js_cookies_third.to_csv('1-'+str(context_number+1)+'-ThirdCookies.csv', index=False)

# %%
# concat big cookies

# js_cookies_third['context_id'] = 3
# temp = js_cookies_third
# temp = temp.append(js_cookies_third)
# temp
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#       visit_id       record_type change_cause          host  \
# 6            1  added-or-changed     explicit    .media.net
# 9            1  added-or-changed     explicit   .google.com
# 10           1           deleted    overwrite   .google.com
# 11           1  added-or-changed     explicit   .google.com
# 12           1           deleted    overwrite   .google.com
# ...        ...               ...          ...           ...
# 1630        13  added-or-changed     explicit  .youtube.com
# 1631        13           deleted    overwrite  .youtube.com
# 1632        13  added-or-changed     explicit  .youtube.com
# 1633        13           deleted    overwrite  .youtube.com
# 1634        13  added-or-changed     explicit  .youtube.com
#
#                     name                                              value  \
# 6             visitor-id                             2310846292182041000V10
# 9                    NID  203=qFA3SyC0fwFwcvqY7MI3nsCFP8YjZRERPiOGOXOwmf...
# 10                   NID  203=wrQi5gqbpIWCBES0bmmyn_WjQLonOi99hLCLqijx1k...
# 11                   NID  203=wrQi5gqbpIWCBES0bmmyn_WjQLonOi99hLCLqijx1k...
# 12                   NID  203=bHHssFauB8Gn7J19HHvYAtfqgk-pvmGVbRLDCNL385...
# ...                  ...                                                ...
# 1630                 YSC                                        c6ja9hl2gnE
# 1631  VISITOR_INFO1_LIVE                                        7rgtR3AaOps
# 1632  VISITOR_INFO1_LIVE                                        7rgtR3AaOps
# 1633                 YSC                                        Y0NmQJtFrd4
# 1634                 YSC                                        Y0NmQJtFrd4
#
#                     time_stamp  context_id
# 6     2020-04-28T14:10:30.115Z           1
# 9     2020-04-28T14:10:31.005Z           1
# 10    2020-04-28T14:10:31.026Z           1
# 11    2020-04-28T14:10:31.026Z           1
# 12    2020-04-28T14:10:31.029Z           1
# ...                        ...         ...
# 1630  2020-04-28T14:16:43.526Z           3
# 1631  2020-04-28T14:16:43.530Z           3
# 1632  2020-04-28T14:16:43.530Z           3
# 1633  2020-04-28T14:16:43.530Z           3
# 1634  2020-04-28T14:16:43.531Z           3
#
# [609 rows x 8 columns]

# %%
# temp.to_csv('1-ThirdCookies.csv', index=False)

# %%
js_1 = javascript[javascript.visit_id == 1]
js_2 = javascript[javascript.visit_id == 2]
js_3 = javascript[javascript.visit_id == 3]

# %%
# third party js (filter by script_url)
js_2.script_url.unique()
# Out:
# array(['https://s.go-mpulse.net/boomerang/7TA4C-EHAW8-JP6NL-WZFXG-NSUSJ',
#        'https://gum.criteo.com/syncframe?topUrl=www.webmd.com#{%22sid%22:{%22value%22:null,%22origin%22:0},%22uid%22:{%22value%22:null,%22origin%22:0},%22optout%22:{%22value%22:false,%22origin%22:0},%22bundle%22:{%22value%22:null,%22origin%22:0},%22lwid%22:{%22value%22:null,%22origin%22:0},%22tld%22:%22webmd.com%22,%22cw%22:true,%22origin%22:%22rtus%22,%22topUrl%22:%22www.webmd.com%22,%22rtusCallerId%22:321}',
#        'https://js.webmd.com/dtmcms/live/webmd/PageBuilder_Assets/JS/responsive_scripts153.js',
#        'https://assets.adobedtm.com/dbc05520d4f49caf542bbd26c65a4b463263a2c9/satelliteLib-99a8aacf5aa69747ae52c15253c9133d2fb09587.js',
#        'https://securepubads.g.doubleclick.net/tag/js/gpt.js',
#        'https://contextual.media.net/dmedianet.js?cid=8CUU54RQD&https=1',
#        'https://contextual.media.net/bidexchange.js?cid=8CU66J63J&version=3.2&https=1',
#        'https://assets.adobedtm.com/dbc05520d4f49caf542bbd26c65a4b463263a2c9/mbox-contents-ebaef46ec7b7354eb057e66308e35f0ebbe97370.js',
#        'https://c.amazon-adsystem.com/aax2/apstag.js',
#        'https://securepubads.g.doubleclick.net/gpt/pubads_impl_2020041602.js?21065915',
#        'https://ibclick.stream/assets/js/track/dist/js/v1/tracker.min.js',
#        'https://contextual.media.net/pubcid.php?itype=HB&cb=window.advBidxc.mnetCoRtusId',
#        'https://gum.criteo.com/sync?r=2&c=321&j=window.advBidxc.mnetRtusId',
#        'https://cdn.tt.omtrdc.net/cdn/target.js',
#        'https://www.webmd.com/',
#        'https://img.webmd.com/bi_common/bi_consumer.js?d=4/22/2020',
#        'https://www.googleadservices.com/pagead/conversion_async.js',
#        'https://js.webmd.com/dtmcms/live/webmd/PageBuilder_Assets/JS_static/responsive_scripts_body.js',
#        'https://connect.facebook.net/en_US/sdk.js#xfbml=1&version=v3.1',
#        'https://www.redditstatic.com/ads/pixel.js',
#        'https://connect.facebook.net/en_US/fbevents.js',
#        'https://b-code.liadm.com/a-00xm.min.js',
#        'https://consent.trustarc.com/notice?domain=webmd.com&c=teconsent&js=nj&noticeType=bb&text=true&cookieLink=https%3A%2F%2Fwww.webmd.com%2Fabout-webmd-policies%2Fabout-california-privacy-policy&privacypolicylink=https%3A%2F%2Fwww.webmd.com%2Fabout-webmd-policies%2Fabout-privacy-policy',
#        'https://connect.facebook.net/en_US/sdk.js?hash=17752931563cb41127c56b23e4097f7d',
KlZ-qpvuIxhqJYVa3wP-geErabSb5snoubgYQ7ISjWddwp9ytM5V32QblsPgeDhZ-fLG38FJqVcopKjpg-XgHfr-yDlXGaHrJ6U5e%26sig%3DCg0ArKJSzBMwZlOaRZxZEAE%26urlfix%3D1%26adurl%3D;dc_rfl=1,https%3A%2F%2Fwww.webmd.com%2F$0;xdt=0;crlt=uUlsym)PZ9;osda=2;sttr=3040;prcl=s?',
#        'https://z.moatads.com/webmddfp936579382290/moatad.js#moatClientLevel1=4862803161&moatClientLevel2=2685151144&moatClientLevel3=5347387581&moatClientLevel4=138309097785&moatClientSlicer1=3312554&moatClientSlicer2=25989674&zMoatMNView=&zMoatMNRefresh=&zMoatPG=&zMoatECD=0&zMoatMGV=&zMoatMMV=&zMoatMSafety=&zMoatMData=&zMoatCC=83&zMoatLeaf=17008&zMoatPT=1728&zMoatBP=1&zMoatURI=/default&zMoatVALUE=158760625135419802&zMoatShield=&zMoatPS=121&zMoatFR='],
#       dtype=object)

# %%
# https://webmd.demdex.net

# %%
js_dict = {
  "nytimes": ['https://static01.nyt.com', 'https://www.nytimes.com', 'https://myaccount.nytimes.com'],
  "webmd": ['https://js.webmd.com', 'https://www.webmd.com', 'https://img.webmd.com', \
            'https://survey.o.webmd.com', 'https://js.staging.webmd.com'],
  "berkeley": ['https://www.berkeley.edu', 'https://bconnected.berkeley.edu', 'https://give.berkeley.edu', \
               'https://news.berkeley.edu', 'https://greatergood.berkeley.edu', 'https://matrix.berkeley.edu'\
              , 'https://irle.berkeley.edu']
}

# %%
js_third_1 = js_1
print(js_third_1.shape)
for temp in js_dict.get(names[0]):
    print(temp)
    js_third_1 = js_third_1[-js_third_1.script_url.str.startswith(temp)]
    print(js_third_1.shape)
    
print("***********************************")

js_third_2 = js_2
print(js_third_2.shape)
for temp in js_dict.get(names[1]):
    print(temp)
    js_third_2 = js_third_2[-js_third_2.script_url.str.startswith(temp)]
    print(js_third_2.shape)
    
print("***********************************")

js_third_3 = js_3
print(js_third_3.shape)
for temp in js_dict.get(names[2]):
    print(temp)
    js_third_3 = js_third_3[-js_third_3.script_url.str.startswith(temp)]
    print(js_third_3.shape)
    
print("***********************************")
# Out:
# (15724, 7)
# https://static01.nyt.com
# (15390, 7)
# https://www.nytimes.com
# (12854, 7)
# https://myaccount.nytimes.com
# (12853, 7)
# ***********************************
# (11654, 7)
# https://js.webmd.com
# (10791, 7)
# https://www.webmd.com
# (10100, 7)
# https://img.webmd.com
# (9592, 7)
# https://survey.o.webmd.com
# (9592, 7)
# https://js.staging.webmd.com
# (9592, 7)
# ***********************************
# (1246, 7)
# https://www.berkeley.edu
# (646, 7)
# https://bconnected.berkeley.edu
# (641, 7)
# https://give.berkeley.edu
# (630, 7)
# https://news.berkeley.edu
# (624, 7)
# https://greatergood.berkeley.edu
# (624, 7)
# https://matrix.berkeley.edu
# (616, 7)
# https://irle.berkeley.edu
# (616, 7)
# ***********************************

# %%
# https://contextual.media.net/bidexchange.js?cid=8CU2553YN&dn=www.nytimes.com&https=1',

# double check
# nytimes

temp = js_third_1
temp = temp[-temp.script_url.str.contains('contextual')]
temp = temp[-temp.script_url.str.contains('criteo')]
list(temp[temp.script_url.str.contains(names[0])].script_url)

# %%
# double check
# webmd

temp = js_third_2
temp = temp[-temp.script_url.str.contains('moatads')]
temp = temp[-temp.script_url.str.contains('criteo')]
temp = temp[-temp.script_url.str.contains('contextual')]
temp = temp[-temp.script_url.str.contains('doubleclick')]
temp = temp[-temp.script_url.str.contains('trustarc')]
temp = temp[-temp.script_url.str.contains('doubleverify')]
list(temp[temp.script_url.str.contains(names[1])].script_url)

# %%
# double check
# berkeley

temp = js_third_3
temp = temp[-temp.script_url.str.contains('sharethis')]
list(temp[temp.script_url.str.contains(names[2])].script_url)
# Out:
# []

# %%
js_third_1.to_csv('1-1-js.csv', index=False)
js_third_2.to_csv('1-2-js.csv', index=False)
js_third_3.to_csv('1-3-js.csv', index=False)

# %%
# HTTP REQUEST

def get_host_from_headers(x):
    temp = x.replace('"','').split('],[')
    for t in temp:
            pair = t.replace(']]','').replace('[[','').split(',')
            if "Host" in pair:
                host_value = pair[1]
    return host_value

def get_cookies_from_headers(x):
    ls = x.replace('"','').split('],[')
    for l in ls:
        ta = l.replace(']]','').split(',')
        if "Cookie" in ta:
            return ta[-1]
    return ''

# %%
# temp = list(map(lambda x: get_host_from_headers(x), http_requests.headers.tolist()))

# http_requests["host"] = temp

# http_requests


# # http_req_cookies = list(map(lambda x: get_cookies_from_headers(x), http_requests.headers.tolist()))

# # http_requests["cookies"] = http_req_cookies

# # http_requests
# Out:
#       visit_id                                            headers  \
# 0            1  [["Host","www.nytimes.com"],["User-Agent","Moz...
# 1            1  [["Host","g1.nyt.com"],["User-Agent","Mozilla/...
# 2            1  [["Host","www.nytimes.com"],["User-Agent","Moz...
# 3            1  [["Host","www.nytimes.com"],["User-Agent","Moz...
# 4            1  [["Host","static01.nyt.com"],["User-Agent","Mo...
# ...        ...                                                ...
# 3959         3  [["Host","p.typekit.net"],["User-Agent","Mozil...
# 3960         3  [["Host","s.ytimg.com"],["User-Agent","Mozilla...
# 3961         3  [["Host","connect.facebook.net"],["User-Agent"...
# 3962         3  [["Host","8343.global.siteimproveanalytics.io"...
# 3963         3  [["Host","www.facebook.com"],["User-Agent","Mo...
#
#                        referrer  \
# 0
# 1      https://www.nytimes.com/
# 2      https://www.nytimes.com/
# 3      https://www.nytimes.com/
# 4      https://www.nytimes.com/
# ...                         ...
# 3959  https://www.berkeley.edu/
# 3960  https://www.berkeley.edu/
# 3961  https://www.berkeley.edu/
# 3962  https://www.berkeley.edu/
# 3963  https://www.berkeley.edu/
#
#                                                     url  \
# 0                              https://www.nytimes.com/
# 1     https://g1.nyt.com/fonts/css/web-fonts.5810def...
# 2     https://www.nytimes.com/vi-assets/static-asset...
# 3     https://www.nytimes.com/vi-assets/static-asset...
# 4     https://static01.nyt.com/images/2020/04/22/us/...
# ...                                                 ...
# 3959  https://p.typekit.net/p.gif?s=1&k=zpy2xov&ht=t...
# 3960  https://s.ytimg.com/yts/jsbin/www-widgetapi-vf...
# 3961  https://connect.facebook.net/en_US/all.js?hash...
# 3962  https://8343.global.siteimproveanalytics.io/im...
# 3963  https://www.facebook.com/x/oauth/status?client...
#
#                     time_stamp  \
# 0     2020-04-23T01:40:02.996Z
# 1     2020-04-23T01:40:03.197Z
# 2     2020-04-23T01:40:03.198Z
# 3     2020-04-23T01:40:03.245Z
# 4     2020-04-23T01:40:03.246Z
# ...                        ...
# 3959  2020-04-23T01:46:38.971Z
# 3960  2020-04-23T01:46:38.974Z
# 3961  2020-04-23T01:46:38.982Z
# 3962  2020-04-23T01:46:39.071Z
# 3963  2020-04-23T01:46:39.120Z
#
#                                                 cookies  \
# 0
# 1
# 2     nyt-a=wb94G3hGddL8COpQIeiBqE; nyt-gdpr=0; nyt-...
# 3     nyt-a=wb94G3hGddL8COpQIeiBqE; nyt-gdpr=0; nyt-...
# 4
# ...                                                 ...
# 3959
# 3960
# 3961
# 3962  siteimproveses=5b6b646a-380a-4c16-9e20-763b183...
# 3963
#
#                                      host
# 0                         www.nytimes.com
# 1                              g1.nyt.com
# 2                         www.nytimes.com
# 3                         www.nytimes.com
# 4                        static01.nyt.com
# ...                                   ...
# 3959                        p.typekit.net
# 3960                          s.ytimg.com
# 3961                 connect.facebook.net
# 3962  8343.global.siteimproveanalytics.io
# 3963                     www.facebook.com
#
# [3964 rows x 7 columns]

# %%
http_request_1 = http_requests[http_requests.visit_id == 1]
http_request_2 = http_requests[http_requests.visit_id == 2]
http_request_3 = http_requests[http_requests.visit_id == 3]

# %%
# http_request (filter by url)
# nytimes
# http_request_1[http_request_1.url.str.contains(names[0])].url.unique()

# %%
http_dict = {
  "nytimes": ['https://www.nytimes.com', 'https://nytimes.com', 'https://a.et.nytimes', 'https://et.nytimes.com','https://static01.nyt.com', \
              'https://a.nytimes.com' ,'https://g1.nyt.com', 'https://als-svc.nytimes.com', 'https://content.api.nytimes.com', 'https://purr.nytimes.com',\
              'https://samizdat-graphql.nytimes.com',  'https://meter-svc.nytimes.com',  'https://mwcm.nytimes.com',  'https://myaccount.nytimes.com'],
  "webmd": ['https://www.webmd.com', 'https://css.webmd.com', 'https://js.webmd.com','https://img.webmd.com',  'http://img.webmd.com',\
            'https://ssl.o.webmd.com' , 'https://survey.o.webmd.com', 'https://js.staging.webmd.com', 'https://css.staging.webmd.com'],
  "berkeley": ['https://www.berkeley.edu', 'https://news.berkeley.edu', 'https://matrix.berkeley.edu', 'http://give.berkeley.edu', \
               'http://bconnected.berkeley.edu', 'https://bconnected.berkeley.edu', 'https://greatergood.berkeley.edu', \
               'https://irle.berkeley.edu',  'https://publichealth.berkeley.edu', 'https://calparents.berkeley.edu',  \
               'http://vcue.berkeley.edu','https://vcue.berkeley.edu', 'http://events.berkeley.edu','https://events.berkeley.edu']
}

# %%
http_request_third_1 = http_request_1
print(http_request_third_1.shape)
for temp in http_dict.get(names[0]):
    print(temp)
    http_request_third_1 = http_request_third_1[-http_request_third_1.url.str.startswith(temp)]
    print(http_request_third_1.shape)
    
print("***********************************")

http_request_third_2 = http_request_2
print(http_request_third_2.shape)
for temp in http_dict.get(names[1]):
    print(temp)
    http_request_third_2 = http_request_third_2[-http_request_third_2.url.str.startswith(temp)]
    print(http_request_third_2.shape)
    
print("***********************************")


http_request_third_3 = http_request_3
print(http_request_third_3.shape)
for temp in http_dict.get(names[2]):
    print(temp)
    http_request_third_3 = http_request_third_3[-http_request_third_3.url.str.startswith(temp)]
    print(http_request_third_3.shape)
    
print("***********************************")
# Out:
# (1380, 7)
# https://www.nytimes.com
# (1165, 7)
# https://nytimes.com
# (1160, 7)
# https://a.et.nytimes
# (1060, 7)
# https://et.nytimes.com
# (992, 7)
# https://static01.nyt.com
# (933, 7)
# https://a.nytimes.com
# (928, 7)
# https://g1.nyt.com
# (910, 7)
# https://als-svc.nytimes.com
# (905, 7)
# https://content.api.nytimes.com
# (859, 7)
# https://purr.nytimes.com
# (854, 7)
# https://samizdat-graphql.nytimes.com
# (842, 7)
# https://meter-svc.nytimes.com
# (838, 7)
# https://mwcm.nytimes.com
# (834, 7)
# https://myaccount.nytimes.com
# (831, 7)
# ***********************************
# (1989, 7)
# https://www.webmd.com
# (1967, 7)
# https://css.webmd.com
# (1945, 7)
# https://js.webmd.com
# (1933, 7)
# https://img.webmd.com
# (1684, 7)
# http://img.webmd.com
# (1684, 7)
# https://ssl.o.webmd.com
# (1676, 7)
# https://survey.o.webmd.com
# (1676, 7)
# https://js.staging.webmd.com
# (1676, 7)
# https://css.staging.webmd.com
# (1676, 7)
# ***********************************
# (595, 7)
# https://www.berkeley.edu
# (526, 7)
# https://news.berkeley.edu
# (455, 7)
# https://matrix.berkeley.edu
# (356, 7)
# http://give.berkeley.edu
# (355, 7)
# http://bconnected.berkeley.edu
# (355, 7)
# https://bconnected.berkeley.edu
# (312, 7)
# https://greatergood.berkeley.edu
# (312, 7)
# https://irle.berkeley.edu
# (312, 7)
# https://publichealth.berkeley.edu
# (312, 7)
# https://calparents.berkeley.edu
# (312, 7)
# http://vcue.berkeley.edu
# (312, 7)
# https://vcue.berkeley.edu
# (312, 7)
# http://events.berkeley.edu
# (312, 7)
# https://events.berkeley.edu
# (312, 7)
# ***********************************

# %%
http_request_third_1.to_csv('1-1-httprequest.csv', index=False)
http_request_third_2.to_csv('1-2-httprequest.csv', index=False)
http_request_third_3.to_csv('1-3-httprequest.csv', index=False)

# %%
experiments_df = pd.DataFrame(pd.read_csv('experiments.csv')  , columns = ['Exp', 'Websites']) 
experiments_df
# Out:
# Empty DataFrame
# Columns: [Exp, Websites]
# Index: []

# %%
experiment_num = 1

temp = pd.DataFrame([[experiment_num, names]], columns = ['Exp', 'Websites']) 

experiments_df = pd.concat([experiments_df,temp])

experiments_df
# Out:
#   Exp                    Websites
# 0   1  [nytimes, webmd, berkeley]

# %%
experiments_df.to_csv('experiments.csv', index=False)
