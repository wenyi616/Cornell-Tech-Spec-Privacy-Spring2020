# %%
import pandas as pd
import numpy as np

# %%
unique_huge = pd.read_csv("hugecookies/hugecookies-1.csv")

# %%
ndex = unique_huge[unique_huge['name'].isin(['expires', 'path'])].index

# %%
unique_huge.drop(ndex, inplace=True)

# %%
unique_huge['namevalue'] = list(map(lambda a, b: (a, b), unique_huge["name"].astype(str), unique_huge["value"].astype(str)))
temp1 = unique_huge.groupby(["namevalue", "context_id"], as_index = False).first()

# %%
temp2 = unique_huge.groupby(["namevalue", "context_id"], as_index = False)['time_stamp'].count()

#temp2.to_csv("unique_namevalue-3.csv", index=False)

# %%
# group by cookie name and context_id
temp3 = unique_huge.groupby(["name", "context_id"], as_index = False)['time_stamp'].count()

# %%
# group by cookie value and context_id
temp3 = unique_huge.groupby(["value", "context_id"], as_index = False)['time_stamp'].count()

# %%
temp4 = pd.DataFrame(unique_huge.groupby(["namevalue", "context_id"], as_index = False)['host'].apply(list))

# %%
temp4
# Out:
#                                                                                                                0
# namevalue                                          context_id
# (131, 20200428)                                    1                                           [.deepintent.com]
# (A3, d=AQABBF45qF4CEEgvPTiD59Nt7NBRJgIJ_7MFEgEB... 1                                 [.yahoo.com, ads.yahoo.com]
# (A3, d=AQABBF45qF4CEEgvPTiD59Nt7NBRJgIJ_7MFEgEB... 1           [.yahoo.com, .yahoo.com, .yahoo.com, .yahoo.co...
#                                                    2           [.yahoo.com, .yahoo.com, .yahoo.com, .yahoo.co...
# (AA003, AXy9mPzBp96O9WOWuGOGv92dLTg5DUX_Gn8VbJw... 2                                                [.atdmt.com]
# (AC, 1)                                            1           [.iasds01.com, sc.iasds01.com, sc.iasds01.com,...
#                                                    2           [sc.iasds01.com, sc.iasds01.com, sc.iasds01.co...
# (AMCVS_16AD4362526701720A490D45%40AdobeOrg, 1)     2           [https://assets.adobedtm.com/dbc05520d4f49caf5...
# (AMCV_16AD4362526701720A490D45%40AdobeOrg, 1585... 2           [https://assets.adobedtm.com/dbc05520d4f49caf5...
# (AMCV_16AD4362526701720A490D45%40AdobeOrg, 1585... 2           [https://assets.adobedtm.com/dbc05520d4f49caf5...
# (AMCV_16AD4362526701720A490D45%40AdobeOrg, 1585... 2           [https://assets.adobedtm.com/dbc05520d4f49caf5...
# (AMCV_16AD4362526701720A490D45%40AdobeOrg, 1585... 2           [https://assets.adobedtm.com/dbc05520d4f49caf5...
# (AMCV_16AD4362526701720A490D45%40AdobeOrg, 1585... 2           [https://assets.adobedtm.com/dbc05520d4f49caf5...
# (AMCV_16AD4362526701720A490D45%40AdobeOrg, 1585... 2           [https://assets.adobedtm.com/dbc05520d4f49caf5...
# (AMCV_16AD4362526701720A490D45%40AdobeOrg, 1585... 2           [https://assets.adobedtm.com/dbc05520d4f49caf5...
# (AMCV_16AD4362526701720A490D45%40AdobeOrg, nan)    2           [https://assets.adobedtm.com/dbc05520d4f49caf5...
# (APID, UP622623e4-895a-11ea-90bf-0a6e783606cf)     2           [.advertising.com, .yahoo.com, pixel.advertisi...
# (APIDTS, 1588083187)                               2                                                [.yahoo.com]
# (ASP.NET_SessionId, fhqj5szv4qv5zz4jxk0lcc2g)      2                            [ib.mookie1.com, ib.mookie1.com]
# (ASP.NET_SessionId, ibutu2uxafh3raf55bvrmybi)      2                      [global.ib-ibi.com, global.ib-ibi.com]
# (ATN, 1.1588083312.6829424160849739526.AYJTMO3w... 2                                                [.atdmt.com]
# (AWSALB, 6RM1kzHjX3IxhOpli1tf8Ttolb/rM2u1btWYTp... 2                [www.surveywriter.net, www.surveywriter.net]
# (AWSALB, UTSHHh32QKXLUvJ6dx4Yq8kIMKXwk6uy3eyyHX... 2                [www.surveywriter.net, www.surveywriter.net]
# (AWSALB, ukw7Ke1T53wOPMUmiwZx5ZMD9b2ufDfU410Qvs... 2                                      [www.surveywriter.net]
# (AWSALBCORS, 6RM1kzHjX3IxhOpli1tf8Ttolb/rM2u1bt... 2                [www.surveywriter.net, www.surveywriter.net]
# (AWSALBCORS, UTSHHh32QKXLUvJ6dx4Yq8kIMKXwk6uy3e... 2                [www.surveywriter.net, www.surveywriter.net]
# (AWSALBCORS, ukw7Ke1T53wOPMUmiwZx5ZMD9b2ufDfU41... 2                                      [www.surveywriter.net]
# (AWSELB, 79A3199D10510369DCF60AC124D33FFF155635... 3           [8343.global.siteimproveanalytics.io, 8343.glo...
# (B, b7vo909fageau&b=3&s=pu)                        1           [.yahoo.com, .yahoo.com, .yahoo.com, .yahoo.co...
#                                                    2           [.yahoo.com, .yahoo.com, .yahoo.com, .yahoo.co...
# ...                                                                                                          ...
# (tuuid_lu, 1588083034)                             1                           [.bidswitch.net, x.bidswitch.net]
# (tuuid_lu, 1588083035)                             1           [.bidswitch.net, .bidswitch.net, .perf-serving...
#                                                    2           [x.bidswitch.net, x.bidswitch.net, x.bidswitch...
# (tuuid_lu, 1588083036)                             1                      [.perf-serving.com, .perf-serving.com]
# (tuuid_lu, 1588083180)                             2                                   [.pswec.com, t.pswec.com]
# (tuuid_lu, 1588083183)                             2                           [.mfadsrvr.com, rtb.mfadsrvr.com]
# (u, oW3Z6M8xneycbA0Z5WVC)                          1                     [.creativecdn.com, ams.creativecdn.com]
# (ud, "eJxrXxzq6XKLQcHA0sTcMMXA2NDSKMnMIM0y0SLRM... 2                                             [.exelator.com]
# (ud, "eJxrXxzq6XKLQcHA0sTcMMXA2NDSKMnMIM0y0SLRM... 2                              [.exelator.com, .exelator.com]
# (ud, \eJxrXxzq6XKLQcHA0sTcMMXA2NDSKMnMIM0y0SLRM... 2                                       [loadus.exelator.com]
# (ui, {%22vtime%22:26468052%2C%22expmatch%22:1})    2           [https://gum.criteo.com/sync?r=2&c=321&j=windo...
# (ui, {%22vtime%22:26468052})                       2           [https://assets.adobedtm.com/dbc05520d4f49caf5...
# (ui, {%22vtime%22:26468053%2C%22expmatch%22:1})    2           [https://assets.adobedtm.com/dbc05520d4f49caf5...
# (ui, {%22vtime%22:26468054%2C%22expmatch%22:1})    2           [https://assets.adobedtm.com/dbc05520d4f49caf5...
# (ui, {%22vtime%22:26468055%2C%22expmatch%22:1})    2           [https://assets.adobedtm.com/dbc05520d4f49caf5...
# (uid, 2558098555938012379)                         1                                                 [.turn.com]
#                                                    2           [.turn.com, .turn.com, .turn.com, .turn.com, d...
# (uid, 5ea839eb9a327579)                            2           [.addthis.com, .addthis.com, .addthis.com, x.d...
# (uid, 7056994258435701774)                         1                                [.adform.net, c1.adform.net]
# (uuid, 7f675ea8-395e-4900-ac28-995748e08e07)       1           [.mathtag.com, sync.mathtag.com, sync.mathtag....
#                                                    2           [sync.mathtag.com, sync.mathtag.com, sync.math...
# (uuid2, 4216705963238673072)                       1           [.adnxs.com, .adnxs.com, .adnxs.com, ib.adnxs....
#                                                    2           [.adnxs.com, .adnxs.com, .adnxs.com, .adnxs.co...
# (visitor-id, 2310846292182041000V10)               1           [.media.net, contextual.media.net, cdneast2-xc...
#                                                    2           [contextual.media.net, contextual.media.net, c...
# (walley, GA1.2.1168632966.1588083035)              1           [https://www.google-analytics.com/analytics.js...
# (walley_gid, GA1.2.2135142154.1588083035)          1           [https://www.google-analytics.com/analytics.js...
# (wfivefivec, 6ZmmRprj1JtqWW5)                      1           [.w55c.net, .w55c.net, .w55c.net, .w55c.net, ....
# (yieldmo_id, g452091d2e664168ba8b%7C15880831875... 2                                              [.yieldmo.com]
# (zuid, DQzoZFTJLyl_Me7UCPJh)                       2           [.zemanta.com, .zemanta.com, .zemanta.com, b1s...
#
# [573 rows x 1 columns]

# %%
temp4.to_csv("hosts_lists.csv")
