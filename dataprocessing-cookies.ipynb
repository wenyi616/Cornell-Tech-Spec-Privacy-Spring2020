# %%
import numpy as np
import pandas as pd
import math
import sys

# %%
def extract_from_jscookies(cookies):
    set_cookies = cookies[["context_id", "host", "name", "value", "time_stamp", "record_type"]]
    
    # set cookies
    set_cookies.rename(columns={"record_type": "type"},inplace=True)
    set_cookies.fillna({'type':"set"}, inplace=True)
    return set_cookies

# %%
def sep_cookies(ls):
    res = []
    for l in ls:
        idx = l.find('=')
        if idx > 0:
            res.append((l[:idx], l[idx+1:]))
    return res

# %%
def extract_from_js(js):
    js_cookies = js[js.symbol == 'window.document.cookie']
    js_cookies = js_cookies[js_cookies.value.notnull()]
    js_cookies_list = list(map(lambda x:x.replace(" ","").split(';'), js_cookies.value.tolist()))
    js_cookies_ls_dict = list(map(lambda x:sep_cookies(x), js_cookies_list))

    js_cookies['cookies_dict'] = js_cookies_ls_dict

    js_cookies_temp = js_cookies[['context_id','script_url', 'cookies_dict', "time_stamp", "operation"]]

    ids = []
    hosts = []
    c_names = []
    c_values = []
    t_stamps = []
    types = []
    for _, row in js_cookies_temp.iterrows():
        Id = row.context_id
        host = row.script_url
        for name, value in row.cookies_dict:
            ids.append(Id)
            hosts.append(host)
            c_names.append(name)
            c_values.append(value)
            t_stamps.append(row.time_stamp)
            types.append(row.operation)

    js_cookies_new = pd.DataFrame({"context_id":ids, "host": hosts, "name":c_names, "value":c_values, "time_stamp":t_stamps, "type":types})

    # cookie use tables
    js_cookies_new.fillna({'type':"use"}, inplace=True)
    return js_cookies_new

# %%
def extract_http(httprequests):
    httprequests = httprequests[httprequests.cookies.notnull()]

    ids = []
    hosts = []
    c_names = []
    c_values = []
    t_stamps = []
    for i, row in httprequests.iterrows():
        Id = row.context_id
        cookies_ls = row.cookies.replace(' ','').split(';')
        for l in cookies_ls:
            idx = l.find('=')
            if idx > 0:
                ids.append(row.context_id)
                hosts.append(row.host)
                c_names.append(l[:idx])
                c_values.append(l[idx+1:])
                t_stamps.append(row.time_stamp)

    httpcookies = pd.DataFrame({"context_id":ids, "host": hosts, "name":c_names, "value":c_values, "time_stamp":t_stamps})
    httpcookies["type"] = ["sent"] * httpcookies.shape[0]
    #httpcookies.fillna({'type':"send"}, inplace=True)
    return httpcookies

# %%
def merge_cookies(jsc_cookies, js_cookies, http_cookies):
    bigcookies = pd.concat([jsc_cookies, js_cookies, http_cookies], ignore_index=True)
    return bigcookies

# %%
##### concatenate

# %%
# cookies (set/change httpresponce, js)
bigcookies = []
# experiment_num = sys.argv[0] #1
# web_nums = sys.argv[1] #3
experiment_num = 1
web_nums = 3
for i in range(1, web_nums+1):
    cookies = pd.read_csv("./{}-{}-ThirdCookies.csv".format(experiment_num, i))
    jscookiesc = extract_from_jscookies(cookies)
    httprequests = pd.read_csv("./{}-{}-httprequest.csv".format(experiment_num, i))
    httpc = extract_http(httprequests)
    js = pd.read_csv("./{}-{}-js.csv".format(experiment_num, i))
    jsc = extract_from_js(js)
    bigcookies.append(merge_cookies(jscookiesc, httpc, jsc))
# Out:
# /Users/rainyleon/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py:4025: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)
# /Users/rainyleon/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py:6130: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)

# %%
hugecookies = pd.concat(bigcookies)

# %%
hugecookies
# Out:
#       context_id                                               host  \
# 0              1                                         .media.net
# 1              1                                        .google.com
# 2              1                                        .google.com
# 3              1                                        .google.com
# 4              1                                        .google.com
# 5              1                                        .google.com
# 6              1                             .scorecardresearch.com
# 7              1                             .scorecardresearch.com
# 8              1                                    news.google.com
# 9              1                                    .pay.google.com
# 10             1                                    .pay.google.com
# 11             1                                    .pay.google.com
# 12             1                                         .adnxs.com
# 13             1                                         .openx.net
# 14             1                                     .bidswitch.net
# 15             1                                     .bidswitch.net
# 16             1                                     .bidswitch.net
# 17             1                                        .dotomi.com
# 18             1                                     pay.google.com
# 19             1                                       .bluekai.com
# 20             1                                       .bluekai.com
# 21             1                                   .doubleclick.net
# 22             1                                         .adnxs.com
# 23             1                                         .adnxs.com
# 24             1                                     .bidswitch.net
# 25             1                                     .bidswitch.net
# 26             1                                     .bidswitch.net
# 27             1                                     .bidswitch.net
# 28             1                                       .bluekai.com
# 29             1                                       .bluekai.com
# ...          ...                                                ...
# 1831           3  https://siteimproveanalytics.com/js/siteanalyz...
# 1832           3  https://siteimproveanalytics.com/js/siteanalyz...
# 1833           3  https://siteimproveanalytics.com/js/siteanalyz...
# 1834           3  https://siteimproveanalytics.com/js/siteanalyz...
# 1835           3  https://siteimproveanalytics.com/js/siteanalyz...
# 1836           3  https://siteimproveanalytics.com/js/siteanalyz...
# 1837           3  https://siteimproveanalytics.com/js/siteanalyz...
# 1838           3  https://siteimproveanalytics.com/js/siteanalyz...
# 1839           3  https://siteimproveanalytics.com/js/siteanalyz...
# 1840           3  https://siteimproveanalytics.com/js/siteanalyz...
# 1841           3  https://siteimproveanalytics.com/js/siteanalyz...
# 1842           3  https://siteimproveanalytics.com/js/siteanalyz...
# 1843           3  https://siteimproveanalytics.com/js/siteanalyz...
# 1844           3  https://siteimproveanalytics.com/js/siteanalyz...
# 1845           3  https://siteimproveanalytics.com/js/siteanalyz...
# 1846           3  https://siteimproveanalytics.com/js/siteanalyz...
# 1847           3  https://siteimproveanalytics.com/js/siteanalyz...
# 1848           3  https://siteimproveanalytics.com/js/siteanalyz...
# 1849           3  https://siteimproveanalytics.com/js/siteanalyz...
# 1850           3  https://siteimproveanalytics.com/js/siteanalyz...
# 1851           3  https://siteimproveanalytics.com/js/siteanalyz...
# 1852           3  https://siteimproveanalytics.com/js/siteanalyz...
# 1853           3  https://siteimproveanalytics.com/js/siteanalyz...
# 1854           3  https://siteimproveanalytics.com/js/siteanalyz...
# 1855           3  https://siteimproveanalytics.com/js/siteanalyz...
# 1856           3  https://siteimproveanalytics.com/js/siteanalyz...
# 1857           3  https://siteimproveanalytics.com/js/siteanalyz...
# 1858           3  https://siteimproveanalytics.com/js/siteanalyz...
# 1859           3  https://siteimproveanalytics.com/js/siteanalyz...
# 1860           3  https://siteimproveanalytics.com/js/siteanalyz...
#
#                     name                                              value  \
# 0             visitor-id                             2310846292182041000V10
# 1                    NID  203=qFA3SyC0fwFwcvqY7MI3nsCFP8YjZRERPiOGOXOwmf...
# 2                    NID  203=wrQi5gqbpIWCBES0bmmyn_WjQLonOi99hLCLqijx1k...
# 3                    NID  203=wrQi5gqbpIWCBES0bmmyn_WjQLonOi99hLCLqijx1k...
# 4                    NID  203=bHHssFauB8Gn7J19HHvYAtfqgk-pvmGVbRLDCNL385...
# 5                    NID  203=bHHssFauB8Gn7J19HHvYAtfqgk-pvmGVbRLDCNL385...
# 6                    UID                  1DA23a36a2aa20a318412601588083033
# 7                   UIDR                                         1588083033
# 8                    OTZ                                 5429651_56_56__56_
# 9                    _ga                         GA1.3.884918508.1588083034
# 10                  _gid                        GA1.3.1251599022.1588083034
# 11     _gat_UA1168580691                                                  1
# 12                 uuid2                                4216705963238673072
# 13                     i    f1ce0de6-2d02-0999-3b7a-7bad14436ce4|1588083034
# 14                 tuuid               4679e76d-9062-4b75-8547-8ae6d7f4aaa1
# 15                     c                                         1588083034
# 16              tuuid_lu                                         1588083034
# 17            DotomiTest                                   1743060967b211b8
# 18                   OTZ                                 5429651_56_56__56_
# 19                  bkdc                                                phx
# 20                   bku                                   5LD99aG83a85wM/A
# 21           test_cookie                                 CheckForPermission
# 22                 uuid2                                4216705963238673072
# 23                 uuid2                                4216705963238673072
# 24                 tuuid               4679e76d-9062-4b75-8547-8ae6d7f4aaa1
# 25                 tuuid               4679e76d-9062-4b75-8547-8ae6d7f4aaa1
# 26              tuuid_lu                                         1588083035
# 27              tuuid_lu                                         1588083035
# 28                   bku                                   5LD99aG83a85wM/A
# 29                   bku                                   5LD99aG83a85wM/A
# ...                  ...                                                ...
# 1831  _gat_UA-4659861-11                                                  1
# 1832              __utmc                                           41573937
# 1833              __utmt                                                  1
# 1834              __utma  41573937.991307700.1588083347.1588083347.15880...
# 1837  2020-04-28T14:17:39.965Z               get
# 1838  2020-04-28T14:17:39.965Z               get
# 1839  2020-04-28T14:17:39.965Z               get
# 1840  2020-04-28T14:17:39.965Z               get
# 1841  2020-04-28T14:17:39.965Z               get
# 1842  2020-04-28T14:17:39.965Z               get
# 1843  2020-04-28T14:17:39.965Z               get
# 1844  2020-04-28T14:17:39.965Z               get
# 1845  2020-04-28T14:17:39.965Z               get
# 1846  2020-04-28T14:17:39.965Z               get
# 1847  2020-04-28T14:17:39.965Z               get
# 1848  2020-04-28T14:17:39.965Z               get
# 1849  2020-04-28T14:17:39.965Z               get
# 1850  2020-04-28T14:17:39.965Z               get
# 1851  2020-04-28T14:17:39.965Z               get
# 1852  2020-04-28T14:17:39.965Z               get
# 1853  2020-04-28T14:17:39.965Z               get
# 1854  2020-04-28T14:17:39.965Z               get
# 1855  2020-04-28T14:17:39.965Z               get
# 1856  2020-04-28T14:17:39.966Z               set
# 1857  2020-04-28T14:17:39.966Z               set
# 1858  2020-04-28T14:17:39.966Z               set
# 1859  2020-04-28T14:17:39.966Z               set
# 1860  2020-04-28T14:17:39.966Z               set
#
# [67468 rows x 6 columns]

# %%
hugecookies.type.unique()
# Out:
# array(['added-or-changed', 'deleted', 'sent', 'set', 'get'], dtype=object)

# %%
hugecookies.to_csv("./hugecookies/hugecookies-{}.csv".format(experiment_num), index=False)

# %%
##########
unique_hugecookies = hugecookies.drop_duplicates()
unique_hugecookies.to_csv("./hugecookies/unique_hugecookies-{}.csv".format(experiment_num), index=False)

# %%
hugecookies.shape
# Out:
# (67468, 6)

# %%
# unique_hugecookies.groupby("value").mean().shape

# %%
unique_context_1 = unique_hugecookies[unique_hugecookies.context_id == 1].value.tolist()
unique_context_2 = unique_hugecookies[unique_hugecookies.context_id == 2].value.tolist()
unique_context_3 = unique_hugecookies[unique_hugecookies.context_id == 3].value.tolist()

# %%
list(set(unique_context_1) & set(unique_context_2))
# Out:
# ['',
#  'AQvitULEwpGHyem3KD_sclC_TdevAkmkIDc5fX-2ctnM3cuySKT08zVqdm6IIk8PUxEDL9hvoMEK4titQ8kOr5jiWXjgwlFT-oo',
#  '\\v1_Qy2edN3p3Xyn/PRyFq5qkA==\\',
#  'SYYIIXTLSI2r3Pl2jBlm8Q',
#  '7f675ea8-395e-4900-ac28-995748e08e07',
#  '6ZmmRprj1JtqWW5~~1',
#  '4679e76d-9062-4b75-8547-8ae6d7f4aaa1~~1',
#  '00000000-0000-003a-398c-861588083038',
#  'd=AQABBF45qF4CEEgvPTiD59Nt7NBRJgIJ_7MFEgEBAQGKqV6yXgAAAAAA_SMAAAcIXjmoXgIJ_7M&S=AQAAAjIjmhMSKUaUG3XfXfyVNH8',
#  '5LD99aG83a85wM/A',
#  'testWrite',
#  '2fac0fa240ca1592',
#  '1DA23a36a2aa20a318412601588083033',
#  'di_9592bd7b1b884f9381548~~1',
#  '4b07018c-0dcb-40e4-8314-5ae24eab86d9',
#  'g_surferid~Xqg5XAAAAKg2BwFU',
#  '4679e76d-9062-4b75-8547-8ae6d7f4aaa1',
#  'YES',
#  '1AB15E46-124E-4486-9D2E-CF149023BDE1',
#  '1588083033',
#  '4Oe53a4sDRVl1-qj0eXv6L',
#  'NO_DATA',
#  '203=bHHssFauB8Gn7J19HHvYAtfqgk-pvmGVbRLDCNL385XQIjO1-bGzE_cpYAp4bawqxjC6pYXp2udS6fZ4kOUxm8bq7wve-5WyJNPr-SNTYn1f2Z-75jTdVBxdQRzjMKPpaMjtRKafXCAhGP-IzdmcihVUgiW04OMAPMeMmcJZoAI',
#  '00000000-0000-003a-3d76-c31588083153',
#  'AHWqTUlOVZKvNy4CkZNqO7cRitxqXgMD91fWHMzrP_KlgTJoBV118EIpwWuHIXw7',
#  'b7vo909fageau&b=3&s=pu',
#  'phx',
#  'None',
#  '/',
#  'AAAGS4e_fM5r_wMBwAzSAAAAAAA~~1',
#  '4:1588083122',
#  'CAA=',
#  'oW3Z6M8xneycbA0Z5WVC~~1',
#  '\\\\',
#  'A-NQZc62Z08Doo7EcvKyr34',
#  '1588083034',
#  '1',
#  'FTF',
#  'Good',
#  'a71a8619-1168-467b-803a-eb1d7fcef021#1588083069027',
#  '2310846292182041000V10',
#  '0',
#  'Thu,01Jan197000:00:01GMT',
#  'AQEBAQFeqYpeskIeXgSK',
#  '.com',
#  'a86be414-eaf1-4c9a-aa35-6cce2d06a0c3~~1',
#  '4216705963238673072',
#  'CAESFgoHcnViaWNvbhILCL7Tot7-4bU4EAUYBSABKAIyCwiEksiKleK1OBAFOAE.',
#  'K9JZMWOU-1E-KP5N~~1',
#  '1588083035',
#  'rNR6Gl9md1RRY3NRVWJua2w0WXFxdWxZQU9mJTJCR3V4OEtCRE5JYzc3cFRpeEo4Qmd5SHJndmhZZCUyRnRLQmk5MWNhOSUyQkRSaG1sR0pPTXBDa3diUHdhSHlhdFdjUSUzRCUzRA',
#  'test',
#  'AEYECmK4p0epAQUnpGNUnV2fwEISwdK8S9R1KczgJ2I=',
#  '2558098555938012379',
#  '1588083038',
#  'e30',
#  '4216705963238673072~~1']

# %%
list(set(unique_context_1) & set(unique_context_3))
# Out:
# ['',
#  '1',
#  'NO_DATA',
#  'AHWqTUlOVZKvNy4CkZNqO7cRitxqXgMD91fWHMzrP_KlgTJoBV118EIpwWuHIXw7',
#  '/']

# %%
list(set(unique_context_2) & set(unique_context_3))
# Out:
# ['',
#  '1',
#  '0VKKhljkesAUbsROW..BeqDnl..F6o.1.0.BeqDnl.',
#  'lax',
#  'NO_DATA',
#  'AHWqTUlOVZKvNy4CkZNqO7cRitxqXgMD91fWHMzrP_KlgTJoBV118EIpwWuHIXw7',
#  '/']

# %%
list(set(unique_context_1) & set(unique_context_2) & set(unique_context_3))
# Out:
# ['',
#  '1',
#  'NO_DATA',
#  'AHWqTUlOVZKvNy4CkZNqO7cRitxqXgMD91fWHMzrP_KlgTJoBV118EIpwWuHIXw7',
#  '/']

# %%
len(list(set(unique_context_1) & set(unique_context_2)))
# Out:
# 57

# %%
len(list(set(unique_context_1) & set(unique_context_3)))
# Out:
# 5

# %%
len(list(set(unique_context_2) & set(unique_context_3)))
# Out:
# 7

# %%
unique_hugecookies.groupby(["name", "value"]).value.unique()


unique_hugecookies.groupby(["name", "value"]).value.unique().shape
# Out:
# (698,)
