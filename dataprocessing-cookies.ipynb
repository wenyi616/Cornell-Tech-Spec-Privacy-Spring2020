# %%
import numpy as np
import pandas as pd
import math
import sys

# %%
def extract_from_jscookies(cookies):
    set_cookies = cookies[["context_id", "host", "name", "value", "time_stamp", "record_type"]]
    
    # set cookies
    set_cookies.rename(columns={"record_type": "type"},inplace=True)
    set_cookies.fillna({'type':"set"}, inplace=True)
    return set_cookies

# %%
def sep_cookies(ls):
    res = []
    for l in ls:
        idx = l.find('=')
        if idx > 0:
            res.append((l[:idx], l[idx+1:]))
    return res

# %%
def extract_from_js(js):
    js_cookies = js[js.symbol == 'window.document.cookie']
    js_cookies = js_cookies[js_cookies.value.notnull()]
    js_cookies_list = list(map(lambda x:x.replace(" ","").split(';'), js_cookies.value.tolist()))
    js_cookies_ls_dict = list(map(lambda x:sep_cookies(x), js_cookies_list))

    js_cookies['cookies_dict'] = js_cookies_ls_dict

    js_cookies_temp = js_cookies[['context_id','script_url', 'cookies_dict', "time_stamp", "operation"]]

    ids = []
    hosts = []
    c_names = []
    c_values = []
    t_stamps = []
    types = []
    for _, row in js_cookies_temp.iterrows():
        Id = row.context_id
        host = row.script_url
        for name, value in row.cookies_dict:
            ids.append(Id)
            hosts.append(host)
            c_names.append(name)
            c_values.append(value)
            t_stamps.append(row.time_stamp)
            types.append(row.operation)

    js_cookies_new = pd.DataFrame({"context_id":ids, "host": hosts, "name":c_names, "value":c_values, "time_stamp":t_stamps, "type":types})

    # cookie use tables
    js_cookies_new.fillna({'type':"use"}, inplace=True)
    return js_cookies_new

# %%
def extract_http(httprequests):
    httprequests = httprequests[httprequests.cookies.notnull()]

    ids = []
    hosts = []
    c_names = []
    c_values = []
    t_stamps = []
    for i, row in httprequests.iterrows():
        Id = row.context_id
        cookies_ls = row.cookies.replace(' ','').split(';')
        for l in cookies_ls:
            idx = l.find('=')
            if idx > 0:
                ids.append(row.context_id)
                hosts.append(row.host)
                c_names.append(l[:idx])
                c_values.append(l[idx+1:])
                t_stamps.append(row.time_stamp)

    httpcookies = pd.DataFrame({"context_id":ids, "host": hosts, "name":c_names, "value":c_values, "time_stamp":t_stamps})
    httpcookies["type"] = ["sent"] * httpcookies.shape[0]
    #httpcookies.fillna({'type':"send"}, inplace=True)
    return httpcookies

# %%
def merge_cookies(jsc_cookies, js_cookies, http_cookies):
    bigcookies = pd.concat([jsc_cookies, js_cookies, http_cookies], ignore_index=True)
    return bigcookies

# %%
##### concatenate

# %%
# cookies (set/change httpresponce, js)
bigcookies = []
# experiment_num = sys.argv[0] #1
# web_nums = sys.argv[1] #3
experiment_num = 2
web_nums = 3
for i in range(1, web_nums+1):
    cookies = pd.read_csv("./{}-{}-ThirdCookies.csv".format(experiment_num, i))
    jscookiesc = extract_from_jscookies(cookies)
    httprequests = pd.read_csv("./{}-{}-httprequest.csv".format(experiment_num, i))
    httpc = extract_http(httprequests)
    js = pd.read_csv("./{}-{}-js.csv".format(experiment_num, i))
    jsc = extract_from_js(js)
    bigcookies.append(merge_cookies(jscookiesc, httpc, jsc))
# Out:
# /Users/rainyleon/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py:4025: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)
# /Users/rainyleon/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py:6130: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)

# %%
hugecookies = pd.concat(bigcookies)

# %%
hugecookies
# Out:
#       context_id                                           host  \
# 0              1                                    .demdex.net
# 1              1                                     .media.net
# 2              1                         .scorecardresearch.com
# 3              1                         .scorecardresearch.com
# 4              1                                    .reddit.com
# 5              1                                     .rlcdn.com
# 6              1                                     .rlcdn.com
# 7              1                                      .turn.com
# 8              1                                     .rlcdn.com
# 9              1                                     .rlcdn.com
# 10             1                                     .rlcdn.com
# 11             1                                     .rlcdn.com
# 12             1                                  .facebook.com
# 13             1                                    .demdex.net
# 14             1                                    .demdex.net
# 15             1                                 ibclick.stream
# 16             1                                 ibclick.stream
# 17             1                           .amazon-adsystem.com
# 18             1                                    .adsrvr.org
# 19             1                               .doubleclick.net
# 20             1                                     .liadm.com
# 21             1                               .doubleclick.net
# 22             1                               .doubleclick.net
# 23             1                               .doubleclick.net
# 24             1                               .doubleclick.net
# 25             1                               .doubleclick.net
# 26             1                               .doubleclick.net
# 27             1                               .doubleclick.net
# 28             1                               .doubleclick.net
# 29             1                               .doubleclick.net
# ...          ...                                            ...
# 1766           3  https://www.google-analytics.com/analytics.js
# 1767           3  https://www.google-analytics.com/analytics.js
# 1768           3  https://www.google-analytics.com/analytics.js
# 1769           3  https://www.google-analytics.com/analytics.js
# 1770           3  https://www.google-analytics.com/analytics.js
# 1771           3  https://www.google-analytics.com/analytics.js
# 1772           3  https://www.google-analytics.com/analytics.js
# 1773           3  https://www.google-analytics.com/analytics.js
# 1774           3  https://www.google-analytics.com/analytics.js
# 1775           3  https://www.google-analytics.com/analytics.js
# 1776           3  https://www.google-analytics.com/analytics.js
# 1777           3  https://www.google-analytics.com/analytics.js
# 1778           3  https://www.google-analytics.com/analytics.js
# 1779           3  https://www.google-analytics.com/analytics.js
# 1780           3  https://www.google-analytics.com/analytics.js
# 1781           3  https://www.google-analytics.com/analytics.js
# 1782           3  https://www.google-analytics.com/analytics.js
# 1783           3  https://www.google-analytics.com/analytics.js
# 1784           3  https://www.google-analytics.com/analytics.js
# 1785           3  https://www.google-analytics.com/analytics.js
# 1786           3  https://www.google-analytics.com/analytics.js
# 1787           3  https://www.google-analytics.com/analytics.js
# 1788           3  https://www.google-analytics.com/analytics.js
# 1789           3  https://www.google-analytics.com/analytics.js
# 1790           3  https://www.google-analytics.com/analytics.js
# 1791           3  https://www.google-analytics.com/analytics.js
# 1792           3  https://www.google-analytics.com/analytics.js
# 1793           3  https://www.google-analytics.com/analytics.js
# 1794           3  https://www.google-analytics.com/analytics.js
# 1795           3  https://www.google-analytics.com/analytics.js
#
#                     name                                              value  \
# 0                 demdex             47026235237090761000520117546690963371
# 1             visitor-id                             2312074272182012000V10
# 2                    UID                  1A117223243a152c3341e7g1588205828
# 3                   UIDR                                         1588205828
# 4                reddaid                                   RT36B44SRKAPJFIB
# 5                  rlas3       k2nnfz0Jcs/DVPE4+qiZpryOzCn6ZMU4wh5rdjmSbVA=
# 6                   pxrc                                               CAA=
# 7                    uid                                8541296435815272522
# 8                  rlas3       n9nAqGVUiBPDVPE4+qiZpryOzCn6ZMU4wh5rdjmSbVA=
# 9                  rlas3       n9nAqGVUiBPDVPE4+qiZpryOzCn6ZMU4wh5rdjmSbVA=
# 10                  pxrc                       CIeyqPUFEgUI6AcQABIGCO3rARAA
# 11                  pxrc                       CIeyqPUFEgUI6AcQABIGCO3rARAA
# 12                    fr            0WdQFxSXT4qtVtcwm..BeqhkH...1.0.BeqhkH.
# 13                demdex             47026235237090761000520117546690963371
# 14                demdex             47026235237090761000520117546690963371
# 15                  _ibp    0:k9m0qunz:ca7c99cf-f3d3-4633-813c-bb16a872fe82
# 16                  _ibs    0:k9m0quo1:37f8f4b9-f6e2-4f3c-a985-1d2cea63f538
# 17                 ad-id                          A-TKbNvwtktyqEr3xtAcFRY|t
# 18                  TDID               79022fe3-a506-4d6d-8117-0d3ffff0a725
# 19           test_cookie                                 CheckForPermission
# 20                 lidid               07c514ce-789a-4fff-bca5-3d1c7732ca31
# 21                   IDE  AHWqTUlNx_VGLhC_AbP-Lo9dy-Le8W2mYI4VlZdwXkG9Xk...
# 22           test_cookie                                 CheckForPermission
# 23                   IDE  AHWqTUlPk_Z40rXQyL4m5AWloJQ6y7cbwTt8TozET4_MiS...
# 24                   IDE  AHWqTUlPk_Z40rXQyL4m5AWloJQ6y7cbwTt8TozET4_MiS...
# 25                   IDE  AHWqTUmKVQ11Ywml6car_71YYVn_4p_oBdmgBbPGhv3hN0...
# 26                   IDE  AHWqTUmKVQ11Ywml6car_71YYVn_4p_oBdmgBbPGhv3hN0...
# 27                   IDE  AHWqTUl3KuTKupPPwhm-YTmQt_8ihDaVno-eqmSlMXBc3b...
# 28                   IDE  AHWqTUl3KuTKupPPwhm-YTmQt_8ihDaVno-eqmSlMXBc3b...
# 29                   IDE  AHWqTUmniWpzWGujqQPowPTc53SpZfICZv5HAZ0N86WxNO...
# ...                  ...                                                ...
# 1766                _gid                        GA1.3.2017137307.1588206174
# 1767              __utma  41573937.562757510.1588206148.1588206148.15882...
# 1768              __utmc                                           41573937
# 1769              __utmz  41573937.1588206148.1.1.utmcsr=(direct)|utmccn...
# 1770              __utmt                                                  1
# 1771              __utmb                           41573937.1.10.1588206148
# 1772                 _ga                         GA1.2.562757510.1588206148
# 1773                _gid                        GA1.2.2017137307.1588206174
# 1774                _gat                                                  1
# 1775              nmstat                                      1588206269520
# 1776  _gat_UA-4659861-10                                                  1
# 1777                 _ga                         GA1.3.562757510.1588206148
# 1778                _gid                        GA1.3.2017137307.1588206174
# 1779  _gat_UA-4659861-11                                                  1
# 1780                path                                                  /
# 1781             expires                           Thu,30Apr202000:25:21GMT
# 1782              domain                           engineering.berkeley.edu
# 1783              __utma  41573937.562757510.1588206148.1588206148.15882...
# 1784              __utmc                                           41573937
# 1785              __utmz  41573937.1588206148.1.1.utmcsr=(direct)|utmccn...
# 1786              __utmt                                                  1
# 1787              __utmb                           41573937.1.10.1588206148
# 1788                 _ga                         GA1.2.562757510.1588206148
# 1789                _gid                        GA1.2.2017137307.1588206174
# 1790                _gat                                                  1
# 1791              nmstat                                      1588206269520
# 1792  _gat_UA-4659861-10                                                  1
# 1793                 _ga                         GA1.3.562757510.1588206148
# 1794                _gid                        GA1.3.2017137307.1588206174
# 1795  _gat_UA-4659861-11                                                  1
#
#                     time_stamp              type
# 0     2020-04-30T00:17:07.546Z  added-or-changed
# 1     2020-04-30T00:17:07.603Z  added-or-changed
# 2     2020-04-30T00:17:08.439Z  added-or-changed
# 3     2020-04-30T00:17:08.441Z  added-or-changed
# 4     2020-04-30T00:17:09.504Z  added-or-changed
# 5     2020-04-30T00:17:09.814Z  added-or-changed
# 6     2020-04-30T00:17:09.815Z  added-or-changed
# 7     2020-04-30T00:17:09.861Z  added-or-changed
# 8     2020-04-30T00:17:11.456Z           deleted
# 9     2020-04-30T00:17:11.456Z  added-or-changed
# 10    2020-04-30T00:17:11.457Z           deleted
# 11    2020-04-30T00:17:11.457Z  added-or-changed
# 12    2020-04-30T00:17:11.463Z  added-or-changed
# 13    2020-04-30T00:17:11.643Z           deleted
# 14    2020-04-30T00:17:11.644Z  added-or-changed
# 15    2020-04-30T00:17:11.653Z  added-or-changed
# 16    2020-04-30T00:17:11.654Z  added-or-changed
# 17    2020-04-30T00:17:11.663Z  added-or-changed
# 18    2020-04-30T00:17:11.704Z  added-or-changed
# 19    2020-04-30T00:17:11.715Z  added-or-changed
# 20    2020-04-30T00:17:11.946Z  added-or-changed
# 21    2020-04-30T00:17:12.062Z  added-or-changed
# 22    2020-04-30T00:17:12.062Z           deleted
# 23    2020-04-30T00:17:12.065Z           deleted
# 24    2020-04-30T00:17:12.065Z  added-or-changed
# 25    2020-04-30T00:17:12.068Z           deleted
# 26    2020-04-30T00:17:12.068Z  added-or-changed
# 27    2020-04-30T00:17:12.070Z           deleted
# 28    2020-04-30T00:17:12.071Z  added-or-changed
# 29    2020-04-30T00:17:12.072Z           deleted
# ...                        ...               ...
# 1766  2020-04-30T00:24:21.227Z               get
# 1767  2020-04-30T00:24:21.229Z               get
# 1768  2020-04-30T00:24:21.229Z               get
# 1769  2020-04-30T00:24:21.229Z               get
# 1770  2020-04-30T00:24:21.229Z               get
# 1771  2020-04-30T00:24:21.229Z               get
# 1772  2020-04-30T00:24:21.229Z               get
# 1773  2020-04-30T00:24:21.229Z               get
# 1774  2020-04-30T00:24:21.229Z               get
# 1775  2020-04-30T00:24:21.229Z               get
# 1776  2020-04-30T00:24:21.229Z               get
# 1777  2020-04-30T00:24:21.229Z               get
# 1778  2020-04-30T00:24:21.229Z               get
# 1779  2020-04-30T00:24:21.229Z               set
# 1780  2020-04-30T00:24:21.229Z               set
# 1781  2020-04-30T00:24:21.229Z               set
# 1782  2020-04-30T00:24:21.229Z               set
# 1783  2020-04-30T00:24:21.229Z               get
# 1784  2020-04-30T00:24:21.229Z               get
# 1785  2020-04-30T00:24:21.229Z               get
# 1786  2020-04-30T00:24:21.229Z               get
# 1787  2020-04-30T00:24:21.229Z               get
# 1788  2020-04-30T00:24:21.229Z               get
# 1789  2020-04-30T00:24:21.229Z               get
# 1790  2020-04-30T00:24:21.229Z               get
# 1791  2020-04-30T00:24:21.229Z               get
# 1792  2020-04-30T00:24:21.229Z               get
# 1793  2020-04-30T00:24:21.229Z               get
# 1794  2020-04-30T00:24:21.229Z               get
# 1795  2020-04-30T00:24:21.229Z               get
#
# [81050 rows x 6 columns]

# %%
hugecookies.type.unique()
# Out:
# array(['added-or-changed', 'deleted', 'sent', 'set', 'get'], dtype=object)

# %%
hugecookies.to_csv("./hugecookies/hugecookies-{}.csv".format(experiment_num), index=False)

##########
unique_hugecookies = hugecookies.drop_duplicates()
unique_hugecookies.to_csv("./hugecookies/unique_hugecookies-{}.csv".format(experiment_num), index=False)

# %%
hugecookies.shape
# Out:
# (67468, 6)

# %%
# unique_hugecookies.groupby("value").mean().shape

# %%
unique_context_1 = unique_hugecookies[unique_hugecookies.context_id == 1].value.tolist()
unique_context_2 = unique_hugecookies[unique_hugecookies.context_id == 2].value.tolist()
unique_context_3 = unique_hugecookies[unique_hugecookies.context_id == 3].value.tolist()

# %%
list(set(unique_context_1) & set(unique_context_2))
# Out:
# ['',
#  'AQvitULEwpGHyem3KD_sclC_TdevAkmkIDc5fX-2ctnM3cuySKT08zVqdm6IIk8PUxEDL9hvoMEK4titQ8kOr5jiWXjgwlFT-oo',
#  '\\v1_Qy2edN3p3Xyn/PRyFq5qkA==\\',
#  'SYYIIXTLSI2r3Pl2jBlm8Q',
#  '7f675ea8-395e-4900-ac28-995748e08e07',
#  '6ZmmRprj1JtqWW5~~1',
#  '4679e76d-9062-4b75-8547-8ae6d7f4aaa1~~1',
#  '00000000-0000-003a-398c-861588083038',
#  'd=AQABBF45qF4CEEgvPTiD59Nt7NBRJgIJ_7MFEgEBAQGKqV6yXgAAAAAA_SMAAAcIXjmoXgIJ_7M&S=AQAAAjIjmhMSKUaUG3XfXfyVNH8',
#  '5LD99aG83a85wM/A',
#  'testWrite',
#  '2fac0fa240ca1592',
#  '1DA23a36a2aa20a318412601588083033',
#  'di_9592bd7b1b884f9381548~~1',
#  '4b07018c-0dcb-40e4-8314-5ae24eab86d9',
#  'g_surferid~Xqg5XAAAAKg2BwFU',
#  '4679e76d-9062-4b75-8547-8ae6d7f4aaa1',
#  'YES',
#  '1AB15E46-124E-4486-9D2E-CF149023BDE1',
#  '1588083033',
#  '4Oe53a4sDRVl1-qj0eXv6L',
#  'NO_DATA',
#  '203=bHHssFauB8Gn7J19HHvYAtfqgk-pvmGVbRLDCNL385XQIjO1-bGzE_cpYAp4bawqxjC6pYXp2udS6fZ4kOUxm8bq7wve-5WyJNPr-SNTYn1f2Z-75jTdVBxdQRzjMKPpaMjtRKafXCAhGP-IzdmcihVUgiW04OMAPMeMmcJZoAI',
#  '00000000-0000-003a-3d76-c31588083153',
#  'AHWqTUlOVZKvNy4CkZNqO7cRitxqXgMD91fWHMzrP_KlgTJoBV118EIpwWuHIXw7',
#  'b7vo909fageau&b=3&s=pu',
#  'phx',
#  'None',
#  '/',
#  'AAAGS4e_fM5r_wMBwAzSAAAAAAA~~1',
#  '4:1588083122',
#  'CAA=',
#  'oW3Z6M8xneycbA0Z5WVC~~1',
#  '\\\\',
#  'A-NQZc62Z08Doo7EcvKyr34',
#  '1588083034',
#  '1',
#  'FTF',
#  'Good',
#  'a71a8619-1168-467b-803a-eb1d7fcef021#1588083069027',
#  '2310846292182041000V10',
#  '0',
#  'Thu,01Jan197000:00:01GMT',
#  'AQEBAQFeqYpeskIeXgSK',
#  '.com',
#  'a86be414-eaf1-4c9a-aa35-6cce2d06a0c3~~1',
#  '4216705963238673072',
#  'CAESFgoHcnViaWNvbhILCL7Tot7-4bU4EAUYBSABKAIyCwiEksiKleK1OBAFOAE.',
#  'K9JZMWOU-1E-KP5N~~1',
#  '1588083035',
#  'rNR6Gl9md1RRY3NRVWJua2w0WXFxdWxZQU9mJTJCR3V4OEtCRE5JYzc3cFRpeEo4Qmd5SHJndmhZZCUyRnRLQmk5MWNhOSUyQkRSaG1sR0pPTXBDa3diUHdhSHlhdFdjUSUzRCUzRA',
#  'test',
#  'AEYECmK4p0epAQUnpGNUnV2fwEISwdK8S9R1KczgJ2I=',
#  '2558098555938012379',
#  '1588083038',
#  'e30',
#  '4216705963238673072~~1']

# %%
list(set(unique_context_1) & set(unique_context_3))
# Out:
# ['',
#  '1',
#  'NO_DATA',
#  'AHWqTUlOVZKvNy4CkZNqO7cRitxqXgMD91fWHMzrP_KlgTJoBV118EIpwWuHIXw7',
#  '/']

# %%
list(set(unique_context_2) & set(unique_context_3))
# Out:
# ['',
#  '1',
#  '0VKKhljkesAUbsROW..BeqDnl..F6o.1.0.BeqDnl.',
#  'lax',
#  'NO_DATA',
#  'AHWqTUlOVZKvNy4CkZNqO7cRitxqXgMD91fWHMzrP_KlgTJoBV118EIpwWuHIXw7',
#  '/']

# %%
list(set(unique_context_1) & set(unique_context_2) & set(unique_context_3))
# Out:
# ['',
#  '1',
#  'NO_DATA',
#  'AHWqTUlOVZKvNy4CkZNqO7cRitxqXgMD91fWHMzrP_KlgTJoBV118EIpwWuHIXw7',
#  '/']

# %%
len(list(set(unique_context_1) & set(unique_context_2)))
# Out:
# 57

# %%
len(list(set(unique_context_1) & set(unique_context_3)))
# Out:
# 5

# %%
len(list(set(unique_context_2) & set(unique_context_3)))
# Out:
# 7

# %%
# unique_hugecookies.groupby(["name", "value"]).value.unique()


# unique_hugecookies.groupby(["name", "value"]).value.unique().shape
# Out:
# (698,)
